# %%
import json
import random
import numpy as np
import pandas as pd
import pickle
import tqdm
import re
import os

# %%
df = pd.read_csv('custom_data_annotated.csv')
data = list(zip(df.sentence,df.annotations))

# %%
len(df)
# Out:
# 843

# %%
with open('SmartTool/custom_data_valid.txt','r') as f:
    qna = json.load(f)

# %%
qna[:4]
# Out:
# [['Among men aged 42 years or older, how many have had other postsurgical states since 2008?',
#   'count(*)-long_registry',
#   'age > 42, endpoint = other postsurgical states, sex = male, year > 2008'],
#  ['What was the average age of people diagnosed with other congenital malformations of skin and who died before 2001?',
#   'avg(age)-mortality',
#   'endpoint = other congenital malformations of skin'],
#  ['If one has precocious puberty. What is the average age of death?',
#   'avg(age)-long_registry',
#   'endpoint=precocious puberty'],
#  ['How many people under the age of 4 have been diagnosed with burn and corrosion of head and neck?',
#   'count(*)-long_registry',
#   'age < 4, endpoint = burn and corrosion of head and neck']]

# %%
re.findall(r'endpoint = ([^,$]+)+','age > 42, endpoint = other postsurgical states')
# Out:
# ['other postsurgical states']

# %%
# [re.findall(r'endpoint = ([^,$]+)+',i[-1])[0] for i in qna]
eps = []
for i in range(len(qna)):
    ep = re.findall(r'(endpoint|outcome|prior) = ([^,$]+)+',qna[i][-1])
    if len(ep) == 1:
        eps.append([ep[0][1]])
    elif len(ep) == 2: 
        eps.append([ep[0][1],ep[1][1]])
    else:
        print(i,qna[i][0])
        print(qna[i][-1])
        print()
        eps.append('failed')

# %%
[('endpoint', 'other postsurgical states')][0][1]
# Out:
# 'other postsurgical states'

# %%
eps_pred = []
for i in data:
    res = json.loads(i[1])
    eps_pred.append([j['str'] for j in res])

# %%
score, total = 0, 0
for i in range(len(eps)):
    for j in eps[i]:
        total += 1
        if j in eps_pred[i]: score += 1
        else:
            print(data[i][0])
            print(eps[i])
            print(eps_pred[i])
            print()
# Out:
# What is the number of women who die ten years after being diagnosed with melignant neoplasm of mesothelium and soft tissue?
# ['melignant neoplasm of mesothelium and soft tissue']
# ['soft tissue', 'years', 'diagnosed', 'neoplasm', 'mesothelium']
#
# Given other specified and unspecified disorders of eye and adnexa, what are the six most powerful related diseases for people under 41?
# ['other specified and unspecified disorders of eye and adnexa']
# ['adnexa', 'related', 'unspecified', 'disorders', 'diseases', 'eye']
#
# I am a woman with other disorders involving the immune mechanism and not elsewhere classified. What are the eight most likely diagnoses that this woman will receive?
# ['other disorders involving the immune mechanism and not elsewhere classified']
# ['disorders involving the immune mechanism', 'likely', 'diagnoses']
#
# In 2012, how many women over the age of 63 had necrobiosis lipoidica and not elsewhere classified?
# ['necrobiosis lipoidica and not elsewhere classified']
# ['age', 'necrobiosis lipoidica']
#
# Before 2004, how many females above 50 years old are diagnosed with acquired clawhand and clubhand and clawfoot and clubfoot?
# ['acquired clawhand and clubhand and clawfoot and clubfoot']
# ['old', 'diagnosed', 'acquired clawhand', 'clubhand', 'clubfoot', 'clawfoot', 'years']
#
# How has previous diagnosis of mesial bite affected the risk of other congenital malformations of face and neck in people over 57 years of age since 2016?
# ['other congenital malformations of face and neck', 'mesial bite']
# ['age', 'previous', 'diagnosis', 'mesial', 'bite', 'other congenital malformations of face and neck', 'years']
#
# What is the hazard ratio for acquired clawhand and clubhand and clawfoot and clubfoot in people under 35 years of age with hyperaldosteronism in the year starting 2019?
# ['hyperaldosteronism', 'acquired clawhand and clubhand and clawfoot and clubfoot']
# ['age', 'year', 'hyperaldosteronism', 'acquired clawhand', 'clubhand', 'clawfoot', 'clubfoot', 'years']
#
# If a person has tmd muscular pain lnked with fibromyalgia. What is the average age of death?
# ['tmd muscular pain lnked with fibromyalgia']
# ['muscular pain', 'fibromyalgia', 'age of death']
#
# What diseases precede other specified or unspecified dorsopathies in patients over 16 years of age during 2010?
# ['other specified or unspecified dorsopathies']
# ['years', 'age', 'diseases', 'unspecified', 'dorsopathies']
#
# Since 2003, what's the hazard ratio of other and unspecified types of non-hodgkin lymphoma given inflammatory diseases of prostate for patients from 59 to 87?How much more likely are patients from 59 to 87 to develop other and unspecified types of non-hodgkin lymphoma if they are already diagnosed with inflammatory diseases of prostate since 2003?
# ['other and unspecified types of non-hodgkin lymphoma', 'inflammatory diseases of prostate']
# ['unspecified', 'non-hodgkin lymphoma', 'non-hodgkin lymphoma', 'diagnosed', 'inflammatory diseases of prostate', 'inflammatory diseases of prostate', 'unspecified', 'likely']
#
# If the patient is a woman over the age of 35, what are the most common comorbidities associated with acquired absence of organs and not elsewhere classified in the 12 years since 2002?
# ['acquired absence of organs and not elsewhere classified']
# ['age', 'comorbidities', 'acquired absence of organs', 'years']
#
# In people less than 30 years old, how many suffer from total colectomy operation starting in 2004?
# ['total colectomy operation']
# ['operation', 'years', 'old', 'suffer', 'total colectomy']
#
# If the patient is a woman under the age of 93, what is the most common complication associated with benign neoplasm of other specified or unspecified intrathoracic organs?
# ['benign neoplasm of other specified or unspecified intrathoracic organs']
# ['complication', 'benign neoplasm', 'unspecified', 'organs', 'age']
#
# What is the most related illness given other obstetric conditions and not elsewhere classified during a 3 year interval beginning 2017 and ending 2020 if my patient is a person above 95 years old?
# ['other obstetric conditions and not elsewhere classified']
# ['related', 'illness', 'year', 'interval', 'beginning', 'years', 'ending', 'old']
#
# What diseases have women under the age of 61 diagnosed before other and unspecified mental retardation since 2005?
# ['other and unspecified mental retardation']
# ['diagnosed', 'unspecified mental retardation', 'diseases', 'age']
#
# What is the most related illness given acohol-induced acute pancreatitis during a 3 year interval beginning 2017 and ending 2020 if my patient is a person above 95 years old?
# ['acohol-induced acute pancreatitis']
# ['interval', 'acute pancreatitis', 'beginning', 'ending', 'years', 'old', 'related', 'year', 'illness']
#
# What is the hazard ratio of convergent concomitant strabismus giving a malignant neoplasm of kidney and except renal pelvis among women aged 55 to 78 years between 2005 and 2008?How much more likely is a woman aged 55 to 78 years to develop convergent concomitant strabismus if she has already been diagnosed with a malignant neoplasm of kidney and except renal pelvis between 2005 and 2008?
# ['convergent concomitant strabismus', 'malignant neoplasm of kidney and except renal pelvis']
# ['renal pelvis', 'convergent concomitant strabismus', 'renal pelvis', 'convergent concomitant strabismus', 'years', 'diagnosed', 'likely', 'malignant neoplasm of kidney', 'years', 'malignant neoplasm of kidney']
#
# Is the average age of people with gingvival huperplasia the first time since 2018?
# ['gingvival huperplasia']
# ['age', 'time']
#
# Given collapsed vertebra and not elsewhere classified, what is the strongest associated disease among men aged 7 years and older since 2016?
# ['collapsed vertebra and not elsewhere classified']
# ['associated disease', 'years', 'collapsed vertebra']
#
# On average, how old are the men who die after being diagnosed with coxarthrosis and primary and with hip surgery?
# ['coxarthrosis and primary and with hip surgery']
# ['diagnosed', 'coxarthrosis', 'primary', 'hip surgery', 'old']
#
# How many people under the age of 30 have had other and unspecified parapsoriasis since 2004?
# ['other and unspecified parapsoriasis']
# ['age', 'unspecified', 'parapsoriasis']
#
# Which diseases may be diagnosed before other and unspecified erythematous conditions in people under 84 years of age?
# ['other and unspecified erythematous conditions']
# ['unspecified', 'erythematous conditions', 'years', 'age', 'diseases', 'diagnosed']
#
# What is the hazard ratio for vasculitis limited to skin and not elsewhere classified given other injuries of upper limb and level unspecified in men from 2003 onwards?
# ['vasculitis limited to skin and not elsewhere classified', 'other injuries of upper limb and level unspecified']
# ['other injuries', 'upper limb', 'level', 'unspecified', 'vasculitis limited to skin']
#
# What is the hazard ratio for vasculitis limited to skin and not elsewhere classified given other injuries of upper limb and level unspecified in men from 2003 onwards?
# ['vasculitis limited to skin and not elsewhere classified', 'other injuries of upper limb and level unspecified']
# ['other injuries', 'upper limb', 'level', 'unspecified', 'vasculitis limited to skin']
#
# What is the most  severe complication among females given malignant neoplasm of breast and her-positive?
# ['malignant neoplasm of breast and her-positive']
# ['positive', 'severe', 'complication', 'malignant neoplasm of breast']
#
# How many people over the age of 36 have been diagnosed with malignant neoplasm of lip and oral cavity and pharynx since 2007?
# ['malignant neoplasm of lip and oral cavity and pharynx']
# ['pharynx', 'age', 'diagnosed', 'malignant neoplasm of lip', 'lip and oral cavity', 'oral cavity']
#
# From 2009 to 2014, which diseases may be diagnosed before people's other specified and unspecified disorders of choroid?
# ['other specified and unspecified disorders of choroid']
# ['diseases', 'diagnosed', 'unspecified', 'disorders', 'choroid']
#
# How likely is a patient who has already been diagnosed with a other disorders of male genital organs to develop otherand unspecified haemorrhagic conditions?
# ['otherand unspecified haemorrhagic conditions', 'other disorders of male genital organs']
# ['diagnosed', 'other disorders of male genital organs', 'unspecified haemorrhagic conditions', 'likely']
#
# What is the effect of a prior panniculitis and unspecified diagnosis on the risk of abnormal weight loss in women over 67 years of age between 2000 and 2001?
# ['abnormal weight loss', 'panniculitis and unspecified']
# ['prior', 'panniculitis', 'unspecified diagnosis', 'abnormal weight loss', 'years', 'age', 'effect']
#
# What extra risk does infective bursitis pose for men over the age of 63 who have been diagnosed with a selective deficiency of immunoglobulin a y?
# ['infective bursitis', 'selective deficiency of immunoglobulin a y']
# ['diagnosed', 'deficiency of immunoglobulin', 'immunoglobulin a', 'does', 'infective bursitis', 'age']
#
# Five years after the first diagnosis, how many women over the age of 98 die of tibial collateral bursitis?
# ['tibial collateral bursitis']
# ['years', 'diagnosis', 'age', 'tibial', 'collateral', 'bursitis']
#
# Men between the ages of 12 and 57 who have had a diagnosed flatulence and related conditions are at increased risk for dvt of lower extremities.
# ['dvt of lower extremities', 'flatulence and related conditions']
# ['diagnosed', 'flatulence and related conditions', 'increased risk', 'dvt', 'lower extremities']
#
# What is the risk ratio of lichen sclerosus et atrophicus to disorders of sclera and cornea and iris and ciliary body among people during 2002? If people were already diagnosed with a disorders of sclera and cornea and iris and ciliary body during 2002, how much more likely were they to have lichen sclerosus et atrophicus?
# ['lichen sclerosus et atrophicus', 'disorders of sclera and cornea and iris and ciliary body']
# ['diagnosed', 'disorders of sclera', 'disorders of sclera', 'likely', 'cornea', 'cornea', 'iris and ciliary body', 'lichen sclerosus et atrophicus', 'iris and ciliary body', 'lichen sclerosus et atrophicus']
#
# What is the average age of women who have died from precocious central puberty since 2006?
# ['precocious central puberty']
# ['died', 'precocious', 'central', 'puberty', 'age']
#
# In the year beginning in 2014, what are the likelihood of presence of other functional implants if 40-year-old men have been diagnosed with a other disorders involving the immune mechanism and not elsewhere classified?
# ['presence of other functional implants', 'other disorders involving the immune mechanism and not elsewhere classified']
# ['diagnosed', 'disorders involving the immune mechanism', 'year', 'implants', 'beginning', 'of presence', 'year', 'presence of other functional implants', 'old']
#
# If you have other specified and unspecified disorders of iris and ciliary body. What is the average age of death?
# ['other specified and unspecified disorders of iris and ciliary body']
# ['age of death', 'unspecified', 'disorders of iris and ciliary body']
#
# What diseases will people over 74 years old have with before dementia in alzheimer disease?
# ['dementia in alzheimer disease']
# ['alzheimer disease', 'diseases', 'years', 'old', 'dementia']
#
# How many patients over the age of 97 died five years after being diagnosed with heart failure and not strict?
# ['heart failure and not strict']
# ['heart failure', 'age', 'died', 'years', 'diagnosed']
#
# What extra risk of other specified or unspecified spondylopathies in males at 49 years old does a previous diagnosis of other and unspecified types of non-hodgkin lymphoma confer  during 2018?
# ['other specified or unspecified spondylopathies', 'other and unspecified types of non-hodgkin lymphoma']
# ['old', 'non-hodgkin lymphoma', 'does', 'unspecified', 'spondylopathies', 'previous', 'diagnosis', 'unspecified', 'years']
#
# What extra risk of other specified or unspecified spondylopathies in males at 49 years old does a previous diagnosis of other and unspecified types of non-hodgkin lymphoma confer  during 2018?
# ['other specified or unspecified spondylopathies', 'other and unspecified types of non-hodgkin lymphoma']
# ['old', 'non-hodgkin lymphoma', 'does', 'unspecified', 'spondylopathies', 'previous', 'diagnosis', 'unspecified', 'years']
#
# How many men under the age of 83 have any death since 2015?
# ['any death']
# ['age', 'death']
#
# What are the top eight complications of pneumonia derived septichemia in people over the age of 24 since 2015?
# ['pneumonia derived septichemia']
# ['pneumonia', 'age', 'complications']
#
# Frequency of diabetic patients under 92 years of age in the year starting 2012
# ['type 1 diabetes']
# ['age', 'year', 'frequency', 'diabetic', 'years']
#
# What is the most common disease diagnosed in females under the age of 6 since 2016?
# ['other specified and unspecified  disorders of eyelid']
# ['disease', 'diagnosed', 'age']
#
# What was the average age of patients who died from other diabetes and wide definition during the 12-year period beginning in 2002 and ending in 2014?
# ['other diabetes and wide definition']
# ['age', 'beginning', 'died', 'ending', 'diabetes', 'year', 'period']
#
# What diseases were diagnosed before diabetics from 2009 to 2014?
# ['phlebitis and thrombophlebitis of lower extremities and unspecified and drug-induced']
# ['diagnosed', 'diabetics', 'diseases']
#
# What diseases will people with post-traumatic wound infection and not elsewhere classified suffer from in 2003?
# ['post-traumatic wound infection and not elsewhere classified']
# ['diseases', 'post-traumatic wound infection', 'suffer']
#
# If patients between the ages of 72 and 96 have been diagnosed with a speech and linguistic disorders, how likely are they to develop horner syndrome?
# ['horner syndrome', 'speech and linguistic disorders']
# ['horner syndrome', 'diagnosed', 'speech', 'disorders', 'likely']
#
# Starting in 2019, how many people suffer from other or unspecified reactive arthropathies?
# ['other or unspecified reactive arthropathies']
# ['reactive arthropathies', 'suffer', 'unspecified']
#
# Starting in 2010, what is the average age of women who get diagnosed with alcohol withdrawal state with delirium for their first time?
# ['alcohol withdrawal state with delirium']
# ['alcohol withdrawal state', 'delirium', 'time', 'age', 'diagnosed']
#
# Prior to other and unspecified disorders of psychological development, starting in 2016, women under the age of 91 were most likely to be diagnosed with what?
# ['other and unspecified disorders of psychological development']
# ['likely', 'diagnosed', 'prior to', 'unspecified', 'disorders of psychological development', 'age']
#
# What is the hazard ratio for poisoning by medicine and drug-induced if a patient between the ages of 59 and 87 has had a postviral fatigue syndrome since 2003?How much more likely is a patient between the ages of 59 and 87 to develop poisoning by medicine and drug-induced if he or she has already been diagnosed with a postviral fatigue syndrome since 2003?
# ['poisoning by medicine and drug-induced', 'postviral fatigue syndrome']
# ['poisoning by', 'medicine', 'drug', 'diagnosed', 'medicine', 'postviral fatigue syndrome', 'postviral fatigue syndrome', 'drug', 'likely', 'poisoning by']
#
# After 2007, what extra risk of thyrotoxicosis with diffuse goitre among people under 21 years old does a previous diagnosis of acquired clawhand and clubhand and clawfoot and clubfoot confer?
# ['thyrotoxicosis with diffuse goitre', 'acquired clawhand and clubhand and clawfoot and clubfoot']
# ['clubhand', 'previous', 'clawfoot', 'clubfoot', 'diagnosis', 'thyrotoxicosis with diffuse goitre', 'acquired clawhand', 'years', 'old', 'does']
#
# What is the number of women who die ten years after being diagnosed with hyperlipidaemia and other or unspecified?
# ['hyperlipidaemia and other or unspecified']
# ['years', 'diagnosed', 'hyperlipidaemia', 'unspecified']
#
# This is a person with !!!muut tapaturmat. What are the most possible illnesses this person will get?
# ['!!!muut tapaturmat']
# ['possible', 'illnesses']
#
# Given female infertility and associated with anovulation, what are the strongest associated complications among men aged 84 years after 2006?
# ['female infertility and associated with anovulation']
# ['anovulation', 'complications', 'years', 'female infertility']
#
# How many men under the age of 83 have had dislocation and sprain and strain of joints and ligaments of shoulder girdle since 2015?
# ['dislocation and sprain and strain of joints and ligaments of shoulder girdle']
# ['age', 'shoulder girdle', 'dislocation', 'sprain', 'strain', 'joints', 'ligaments']
#
# What is the average age of women who have died from type 1 diabetes and wide definition and subgroup 1 since 2006?
# ['type 1 diabetes and wide definition and subgroup 1']
# ['type 1 diabetes', 'age', 'died']
#
# From 2019 to 2020, what is the hazard ratio for a soft tissue disorders due to malignant neoplasm of kidney and except renal pelvis in patients under 79 years of age?
# ['malignant neoplasm of kidney and except renal pelvis', 'soft tissue disorders']
# ['soft tissue disorders', 'malignant neoplasm of kidney', 'renal pelvis', 'years', 'age']
#
# What is the average age of people who survive another 5 years after a diagnosis of alzheimer disease and including avohilmo?
# ['alzheimer disease and including avohilmo']
# ['age', 'survive', 'years', 'diagnosis', 'alzheimer disease']
#
# For women with selective deficiency of immunoglobulin a y, how many years do they usually live?
# ['selective deficiency of immunoglobulin a y']
# ['usually', 'deficiency of immunoglobulin', 'immunoglobulin a', 'years']
#
# If women between the ages of 16 and 79 have been diagnosed with a melanocytic naevi and other sites or unspecified, how likely are they to develop disturbance of activity and attention?
# ['disturbance of activity and attention', 'melanocytic naevi and other sites or unspecified']
# ['likely', 'disturbance of activity and attention', 'diagnosed', 'melanocytic naevi', 'unspecified']
#
# How many people die 15 years after being diagnosed with other and unspecified disorders of vitreous body?
# ['other and unspecified disorders of vitreous body']
# ['diagnosed', 'unspecified', 'disorders of vitreous body', 'years']
#
# Before somnolence and stupor and coma, what diseases are most likely to be diagnosed in women under the age of 24?
# ['somnolence and stupor and coma']
# ['stupor', 'coma', 'likely', 'diseases', 'diagnosed', 'age', 'somnolence']
#
# What is the average age of men who die of aneurysms and operations and sah?
# ['aneurysms and operations and sah']
# ['age', 'aneurysms']
#
# What are the diagnoses of disorders of puberty and other or unspecified in men under the age of 90 in the year starting in 2012?
# ['disorders of puberty and other or unspecified']
# ['puberty', 'unspecified', 'age', 'year', 'diagnoses', 'disorders']
#
# Frequency of diabetic patients under 92 years of age in the year starting 2012
# ['allergic asthma']
# ['age', 'year', 'frequency', 'diabetic', 'years']
#
# What is the average age of men who died after a diagnosis of mental and behabioural disorders of puerperum and not classified elsewhere after 2009?
# ['mental and behabioural disorders of puerperum and not classified elsewhere']
# ['diagnosis', 'mental', 'disorders', 'age', 'died']
#
# What was the additional risk of scarlet fever in women in 2005?
# ['scarlet fever', 'hand']
# ['scarlet fever']
#
# How many patients over the age of 74 have been diagnosed with other degenarative diseases of the basal ganglia since 2020?
# ['other degenarative diseases of the basal ganglia']
# ['diagnosed', 'diseases', 'basal ganglia', 'age']
#
# How many men over 99 years old died after they diagnosed with subarachnoid haemmorrhage?
# ['subarachnoid haemmorrhage']
# ['diagnosed', 'subarachnoid', 'years', 'old', 'died']
#
# I am a male with type 2 diabetes and wide definition. What is the most likely disease this male has?
# ['type 2 diabetes and wide definition']
# ['likely', 'disease', 'type 2 diabetes']
#
# What are the most likely conditions a woman with mesial bite will get?
# ['mesial bite']
# ['likely', 'mesial', 'bite']
#
# What are the most common complications in diabetics?
# ['tracheo-bronchomalasia']
# ['complications', 'diabetics']
#
# If males over 82 years old are diagnosed with other or unspecified rheumatoid arthritis, what 6 things are they likely to suffer from in the period between 2019 and 2020?
# ['other or unspecified rheumatoid arthritis']
# ['unspecified', 'suffer', 'rheumatoid arthritis', 'period', 'years', 'old', 'diagnosed', 'likely']
#
# Starting from 2010, which diagnoses may be diagnosed before haematosalpinx or haematoma of broad ligament in females?
# ['haematosalpinx or haematoma of broad ligament']
# ['diagnosed', 'haematosalpinx', 'haematoma of broad ligament', 'diagnoses']
#
# I am a diabetic person. What are the complications that this person is likely to have?
# ['other injuries of upper limb and level unspecified']
# ['complications', 'likely', 'diabetic']
#
# 脳卒中の診断歴は、69歳から84歳までの女性が糖尿病になるリスクにどのように影響するのでしょうか？私の女性が69歳から84歳で脳卒中を患っている場合。糖尿病のリスク比はどのくらいですか？
# ['superficial injury of thorax', 'benign lipomatous neoplasm']
# []
#
# 脳卒中の診断歴は、69歳から84歳までの女性が糖尿病になるリスクにどのように影響するのでしょうか？私の女性が69歳から84歳で脳卒中を患っている場合。糖尿病のリスク比はどのくらいですか？
# ['superficial injury of thorax', 'benign lipomatous neoplasm']
# []
#
# What's the mean age of males died after the diagnosis of smoking starting from 2017?
# ['smoking']
# ['smoking starting', 'age', 'died', 'diagnosis']
#
# By 2013, what are the chances that a patient already diagnosed with toxic effect of corrosive substances will develop unspecified diabetes with neurological complications?
# ['unspecified diabetes with neurological complications', 'toxic effect of corrosive substances']
# ['diagnosed', 'toxic effect of corrosive substances', 'unspecified', 'diabetes with neurological complications']
#
# What diseases do people between the ages of 27 and 82 have before they become diabetic?
# ['death due to cardiac causes']
# ['diabetic', 'diseases']
#
# I am a diabetic. What might be my illness?
# ['other diseases caused by chlamydiae']
# ['diabetic', 'illness']
#
# How many men aged 8 to 35 years die five years after being diagnosed with speech and linguistic disorders?
# ['speech and linguistic disorders']
# ['diagnosed', 'speech', 'disorders', 'years', 'years']
#
# How many men over the age of 42 have other and unspecified intracranial injuries since 2008?
# ['other and unspecified intracranial injuries']
# ['intracranial', 'injuries', 'age', 'unspecified']
#
# In 2012, what's the hazard ratio of anxiety disorders given malignant neoplasm of kidney and except renal pelvis in females above 85 years old?How much more likely are females above 85 years old to develop anxiety disorders if they are already diagnosed with malignant neoplasm of kidney and except renal pelvis in 2012?
# ['anxiety disorders', 'malignant neoplasm of kidney and except renal pelvis']
# ['old', 'anxiety disorders', 'renal pelvis', 'anxiety disorders', 'years', 'diagnosed', 'old', 'malignant neoplasm of kidney', 'likely', 'malignant neoplasm of kidney', 'years', 'renal pelvis']
#
# My patient is a patient. What are the top 10 most associated diseases of other factor of the environment between 2003 and 2020?
# ['other factor of the environment']
# ['diseases']
#
# What is the average age of women who have died after a diagnosis of melanocytic naevi and other sites or unspecified since 2005?
# ['melanocytic naevi and other sites or unspecified']
# ['melanocytic naevi', 'unspecified', 'age', 'died', 'diagnosis']
#
# In 2000, how many people aged 97 had !!!vapaa-ajan tapaturmat?
# ['!!!vapaa-ajan tapaturmat']
# ['ajan']
#
# I am a diabetic patient. What are the diseases that this patient is likely to get?
# ['problems related to negative life events in childhood']
# ['likely', 'diabetic', 'diseases']
#
# What are the  severe comorbidities for men before 2019 given disorder of thyroid and unspecified?
# ['disorder of thyroid and unspecified']
# ['thyroid', 'unspecified', 'comorbidities', 'severe', 'disorder']
#
# I am a diabetic patient. What are the diseases that this patient is likely to get?
# ['other and unspecidied mood disorders']
# ['likely', 'diabetic', 'diseases']
#
# From 2000 to 2004, what was the average age of women who died from disorders of sclera and cornea and iris and ciliary body?
# ['disorders of sclera and cornea and iris and ciliary body']
# ['age', 'died', 'disorders of sclera', 'cornea', 'iris and ciliary body']
#
# How many people died one year after they diagnosed with !syndromata malformationum congenitarum praecipue faciem afficientia?
# ['!syndromata malformationum congenitarum praecipue faciem afficientia']
# ['died', 'one year', 'diagnosed']
#
# What are the most common diseases among people aged 90 and older who had unspecified diabetes with ophthalmic complications in the 12 years between 2007 and 2019?
# ['unspecified diabetes with ophthalmic complications']
# ['diabetes', 'ophthalmic', 'complications', 'years', 'diseases', 'unspecified']
#
# During 2001, what will be the pre-diabetic status of patients under the age of 74?
# ['complications of other internal prosthetic devices and implants and grafts']
# ['pre-diabetic', 'age']
#
# During 2010, what extra risk of bacterial infection and other or unspecified in patients under 83 years old does a previous diagnosis of primary open-angle glaucoma and strict confer?
# ['bacterial infection and other or unspecified', 'primary open-angle glaucoma and strict']
# ['unspecified', 'years', 'old', 'does', 'diagnosis', 'previous', 'primary open-angle glaucoma', 'bacterial infection']
#
# During 2010, what extra risk of bacterial infection and other or unspecified in patients under 83 years old does a previous diagnosis of primary open-angle glaucoma and strict confer?
# ['bacterial infection and other or unspecified', 'primary open-angle glaucoma and strict']
# ['unspecified', 'years', 'old', 'does', 'diagnosis', 'previous', 'primary open-angle glaucoma', 'bacterial infection']
#
# What is the number of deaths among women under 91 10 years after being diagnosed with panniculitis and unspecified?
# ['panniculitis and unspecified']
# ['panniculitis', 'unspecified', 'years', 'diagnosed']
#
# What was the average age of women who died after being diagnosed with primary open-angle glaucoma and strict in 2008?
# ['primary open-angle glaucoma and strict']
# ['age', 'died', 'diagnosed', 'primary open-angle glaucoma']
#
# What is the hazard ratio for normal-pressure hydrocephalus in people aged 19 years and older who had a mental and behabioural disorders of puerperum and not classified elsewhere during 2015?
# ['normal-pressure hydrocephalus', 'mental and behabioural disorders of puerperum and not classified elsewhere']
# ['normal-pressure hydrocephalus', 'years', 'mental', 'disorders']
#
# Typical life expectancy of women diagnosed with other insterstitial pulmonary diseases during 2013.
# ['other insterstitial pulmonary diseases']
# ['diagnosed', 'pulmonary diseases']
#
# What are the additional supplementary factors related to causes of morbidity and mortality classified elsewhere risks posed by previous alzheimer disease and including avohilmo diagnoses over the 17 years to 2018?
# ['supplementary factors related to causes of morbidity and mortality classified elsewhere', 'alzheimer disease and including avohilmo']
# ['alzheimer disease', 'diagnoses', 'years', 'supplementary factors related to causes of morbidity and mortality classified elsewhere', 'previous']
#
# How many women over the age of 22 were diagnosed with inguinal of femoral hernia and unilateral by 2005?
# ['inguinal of femoral hernia and unilateral']
# ['diagnosed', 'inguinal', 'femoral hernia', 'age']
#
# After 2008, what diseases do women over the age of 17 suffer from before femoral hernia and bilateral?
# ['femoral hernia and bilateral']
# ['age', 'suffer', 'femoral hernia', 'diseases']
#
# Which 8 conditions are most commonly diagnosed in people by 2003?
# ['other keratitis']
# ['diagnosed']
#
# Among men under age 61, how many had inflammatory disorders of male genital organs and not elsewhere classified in the two years ending in 2015?
# ['inflammatory disorders of male genital organs and not elsewhere classified']
# ['male genital organs', 'years', 'ending', 'age', 'disorders']
#
# What is the average age at which women die after a alcohol related diseases and tilastokeskus definition diagnosis since 2009?
# ['alcohol related diseases and tilastokeskus definition']
# ['alcohol', 'related', 'diseases', 'diagnosis', 'age']
#
# What is the average age of patients diagnosed with and dying from other and unspecified glaucoma by 2020?
# ['other and unspecified glaucoma']
# ['age', 'diagnosed', 'unspecified glaucoma']
#
# On average, how old are males who died of the diagnosis of melignant neoplasm of mesothelium and soft tissue?
# ['melignant neoplasm of mesothelium and soft tissue']
# ['died', 'diagnosis', 'neoplasm', 'mesothelium', 'soft tissue', 'old']
#
# What diseases can be diagnosed before men have other specified and unspecified disorders of eye and adnexa since 2006?
# ['other specified and unspecified disorders of eye and adnexa']
# ['adnexa', 'diagnosed', 'unspecified', 'disorders', 'eye', 'diseases']
#
# What is the average age of women who have died after being diagnosed with other disorders involving the immune mechanism and not elsewhere classified?
# ['other disorders involving the immune mechanism and not elsewhere classified']
# ['diagnosed', 'disorders involving the immune mechanism', 'age', 'died']
#
# What is the average age of patients who are first diagnosed with necrobiosis lipoidica and not elsewhere classified?
# ['necrobiosis lipoidica and not elsewhere classified']
# ['age', 'diagnosed', 'necrobiosis lipoidica']
#
# In 2010, how many men younger than 28 years old have been diagnosed with acquired clawhand and clubhand and clawfoot and clubfoot?
# ['acquired clawhand and clubhand and clawfoot and clubfoot']
# ['old', 'acquired clawhand', 'diagnosed', 'clubhand', 'clawfoot', 'clubfoot', 'years']
#
# How many people under the age of 96 had tmd muscular pain lnked with fibromyalgia before 2014?
# ['tmd muscular pain lnked with fibromyalgia']
# ['age', 'muscular pain', 'fibromyalgia']
#
# How many 3-year-old men die 1 year after a other specified or unspecified dorsopathies diagnosis?
# ['other specified or unspecified dorsopathies']
# ['unspecified', 'dorsopathies', 'diagnosis', 'year', 'old', 'year']
#
# How does a previous diagnosis of hyperlipidaemia and other or unspecified affect a man's risk of urethral stricture? What is the risk rate of urethral stricture if my man has a hyperlipidaemia and other or unspecified?
# ['urethral stricture', 'hyperlipidaemia and other or unspecified']
# ['hyperlipidaemia', 'previous', 'affect', 'diagnosis', 'urethral stricture', 'unspecified', 'hyperlipidaemia', 'urethral stricture', 'unspecified', 'does']
#
# During a 6 year interval beginning 2007 and ending 2013, how many men more than 72 years old are diagnosed with other and unspecified types of non-hodgkin lymphoma?
# ['other and unspecified types of non-hodgkin lymphoma']
# ['beginning', 'non-hodgkin lymphoma', 'ending', 'years', 'old', 'diagnosed', 'year', 'unspecified', 'interval']
#
# Which comorbidities may be diagnosed given acquired absence of organs and not elsewhere classified for people older than 11 years old?
# ['acquired absence of organs and not elsewhere classified']
# ['comorbidities', 'diagnosed', 'acquired absence of organs', 'years', 'old']
#
# In 2010, the average age at which women first developed total colectomy operation was 2010.
# ['total colectomy operation']
# ['age', 'total colectomy', 'operation']
#
# From 2009 to 2016, what diseases would patients have had prior to benign neoplasm of other specified or unspecified intrathoracic organs?
# ['benign neoplasm of other specified or unspecified intrathoracic organs']
# ['benign neoplasm', 'unspecified', 'organs', 'diseases', 'prior to']
#
# This is a male younger than 88 years old with endometriosis of pelvic peritoneum. What is my risk rate of having other obstetric conditions and not elsewhere classified?
# ['other obstetric conditions and not elsewhere classified', 'endometriosis of pelvic peritoneum']
# ['years', 'old', 'endometriosis of pelvic peritoneum']
#
# How many men under the age of 100 were diagnosed with other and unspecified mental retardation by 2010?
# ['other and unspecified mental retardation']
# ['age', 'diagnosed', 'unspecified mental retardation']
#
# What is the risk ratio of ocular pain to acohol-induced acute pancreatitis for people over 47?
# ['acohol-induced acute pancreatitis', 'ocular pain']
# ['ocular pain', 'acute pancreatitis']
#
# How does a prior diagnosis of other and unspecified glaucoma effect the risk of women over 67 years old developing convergent concomitant strabismus between 2000 and 2001?
# ['convergent concomitant strabismus', 'other and unspecified glaucoma']
# ['years', 'old', 'convergent concomitant strabismus', 'does', 'prior', 'unspecified glaucoma', 'diagnosis', 'effect']
#
# What diseases will be diagnosed in men under the age of 45 by 2002?
# ['postviral fatigue syndrome']
# ['diseases', 'diagnosed', 'age']
#
# If my woman is over 76, she is diagnosed with a death due to cardiac causes. Is the risk of voice disturbances high?
# ['voice disturbances', 'death due to cardiac causes']
# ['voice disturbances', 'high', 'diagnosed', 'death', 'cardiac']
#
# What's the mean age of females deceased after the diagnosis of gingvival huperplasia by 2001?
# ['gingvival huperplasia']
# ['age', 'deceased', 'diagnosis']
#
# What is the most common disease diagnosed in women over the age of 48?
# ['small plaque parapsoriasis']
# ['disease', 'diagnosed', 'age']
#
# What is the average age of men dying of collapsed vertebra and not elsewhere classified starting in 2017?
# ['collapsed vertebra and not elsewhere classified']
# ['age', 'collapsed vertebra']
#
# Prior to coxarthrosis and primary and with hip surgery, what diagnoses are most likely to be diagnosed in men above 41 years old during 2009?
# ['coxarthrosis and primary and with hip surgery']
# ['years', 'likely', 'old', 'prior to', 'coxarthrosis', 'primary', 'hip surgery', 'diagnosed', 'diagnoses']
#
# How many people under the age of 14 have other and unspecified parapsoriasis?
# ['other and unspecified parapsoriasis']
# ['age', 'unspecified', 'parapsoriasis']
#
# How will the risk of other and unspecified erythematous conditions increase in patients who have had a diagnosis of symptoms and signs involving the urinary system over the next 17 years through 2018?
# ['other and unspecified erythematous conditions', 'symptoms and signs involving the urinary system']
# ['symptoms and signs involving the urinary system', 'unspecified', 'erythematous conditions', 'diagnosis']
#
# What diagnoses will females have with before vasculitis limited to skin and not elsewhere classified?
# ['vasculitis limited to skin and not elsewhere classified']
# ['diagnoses', 'vasculitis limited to skin']
#
# What's the mean age of people deceased after the diagnosis of malignant neoplasm of breast and her-positive between 2002 and 2003?
# ['malignant neoplasm of breast and her-positive']
# ['positive', 'age', 'deceased', 'diagnosis', 'malignant neoplasm of breast']
#
# What is the average age of men who develop malignant neoplasm of lip and oral cavity and pharynx for the first time?
# ['malignant neoplasm of lip and oral cavity and pharynx']
# ['pharynx', 'time', 'age', 'malignant neoplasm of lip', 'lip and oral cavity', 'oral cavity']
#
# What is the hazard ratio for type 2 diabetes and wide definition in people under 39 years of age with cicatricial pemphigoid?
# ['cicatricial pemphigoid', 'type 2 diabetes and wide definition']
# ['cicatricial pemphigoid', 'type 2 diabetes', 'years', 'age']
#
# What other specified and unspecified disorders of choroid can be diagnosed in patients over the age of 99 by 2009?
# ['other specified and unspecified disorders of choroid']
# ['diagnosed', 'age', 'unspecified', 'disorders', 'choroid']
#
# Typical life expectancy of a person diagnosed with otherand unspecified haemorrhagic conditions.
# ['otherand unspecified haemorrhagic conditions']
# ['diagnosed', 'unspecified haemorrhagic conditions']
#
# What are the pre-diabetic diseases among men aged 54 and older in 2014-2015?
# ['abnormal weight loss']
# ['pre-diabetic', 'diseases']
#
# How many people have been diagnosed with tibial collateral bursitis since 2005?
# ['tibial collateral bursitis']
# ['diagnosed', 'tibial', 'collateral', 'bursitis']
#
# From 2016 to 2017, what was the average age of women who were first diagnosed with dvt of lower extremities?
# ['dvt of lower extremities']
# ['lower extremities', 'age', 'diagnosed', 'dvt']
#
# How many men over 99 years old died after they diagnosed with precocious central puberty?
# ['precocious central puberty']
# ['years', 'old', 'died', 'diagnosed', 'precocious', 'central', 'puberty']
#
# By 2013, how much more likely will patients be to develop other specified and unspecified disorders of iris and ciliary body if they have already been diagnosed with a aneurysms and operations and sah?
# ['other specified and unspecified disorders of iris and ciliary body', 'aneurysms and operations and sah']
# ['likely', 'unspecified', 'disorders of iris and ciliary body', 'diagnosed', 'aneurysms']
#
# By 2013, how much more likely will patients be to develop other specified and unspecified disorders of iris and ciliary body if they have already been diagnosed with a aneurysms and operations and sah?
# ['other specified and unspecified disorders of iris and ciliary body', 'aneurysms and operations and sah']
# ['likely', 'unspecified', 'disorders of iris and ciliary body', 'diagnosed', 'aneurysms']
#
# What diseases can be diagnosed before dementia in alzheimer disease in people under 84?
# ['dementia in alzheimer disease']
# ['dementia', 'alzheimer disease', 'diseases', 'diagnosed']
#
# How many women between the ages of 82 and 97 have died 10 years after being diagnosed with heart failure and not strict?
# ['heart failure and not strict']
# ['years', 'diagnosed', 'heart failure', 'died']
#
# The average age of women who were first diagnosed with other specified or unspecified spondylopathies in 2012 was 2012.
# ['other specified or unspecified spondylopathies']
# ['unspecified', 'spondylopathies', 'age', 'diagnosed']
#
# What is the number of deaths of men under 52 years of age after 5 years of any death?
# ['any death']
# ['age', 'years', 'death', 'years']
#
# What's the hazard ratio of pneumonia derived septichemia given heart failure and not strict among individuals more than 92 years old between 2017 and 2018?
# ['pneumonia derived septichemia', 'heart failure and not strict']
# ['heart failure', 'years', 'old', 'pneumonia']
#
# What's the hazard ratio of pneumonia derived septichemia given heart failure and not strict among individuals more than 92 years old between 2017 and 2018?
# ['pneumonia derived septichemia', 'heart failure and not strict']
# ['heart failure', 'years', 'old', 'pneumonia']
#
# What is the additional risk of type 1 diabetes associated with a previous diagnosis of other specified and unspecified  disorders of eyelid in men aged 44 to 76 years during 2012?
# ['type 1 diabetes', 'other specified and unspecified  disorders of eyelid']
# ['type 1 diabetes', 'diagnosis', 'unspecified', 'disorders', 'eyelid', 'years', 'previous']
#
# What is the hazard ratio for mixed and other personality disorders due to other specified and unspecified  disorders of eyelid in men aged 64 to 98 years?
# ['other specified and unspecified  disorders of eyelid', 'mixed and other personality disorders']
# ['eyelid', 'years', 'mixed and other personality disorders', 'unspecified', 'disorders']
#
# Between 2018 and 2019, which illnesses may be diagnosed before other diabetes and wide definition in males less than 38 years old?
# ['other diabetes and wide definition']
# ['diabetes', 'years', 'old', 'illnesses', 'diagnosed']
#
# Starting in 2010, what diagnoses can be made before a woman has phlebitis and thrombophlebitis of lower extremities and unspecified and drug-induced?
# ['phlebitis and thrombophlebitis of lower extremities and unspecified and drug-induced']
# ['drug', 'diagnoses', 'phlebitis and thrombophlebitis', 'thrombophlebitis of lower extremities', 'lower extremities', 'unspecified']
#
# How many women younger than 26 years old died 5 years after post-traumatic wound infection and not elsewhere classified diagnosis?
# ['post-traumatic wound infection and not elsewhere classified']
# ['died', 'years', 'post-traumatic wound infection', 'diagnosis', 'years', 'old']
#
# How many people die ten years after being diagnosed with other or unspecified reactive arthropathies?
# ['other or unspecified reactive arthropathies']
# ['reactive arthropathies', 'years', 'diagnosed', 'unspecified']
#
# What is the number of men diagnosed with alcohol withdrawal state with delirium at age 87?
# ['alcohol withdrawal state with delirium']
# ['diagnosed', 'alcohol withdrawal state', 'delirium', 'age']
#
# What diseases will diabetics under the age of 74 suffer from in 2001?
# ['other and unspecified disorders of psychological development']
# ['suffer', 'diseases', 'diabetics', 'age']
#
# How many women aged 39 to 57 died within 10 years of their poisoning by medicine and drug-induced diagnosis?
# ['poisoning by medicine and drug-induced']
# ['drug', 'diagnosis', 'died', 'years', 'poisoning by', 'medicine']
#
# What's the average age of men who get diagnosed with hyperlipidaemia and other or unspecified for their first time  during a 1 year period starting in 2016?
# ['hyperlipidaemia and other or unspecified']
# ['year', 'age', 'diagnosed', 'period', 'hyperlipidaemia', 'unspecified', 'time']
#
# How many of your patients between the ages of 66 and 98 have developed !!!muut tapaturmat since 2009?
# ['!!!muut tapaturmat']
# []
#
# What are the additional risks of arthropod-borne viral fevers and viral haemorrhagic fevers for people aged 2 to 90 between 2011 and 2016?
# ['arthropod-borne viral fevers and viral haemorrhagic fevers', 'reduction defects of lower limb']
# ['arthropod-borne viral fevers and viral haemorrhagic fevers']
#
# In 2008, what is the average age of women who get diagnosed with female infertility and associated with anovulation for their first time?
# ['female infertility and associated with anovulation']
# ['age', 'diagnosed', 'female infertility', 'anovulation', 'time']
#
# What is the average age of death for a person diagnosed with dislocation and sprain and strain of joints and ligaments of shoulder girdle?
# ['dislocation and sprain and strain of joints and ligaments of shoulder girdle']
# ['diagnosed', 'shoulder girdle', 'dislocation', 'sprain', 'strain', 'joints', 'age of death', 'ligaments']
#
# What is the hazard ratio of people with herpesviral keratitis and keratoconjunctivitis to other disorders involving the immune mechanism and not elsewhere classified during 2002?During 2002, how likely are people who have already been diagnosed with a other disorders involving the immune mechanism and not elsewhere classified to have herpesviral keratitis and keratoconjunctivitis?
# ['herpesviral keratitis and keratoconjunctivitis', 'other disorders involving the immune mechanism and not elsewhere classified']
# ['diagnosed', 'disorders involving the immune mechanism', 'herpesviral keratitis and keratoconjunctivitis', 'herpesviral keratitis and keratoconjunctivitis', 'disorders involving the immune mechanism', 'likely']
#
# What do you think people diagnosed with type 1 diabetes and wide definition and subgroup 1 will be struggling with in the period leading up to 2014?
# ['type 1 diabetes and wide definition and subgroup 1']
# ['period', 'leading', 'think', 'diagnosed', 'type 1 diabetes']
#
# What is the malignant neoplasm of kidney and except renal pelvis risk ratio for mixed conductive and sensorineural hearing loss in patients aged 59 to 87 years since 2003? If patients aged 59 to 87 years have been diagnosed with mixed conductive and sensorineural hearing loss, how likely are they to have developed malignant neoplasm of kidney and except renal pelvis since 2003?
# ['malignant neoplasm of kidney and except renal pelvis', 'mixed conductive and sensorineural hearing loss']
# ['mixed conductive and sensorineural hearing loss', 'mixed conductive and sensorineural hearing loss', 'renal pelvis', 'malignant neoplasm of kidney', 'years', 'likely', 'years', 'malignant neoplasm of kidney', 'diagnosed', 'renal pelvis']
#
# What is the most likely diagnosis I can get when I am diabetic?
# ['alzheimer disease and including avohilmo']
# ['likely', 'diagnosis', 'diabetic']
#
# How many men under the age of 37 were diagnosed with selective deficiency of immunoglobulin a y in 2007?
# ['selective deficiency of immunoglobulin a y']
# ['immunoglobulin a', 'age', 'diagnosed', 'deficiency of immunoglobulin']
#
# I am a diabetic. What are the diseases that I could get?
# ['disturbance of activity and attention']
# ['diabetic', 'diseases']
#
# How many 73 to 100 people were diagnosed with other and unspecified disorders of vitreous body between 2012 and 2013?
# ['other and unspecified disorders of vitreous body']
# ['unspecified', 'disorders of vitreous body', 'diagnosed']
#
# Frequency of people aged 22 and older with somnolence and stupor and coma by 2019
# ['somnolence and stupor and coma']
# ['somnolence', 'stupor', 'coma', 'frequency']
#
# Given aneurysms and operations and sah, what're the top nine strongest associated complications for patients over 86 years old starting in 2015?
# ['aneurysms and operations and sah']
# ['old', 'aneurysms', 'complications', 'years']
#
# In the 6-year period beginning in 2007 and ending in 2013, how many men over the age of 72 were diagnosed with disorders of puberty and other or unspecified?
# ['disorders of puberty and other or unspecified']
# ['ending', 'age', 'period', 'beginning', 'diagnosed', 'disorders', 'puberty', 'unspecified', 'year']
#
# What is the hazard ratio of allergic asthma and type 1 diabetes and wide definition and subgroup 1 in people under 71 years of age during the nine years ending in 2014?
# ['allergic asthma', 'type 1 diabetes and wide definition and subgroup 1']
# ['type 1 diabetes', 'years', 'age', 'years', 'ending', 'allergic asthma']
#
# If women under the age of 11 are diagnosed with mental and behabioural disorders of puerperum and not classified elsewhere, what are they likely to have in 2015?
# ['mental and behabioural disorders of puerperum and not classified elsewhere']
# ['diagnosed', 'mental', 'disorders', 'likely', 'age']
#
# What additional risks does a previous inhalation of gastric contents diagnosis pose to men over 63?
# ['other degenarative diseases of the basal ganglia', 'inhalation of gastric contents']
# ['inhalation of gastric contents', 'diagnosis', 'does', 'previous']
#
# My patient is a human being. What are the complications associated with giving subarachnoid haemmorrhage?
# ['subarachnoid haemmorrhage']
# ['complications', 'subarachnoid']
#
# What is the average age of men who first became diabetic?
# ['type 2 diabetes and wide definition']
# ['diabetic', 'age']
#
# What is the risk ratio of mesial bite to eustachian salpingitis and obstruction in people under 33 years of age?
# ['mesial bite', 'eustachian salpingitis and obstruction']
# ['eustachian salpingitis and obstruction', 'years', 'age', 'mesial', 'bite']
#
# Number of people over 77 who die after a tracheo-bronchomalasia diagnosis?
# ['tracheo-bronchomalasia']
# ['tracheo-', 'diagnosis']
#
# Before other or unspecified rheumatoid arthritis, what diseases are most likely to be diagnosed in an individual after 2011?
# ['other or unspecified rheumatoid arthritis']
# ['likely', 'diagnosed', 'unspecified', 'rheumatoid arthritis', 'diseases']
#
# During 2007, which diseases may be diagnosed before haematosalpinx or haematoma of broad ligament for people younger than 88 years of age?
# ['haematosalpinx or haematoma of broad ligament']
# ['years', 'age', 'diseases', 'diagnosed', 'haematosalpinx', 'haematoma of broad ligament']
#
# Prior to other injuries of upper limb and level unspecified, what diseases are most likely to be diagnosed in men over 60 in 2019-2020?
# ['other injuries of upper limb and level unspecified']
# ['diseases', 'other injuries', 'likely', 'upper limb', 'diagnosed', 'over 60', 'prior to', 'level', 'unspecified']
#
# What is the average age of men who are diagnosed with unspecified diabetes with neurological complications for the first time?
# ...
# ['unspecified', 'drug', 'drug', 'diagnoses', 'age', 'phlebitis and thrombophlebitis', 'phlebitis and thrombophlebitis', 'thrombophlebitis of lower extremities', 'thrombophlebitis of lower extremities', 'lower extremities', 'lower extremities', 'unspecified']
#
# What's the number of individuals older than 34 years old who died 5 years after being diagnosed with post-traumatic wound infection and not elsewhere classified?
# ['post-traumatic wound infection and not elsewhere classified']
# ['post-traumatic wound infection', 'years', 'old', 'died', 'years', 'diagnosed']
#
# Which diseases can be diagnosed in people with other or unspecified reactive arthropathies between 4 and 20?
# ['other or unspecified reactive arthropathies']
# ['diseases', 'diagnosed', 'unspecified', 'reactive arthropathies']
#
# In men below 83 years old, how many suffer from alcohol withdrawal state with delirium starting from 2017?
# ['alcohol withdrawal state with delirium']
# ['alcohol withdrawal state', 'delirium', 'years', 'old', 'suffer']
#
# How many women between the ages of 98 and 99 die 10 years after a other and unspecified disorders of psychological development diagnosis?
# ['other and unspecified disorders of psychological development']
# ['unspecified', 'disorders of psychological development', 'diagnosis', 'years']
#
# By 2012, what was the average age of women who were first diagnosed with poisoning by medicine and drug-induced?
# ['poisoning by medicine and drug-induced']
# ['poisoning by', 'medicine', 'drug', 'age', 'diagnosed']
#
# How many people under the age of 39 were diagnosed with hyperlipidaemia and other or unspecified before 2000?
# ['hyperlipidaemia and other or unspecified']
# ['unspecified', 'age', 'diagnosed', 'hyperlipidaemia']
#
# Prior to !!!muut tapaturmat, which conditions were men most likely to be diagnosed with between 2014 and 2018?
# ['!!!muut tapaturmat']
# ['likely', 'diagnosed', 'prior to']
#
# Frequency of diabetic patients aged 22 years and older by 2019.
# ['hypertrophy of fat pad']
# ['diabetic', 'years', 'frequency']
#
# How many men under the age of 89 died 10 years after becoming diabetic?
# ['other disorders of skin and subcutaneous tissue']
# ['diabetic', 'age', 'died', 'years']
#
# What was the average age at which women first developed female infertility and associated with anovulation over a two-year period beginning in 2000?
# ['female infertility and associated with anovulation']
# ['period', 'beginning', 'age', 'female infertility', 'anovulation', 'year']
#
# How many women under the age of 39 die from dislocation and sprain and strain of joints and ligaments of shoulder girdle?
# ['dislocation and sprain and strain of joints and ligaments of shoulder girdle']
# ['sprain', 'strain', 'joints', 'ligaments', 'shoulder girdle', 'age', 'dislocation']
#
# During 2001, what will be the pre-diabetic status of patients under the age of 74?
# ['herpesviral keratitis and keratoconjunctivitis']
# ['pre-diabetic', 'age']
#
# What is the risk of endometriosis of pelvic peritoneum in patients over 95 years of age?
# ['benign neoplasm of adrenal gland', 'endometriosis of pelvic peritoneum']
# ['endometriosis of pelvic peritoneum', 'years', 'age']
#
# How many women aged 82 to 97 years died within 10 years of their type 1 diabetes and wide definition and subgroup 1 diagnosis?
# ['type 1 diabetes and wide definition and subgroup 1']
# ['diagnosis', 'years', 'died', 'years', 'type 1 diabetes']
#
# In men, how many suffer from malignant neoplasm of kidney and except renal pelvis since 2018?
# ['malignant neoplasm of kidney and except renal pelvis']
# ['suffer', 'malignant neoplasm of kidney', 'renal pelvis']
#
# What's the mean age at the first event of alzheimer disease and including avohilmo in women before 2017?
# ['alzheimer disease and including avohilmo']
# ['event', 'alzheimer disease', 'age']
#
# What is the most common disease diagnosed in women over the age of 48?
# ['selective deficiency of immunoglobulin a y']
# ['disease', 'diagnosed', 'age']
#
# What is the average age of women who have died of other and unspecified disorders of vitreous body in the seven years since 2012?
# ['other and unspecified disorders of vitreous body']
# ['died', 'unspecified', 'disorders of vitreous body', 'years', 'age']
#
# What extra risk of generalized skin eruption due to drugs and medicaments among men does a previous diagnosis of disorder of thyroid and unspecified confer  starting from 2016?
# ['generalized skin eruption due to drugs and medicaments', 'disorder of thyroid and unspecified']
# ['unspecified', 'previous', 'diagnosis', 'disorder', 'generalized skin eruption due to drugs and medicaments', 'thyroid', 'does']
#
# What is the risk of cerebral arteritis in patients over 95 years of age?
# ['myocarditis', 'cerebral arteritis']
# ['age', 'cerebral arteritis', 'years']
#
# Frequency of diabetic patients 21 years and older starting in 2018
# ['granuloma annulare']
# ['diabetic', 'years', 'frequency']
#
# Among men under the age of 83, how many have somnolence and stupor and coma since 2017?
# ['somnolence and stupor and coma']
# ['coma', 'age', 'somnolence', 'stupor']
#
# By 2020, what will be the average age of women who develop aneurysms and operations and sah for the first time?
# ['aneurysms and operations and sah']
# ['age', 'aneurysms', 'time']
#
# What are the risk rates of collapsed vertebra and not elsewhere classified in men under 85 from 2020?
# ['other hammer toe', 'collapsed vertebra and not elsewhere classified']
# ['collapsed vertebra']
#
# What are the risk rates of collapsed vertebra and not elsewhere classified in men under 85 from 2020?
# ['other hammer toe', 'collapsed vertebra and not elsewhere classified']
# ['collapsed vertebra']
#
# From 2016 to 2020, which diseases are likely to be diagnosed before disorders of puberty and other or unspecified in people over the age of 83?
# ['disorders of puberty and other or unspecified']
# ['likely', 'diagnosed', 'disorders', 'puberty', 'unspecified', 'age', 'diseases']
#
# What are the most likely conditions a woman with mental and behabioural disorders of puerperum and not classified elsewhere will get?
# ['mental and behabioural disorders of puerperum and not classified elsewhere']
# ['disorders', 'likely', 'mental']
#
# What was the risk of other or unspecified rheumatoid arthritis among women aged 55 to 78 between 2005 and 2008? If women between the ages of 55 and 78 had been diagnosed with a other or unspecified rheumatoid arthritis between 2005 and 2008, how likely were they to develop other degenarative diseases of the basal ganglia?
# ['other degenarative diseases of the basal ganglia', 'other or unspecified rheumatoid arthritis']
# ['diseases', 'unspecified', 'basal ganglia', 'rheumatoid arthritis', 'diagnosed', 'unspecified', 'rheumatoid arthritis', 'likely']
#
# What was the risk of other or unspecified rheumatoid arthritis among women aged 55 to 78 between 2005 and 2008? If women between the ages of 55 and 78 had been diagnosed with a other or unspecified rheumatoid arthritis between 2005 and 2008, how likely were they to develop other degenarative diseases of the basal ganglia?
# ['other degenarative diseases of the basal ganglia', 'other or unspecified rheumatoid arthritis']
# ['diseases', 'unspecified', 'basal ganglia', 'rheumatoid arthritis', 'diagnosed', 'unspecified', 'rheumatoid arthritis', 'likely']
#
# In the 14 years to 2020, how many people over the age of 2 will have subarachnoid haemmorrhage?
# ['subarachnoid haemmorrhage']
# ['age', 'subarachnoid', 'years']
#
# How many women aged 82 to 97 years died within 10 years of their type 2 diabetes and wide definition diagnosis?
# ['type 2 diabetes and wide definition']
# ['years', 'died', 'years', 'type 2 diabetes', 'diagnosis']
#
# Prior to mesial bite, what is the most common diagnosis likely to be diagnosed in men between the ages of 22 and 65 from 2012?
# ['mesial bite']
# ['mesial', 'bite', 'diagnosis', 'likely', 'diagnosed', 'prior to']
#
# Starting in 2013, which conditions will females above 65 years old have with before tracheo-bronchomalasia?
# ['tracheo-bronchomalasia']
# ['years', 'old', 'tracheo-']
#
# During 2000, how many people at 97 years old suffer from other or unspecified rheumatoid arthritis?
# ['other or unspecified rheumatoid arthritis']
# ['old', 'suffer', 'unspecified', 'rheumatoid arthritis', 'years']
#
# What is the average age of women who have died from haematosalpinx or haematoma of broad ligament since 2006?
# ['haematosalpinx or haematoma of broad ligament']
# ['age', 'died', 'haematosalpinx', 'haematoma of broad ligament']
#
# How many women under the age of 43 die 10 years after a other injuries of upper limb and level unspecified diagnosis?
# ['other injuries of upper limb and level unspecified']
# ['age', 'other injuries', 'upper limb', 'level', 'unspecified diagnosis', 'years']
#
# Given unspecified diabetes with neurological complications, what were the strongest associated diseases for people under 6 years of age during the 2-year period ending in 2017?
# ['unspecified diabetes with neurological complications']
# ['unspecified', 'period', 'diabetes with neurological complications', 'ending', 'diseases', 'years', 'age', 'year']
#
# How many people over the age of 63 had death due to cardiac causes in 2009?
# ['death due to cardiac causes']
# ['age', 'death', 'cardiac']
#
# If my patient is a person over the age of 95, what are the most relevant diseases associated with speech and linguistic disorders over a 3-year period beginning in 2017 and ending in 2020?
# ['speech and linguistic disorders']
# ['period', 'beginning', 'diseases', 'ending', 'age', 'speech', 'disorders', 'year']
#
# 脳卒中の診断歴は、69歳から84歳までの女性が糖尿病になるリスクにどのように影響するのでしょうか？私の女性が69歳から84歳で脳卒中を患っている場合。糖尿病のリスク比はどのくらいですか？
# ['erosion of teeth', 'other ill-defined and unspecified causes of mortality']
# []
#
# 脳卒中の診断歴は、69歳から84歳までの女性が糖尿病になるリスクにどのように影響するのでしょうか？私の女性が69歳から84歳で脳卒中を患っている場合。糖尿病のリスク比はどのくらいですか？
# ['erosion of teeth', 'other ill-defined and unspecified causes of mortality']
# []
#
# Since 2020, what's the mean age of people who get diagnosed with other and unspecified intracranial injuries for their first time?
# ['other and unspecified intracranial injuries']
# ['diagnosed', 'unspecified', 'intracranial', 'injuries', 'age', 'time']
#
# Which diseases are most commonly diagnosed in women over the age of 48?
# ['benign lipomatous neoplasm']
# ['age', 'diseases', 'diagnosed']
#
# What is the number of patients over the age of 41 who died ten years after their diagnosis of other factor of the environment?
# ['other factor of the environment']
# ['number of patients', 'age', 'died', 'years', 'diagnosis']
#
# What's the hazard ratio of melanocytic naevi and other sites or unspecified given female infertility and associated with anovulation in individuals over 45 years old during a 7 year period starting in 2003?
# ['melanocytic naevi and other sites or unspecified', 'female infertility and associated with anovulation']
# ['female infertility', 'a 7', 'anovulation', 'melanocytic naevi', 'years', 'year', 'old', 'period', 'unspecified']
#
# What's the hazard ratio of melanocytic naevi and other sites or unspecified given female infertility and associated with anovulation in individuals over 45 years old during a 7 year period starting in 2003?
# ['melanocytic naevi and other sites or unspecified', 'female infertility and associated with anovulation']
# ['female infertility', 'a 7', 'anovulation', 'melanocytic naevi', 'years', 'year', 'old', 'period', 'unspecified']
#
# What is the average age between the diagnosis of !!!vapaa-ajan tapaturmat and death?
# ['!!!vapaa-ajan tapaturmat']
# ['age', 'diagnosis', 'ajan', 'death']
#
# What is the risk rate of wind in people under 35 in the year starting in 2019?
# ['other mosquito-borne viral fevers', 'acquired clawhand and clubhand and clawfoot and clubfoot']
# ['wind', 'year']
#
# What is the risk rate of wind in people under 35 in the year starting in 2019?
# ['other mosquito-borne viral fevers', 'acquired clawhand and clubhand and clawfoot and clubfoot']
# ['wind', 'year']
#
# How many men under the age of 19 die after five years of disorder of thyroid and unspecified?
# ['disorder of thyroid and unspecified']
# ['thyroid', 'unspecified', 'age', 'years', 'disorder']
#
# Age of initial diagnosis of other and unspecidied mood disorders in normal individuals from 2004?
# ['other and unspecidied mood disorders']
# ['initial diagnosis', 'mood disorders', 'normal', 'age']
#
# What is the average age of women who were first diagnosed with disorders of sclera and cornea and iris and ciliary body since 2008?
# ['disorders of sclera and cornea and iris and ciliary body']
# ['iris and ciliary body', 'age', 'diagnosed', 'disorders of sclera', 'cornea']
#
# This is a inhalation of gastric contents in a woman over the age of 93. Is my risk of !syndromata malformationum congenitarum praecipue faciem afficientia high?
# ['!syndromata malformationum congenitarum praecipue faciem afficientia', 'inhalation of gastric contents']
# ['age', 'high', 'inhalation of gastric contents']
#
# In the nine years since 2001, what is the average age of people diagnosed with unspecified diabetes with ophthalmic complications who have died?
# ['unspecified diabetes with ophthalmic complications']
# ['complications', 'died', 'years', 'age', 'diabetes', 'diagnosed', 'ophthalmic', 'unspecified']
#
# What is the average age of women who have died from complications of other internal prosthetic devices and implants and grafts since 2006?
# ['complications of other internal prosthetic devices and implants and grafts']
# ['implants', 'grafts', 'age', 'died', 'complications']
#
# Prior to bacterial infection and other or unspecified, what is the most common diagnosis among individuals under the age of 96 in the year 2017-2018?
# ['bacterial infection and other or unspecified']
# ['year', 'prior to', 'bacterial infection', 'unspecified', 'diagnosis', 'age']
#
# Starting from 2016, which diseases will males over 78 years old have with before panniculitis and unspecified?
# ['panniculitis and unspecified']
# ['unspecified', 'diseases', 'years', 'old', 'panniculitis']
#
# What is the number of people who die 10 years after being diagnosed with primary open-angle glaucoma and strict?
# ['primary open-angle glaucoma and strict']
# ['diagnosed', 'primary open-angle glaucoma', 'years']
#
# This is a person who is diabetic. What disease is this person most likely to get?
# ['localized skin eruption due to drugs and medicaments']
# ['likely', 'diabetic', 'disease']
#
# Before 2001, what extra risk of other insterstitial pulmonary diseases in individuals between 56 and 100 does a previous diagnosis of localized skin eruption due to drugs and medicaments confer?
# ['other insterstitial pulmonary diseases', 'localized skin eruption due to drugs and medicaments']
# ['diagnosis', 'localized skin eruption due to drugs and medicaments', 'pulmonary diseases', 'does', 'previous']
#
# How long do diabetic patients usually live?
# ['inguinal of femoral hernia and unilateral']
# ['diabetic', 'usually']
#
# Before femoral hernia and bilateral, which diseases are most likely to be diagnosed in women over 73?
# ['femoral hernia and bilateral']
# ['femoral hernia', 'diseases', 'likely', 'diagnosed']
#
# How does a previous diagnosis of postmenopausal osteoporosis with pathological fracture affect the risk of inflammatory disorders of male genital organs and not elsewhere classified in patients over the age of 89 in the two years to 2018?
# ['inflammatory disorders of male genital organs and not elsewhere classified', 'postmenopausal osteoporosis with pathological fracture']
# ['affect', 'does', 'disorders', 'years', 'male genital organs', 'previous', 'diagnosis', 'postmenopausal osteoporosis with pathological fracture', 'age']
#
# If a woman over the age of 58 is diagnosed with alcohol related diseases and tilastokeskus definition, what symptoms might she suffer from during her period?
# ['alcohol related diseases and tilastokeskus definition']
# ['related', 'diagnosed', 'diseases', 'alcohol', 'symptoms', 'suffer', 'period', 'age']
#
# How many people over the age of 40 have been diagnosed with other and unspecified glaucoma?
# ['other and unspecified glaucoma']
# ['unspecified glaucoma', 'age', 'diagnosed']

# %%
print(score, total, score/total)
# Out:
# 648 969 0.6687306501547987

# %%
data[0][0][52:77]
# Out:
# 'other postsurgical states'

# %% [markdown]
# ### Data source 1: FinnGen endpoints

# %%
with open('/Users/feiwang/Documents/Data/endpoint_list.json') as f:
    endpoint_list = json.load(f)

# %%
endpoint_list = [endpoint.lower() for endpoint in set([i[0] for i in endpoint_list] + [i[1] for i in endpoint_list])]
endpoint_list = [re.sub('\s{0,1}\(.+\)\s{0,1}',' ',i) for i in endpoint_list] # remove all the (xxx)
endpoint_list = [re.sub('benign neoplasm: ','benign neoplasm of ',i) for i in endpoint_list]
endpoint_list = [re.sub('\s{0,1}&\s{0,1}',' and ',i) for i in endpoint_list]
endpoint_list = [re.sub('\s{0,1}/\s{0,1}',' or ',i) for i in endpoint_list]
endpoint_list = [re.sub('\s{0,1}\[.+\]\s{0,1}',' ',i).strip() for i in endpoint_list] # remove all the [xxx]. Instead, add xxx as a new disease?
endpoint_list = list(set(endpoint_list)) # 2904 -> 2862
endpoint_list = [i for i in endpoint_list if len(i.split(' ')) <= 12] # 2862 -> 2814

diseases_valid = endpoint_list[:len(endpoint_list)//10]
diseases_train = endpoint_list[len(endpoint_list)//10:]

# %% [markdown]
# ### Data source 2: Phenocodes

# %%
endpoint_list = pd.read_csv('/Users/feiwang/Documents/Materials/query tool/phecode_definitions1.2.csv').phenotype.to_list()
endpoint_list = [i.lower() for i in endpoint_list] # 1866
diseases_valid = endpoint_list[:len(endpoint_list)//10]
diseases_train = endpoint_list[len(endpoint_list)//10:]

# %% [markdown]
# ### Data source 3: web_scraper script

# %%
with open('diseases.pickle', 'rb') as f:
    diseases = pickle.load(f)
# with open('drugs.pickle', 'rb') as f:
#     drugs = pickle.load(f)

# %%
len(diseases)
# Out:
# 538

# %%
diseases_valid = diseases[:len(diseases)//10]
diseases_train = diseases[len(diseases)//10:]
drugs_valid = drugs[:len(drugs)//10]
drugs_train = drugs[len(drugs)//10:]

# %% [markdown]
# ### Data source 4: Finnish version ICD10

# %%
onto = pd.read_excel('/Users/feiwang/Documents/Data/icd10_tautiluokitus_thl_08012020.xls',sheet_name='Sheet0', engine='openpyxl')
onto = [i[0].lower()+i[1:] for i in set(onto['A:Long_name'].dropna().tolist())] # 11608
diseases_valid = onto[:len(onto)//10]
diseases_train = onto[len(onto)//10:]
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/openpyxl/styles/stylesheet.py:221: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
pickle.dump(onto, open('onto.pickle', "wb" ))

# %% [markdown]
# ## Define tags for NER

# %%
tag_map = {'B': 1, 'I': 2, 'O': 3, 'X': 4}

# tag_map = {
#     'o': 0,
#     'year': 1,
#     'year_num': 2,
#     'year_num1': 3,
#     'year_num2': 4,
#     'age': 5,
#     'age_num': 6,
#     'age_num1': 7,
#     'age_num2': 8,
#     'sex = 1': 9,
#     'sex = 2': 10,
#     'endpoint': 11
# }

# %% [markdown]
# ## Setting up the conditions
# ### Sex

# %%
# sex options
# general - general questions; specific - questions for specific persons
# s - singular; p - plural; m - male; f - female
sex_general = {
    '': ['people','individuals','patients', 'kids', 'children', 'seniors', 'senior people', 'young people', 'adults', 'adolescents', 'teenagers'],
    'sex = 1': ['males', 'men', 'boys', 'old males', 'old men', 'young males', 'young men'],
    'sex = 2': ['females', 'women', 'girls', 'old females', 'old women', 'young females', 'young women']
} 

sex_specific = {
    '': ['an individual','a patient', 'a kid', 'a child', 'a senior', 'a person', 'my friend'],
    'sex = 1': ['a male', 'a man', 'a boy', 'my son', 'my husband', 'my father', 'my dad', 'my daddy', 'my grandpa', 'my grandfather', 'my male friend'],
    'sex = 2': ['a female', 'a woman', 'a girl', 'my daughter', 'my wife', 'my mother', 'my mom', 'my mommy', 'my grandma', 'my grandmother', 'my female friend']
}


def sex(specific_bool=False):
    '''
    general_specific_bool: boolean(0-general, 1-specific)
    return: string(one from sex options), list([], ['sex = 1'], ['sex = 2']), list(0,9,10)
    '''
    query = random.choice(list(sex_general.keys()))
    if specific_bool:
        question = random.choice(sex_specific[query])
    else:
        question = random.choice(sex_general[query])
    word_len = len(question.split(' '))
    query = [query] if query != '' else []
    return question, query

# %%
sex()
# Out:
# ('seniors', [])

# %% [markdown]
# ### Year

# %%
conj_year = {
    'year < ': ['before','by','ending in'],
    'year > ': ['after','since','starting from','starting in'],
    'year = ': ['during','in']
}
conj_years = ['between num1 and num2','from num1 to num2','during num1 and num2',
              'during a delta-year period starting in num1',
              'during a delta-year period ending by num2',
              'during a delta-year interval beginning num1 and ending num2']

years = list(range(2000,2021))

def year():
    '''
    return string, list, list(1,2,3,4)
    '''
    conj_type = random.choice(['', 'one point', 'two points'])
    if conj_type == 'one point':
        condition = random.choice(list(conj_year.keys()))
        conj = random.choice(conj_year[condition])
        num = random.choice(years)
        query = [condition+str(num)]
        question = conj+' '+str(num)
    elif conj_type == 'two points':
        num1 = random.choice(years)
        num2 = random.choice(years[years.index(num1)+1:])
        delta = num2 - num1
        query = ['year between '+str(num1)+' and '+str(num2)]
        conj = random.choice(conj_years)
        question = conj.replace('num1', str(num1))
        question = question.replace('num2', str(num2))
        question = question.replace('delta', str(delta))
    else:
        question, query = '',[]
    word_len = len(question.split(' '))
    return question, query

# %%
year()
# Out:
# ('since 2006', ['year > 2006'])

# %%
Here are the info for accessing the Risteys DB:

host: 35.205.171.61
database name: risteys_r8
user: feiyi
password: PW7ynadoRRDT%vKNTewi6U6^b&z*KsB)Y(uUsdbxu9!PAy637Adn$QE%!wz25kLW

# %%
from sqlalchemy import create_engine

# %%
# Here are the info for accessing the Risteys DB:
host = "35.205.171.61"
database_name = "risteys_r8"
user = "feiyi"
password = "PW7ynadoRRDT%vKNTewi6U6^b&z*KsB)Y(uUsdbxu9!PAy637Adn$QE%!wz25kLW"
engine = create_engine('postgresql://'+user+':'+password+'@'+host+'/'+database_name)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/psycopg2/__init__.py:144: UserWarning: The psycopg2 wheel package will be renamed from release 2.8; in order to keep installing from binary please use "pip install psycopg2-binary" instead. For details see: <http://initd.org/psycopg/docs/install.html#binary-install-from-pypi>.
#   """)

# %%
pd.read_sql_query(
            "SELECT count(sex) FROM phenocodes where sex = '1';",
            engine).iloc[0, :]
# Out:
# count    38
# Name: 0, dtype: int64

# %% [markdown]
# ### Age

# %%
conj_age = {
    'age < ': ['below', 'under', 'less than', 'younger than'],
    'age > ': ['above', 'over', 'more than', 'older than'],
    'age = ': ['at', 'in']
}
conj_ages = ['between num1 and num2','from num1 to num2',
            'between num1 years old and num2 years old','from num1 years old to num2 years old']
ages = list(range(0,101))

def age(special_one_point=False):
    '''
    return string, list
    '''
    if special_one_point:
        num = random.choice(ages)
        question = ' '+str(num)+'-year-old '
        query = ['age = '+str(num)]
        return question, query
    conj_type = random.choice(['', 'one point', 'two points'])
    if conj_type == 'one point':
        condition = random.choice(list(conj_age.keys()))
        conj = random.choice(conj_age[condition])
        num = random.choice(ages)
        query = [condition+str(num)]
        question = conj+' '+str(num)+random.choice([' years old', ''])
    elif conj_type == 'two points':
        num1 = random.choice(ages)
        num2 = random.choice(ages[ages.index(num1)+1:])
        query = ['year between '+str(num1)+' and '+str(num2)]
        conj = random.choice(conj_ages)
        question = conj.replace('num1', str(num1))
        question = question.replace('num2', str(num2))
    else:
        question, query = '',[]
    return question, query

# %%
age()
# Out:
# ('', [])

# %%
cut_yr = [0,1,5,15]

def get_cut_yr():
    '''
    return string - after xx years follow-up, ['cut_year = xx']
    '''
    cut = random.choice(cut_yr)
    if cut == 0:
        return '', ['cut_year = 0']
    elif cut == 1:
        ans = 'after a year follow-up' if random.random() < 0.5 else 'after one year follow-up'
        return ans, ['cut_year = 1']
    else:
        return 'after '+str(cut)+' years follow-up', ['cut_year = '+str(cut)]

# %% [markdown]
# ### make questions

# %%
questions_1 = [
    'What is the number of <sex> who are <age> diagnosed with <disease> <year>?',
    'How many <sex> <age> have been diagnosed with <disease> <year>?',
    'How many <sex> <age> are diagnosed with <disease> <year>?',
    '<year>, how many <sex> <age> have been diagnosed with <disease>?',
    '<year>, how many <sex> <age> are diagnosed with <disease>?',
    'How many <sex> <age> suffer from <disease> <year>?',
    '<year>, how many <sex> <age> suffer from <disease>?',
    'Frequency of <sex> with <disease> <age> <year>.',
    'In <sex> <age> , how many suffer from <disease> <year>?',
    'Among <sex> <age>, how many suffer from <disease> <year>?',
]


def question1():
    '''
    return string(question), list(answer)
    
 'How many women older than 70 have been diagnosed with flatulence?',
  'How many women over the age of 70 got flatulence?',
 'How many women over 70 years old suffer from flatulence?',
 *'What proportion of females over 70 have flatulence?',

 'count(*)-long_registry',
 'age > 70, endpoint = flatulence, sex = female'],
    
    Question - input: How many individuals under 78 have been diagnosed with migraine before 2005?\n
    Answer - output: count; people, migraine, 1, 78, 2000, 2005\n\n"
    '''
    sex_q, sex_a = sex()
    age_q, age_a = age()
    year_q, year_a = year()
    q = random.choice(questions_1).replace('<sex>', sex_q).replace('<age>', age_q).replace('<year>', year_q)
    q = re.sub(r'(^, )', '', q).replace('  ', ' ').capitalize()
    a = sex_a+['endpoint IN (<disease>)']+age_a+year_a
    return q, a

# %%
question1()
# Out:
# sex_q individuals age_q between 30 years old and 63 years old year_q
# ('Frequency of individuals with <disease> between 30 years old and 63 years old .',
#  ['endpoint IN (<disease>)', 'year between 30 and 63'])

# %%
questions_1 = [
    'What is the number of <sex> who are <age> diagnosed with <disease> <year>?',
    'How many <sex> <age> have been diagnosed with <disease> <year>?',
    'How many <sex> <age> are diagnosed with <disease> <year>?',
    '<year>, how many <sex> <age> have been diagnosed with <disease>?',
    '<year>, how many <sex> <age> are diagnosed with <disease>?',
    'How many <sex> <age> suffer from <disease> <year>?',
    '<year>, how many <sex> <age> suffer from <disease>?',
    'Frequency of <sex> with <disease> <age> <year>.',
    'In <sex> <age> , how many suffer from <disease> <year>?',
    'Among <sex> <age>, how many suffer from <disease> <year>?',
]


def question1():
    '''
    return string(question), list(answer)
    
 'How many women older than 70 have been diagnosed with flatulence?',
  'How many women over the age of 70 got flatulence?',
 'How many women over 70 years old suffer from flatulence?',
 *'What proportion of females over 70 have flatulence?',

 'count(*)-long_registry',
 'age > 70, endpoint = flatulence, sex = female'],
    
    Question - input: How many individuals under 78 have been diagnosed with migraine before 2005?\n
    Answer - output: count; people, migraine, 1, 78, 2000, 2005\n\n"
    '''
    sex_q, sex_a = sex()
    age_q, age_a = age()
    year_q, year_a = year()
    q = random.choice(questions_1).replace('<sex>', sex_q).replace('<age>', age_q).replace('<year>', year_q)
    q = re.sub(r'(^, )', '', q).replace('  ', ' ').capitalize()
    a = sex_a+['endpoint IN (<disease>)']+age_a+year_a
    return q, a

# %%
sex_q, sex_a = sex(True)
age_q, age_a = age(True)
re.sub(r'([a|an|my]) ', r'\1'+age_q, sex_q)

# %%
#     print('sex_q',sex_q, 'age_q', age_q, 'year_q', year_q)    
#     a = 'count(*); long_registry; '+', '.join(age_a+['endpoint = <disease>']+sex_a+year_a)
#     a = ', '.join(age_a+['endpoint IN (<disease>)']+sex_a+year_a)
# Out:
# ' 92-year-old '

# %%
input_prefix="input: "
input_suffix=" \n "
output_prefix="output: "
output_suffix=" \n\n"

# answer: ['sex', 'endpoint', 'age1', 'age2', 'year1', 'year2']

def make_data1(endpoint):
    '''
    return string(question), list(answer)

    
    Question - input: How many individuals under 78 have been diagnosed as migraine before 2005?\n
    Answer - output: count; people, migraine, 1, 78, 2000, 2005\n\n"
    '''
    sex_q, sex_a = get_sex()
    age_q, age_a = get_age()
    year_q, year_a = get_year()
    q = 'How many '+sex_q+age_q+' have been diagnosed as '+endpoint+year_q+'?'
    a = 'count; '+', '.join(sex_a+[endpoint]+age_a+year_a)
    return input_prefix+q+input_suffix+output_prefix+a+output_suffix

def make_data2(endpoint):
    '''
    return string(question), list(answer)
    
    Question - What is the prevalence of migraine among individuals over 71 from 2013 to 2017?\n
    Answer - output: prevalence; people, migraine, 71, 100, 2013, 2017\n\n"
    '''
    num = random.random() # random float 0.0 <= x < 1.0
    if num < 0.05:
        q = 'What is the prevalence of '+endpoint+'?'
        a = 'prevalence; people, '+endpoint+', 1, 100, 2000, 2020'
        return input_prefix+q+input_suffix+output_prefix+a+output_suffix
    else: 
        sex_q, sex_a = get_sex()
        age_q, age_a = get_age()
        year_q, year_a = get_year()
        q = 'What is the prevalence of '+endpoint+' among '+sex_q+age_q+year_q+'?'
        a = 'prevalence; '+', '.join(sex_a+[endpoint]+age_a+year_a)
        return input_prefix+q+input_suffix+output_prefix+a+output_suffix
    
def make_data3(endpoint):
    '''
    return string(question), list(answer)
    
    Question - What is the mean age at the first event for migraine among individuals over 71 from 2013 to 2017?\n
    Answer - output: mean age; people, migraine, 71, 100, 2013, 2017\n\n"
    '''
    num = random.random() # random float 0.0 <= x < 1.0
    if num < 0.05:
        q = 'What is the mean age at the first event for '+endpoint+'?'
        a = 'mean age; people, '+endpoint+', 1, 100, 2000, 2020'
        return input_prefix+q+input_suffix+output_prefix+a+output_suffix
    else: 
        sex_q, sex_a = get_sex()
        age_q, age_a = get_age()
        year_q, year_a = get_year()
        q = 'What is the mean age at the first event for '+endpoint+' among '+sex_q+age_q+year_q+'?'
        a = 'mean age; '+', '.join(sex_a+[endpoint]+age_a+year_a)
        return input_prefix+q+input_suffix+output_prefix+a+output_suffix

# %%
input_prefix="input: "
input_suffix=" \n "
output_prefix="output: "
output_suffix=" \n\n"

# answer: ['sex', 'endpoint', 'age1', 'age2', 'year1', 'year2']

def count_longre(endpoint):
    '''
    return string(question), list(answer)
    
 'How many women older than 70 have been diagnosed with flatulence?',
  'How many women over the age of 70 got flatulence?',
 'How many women over 70 years old suffer from flatulence?',
 *'What proportion of females over 70 have flatulence?',

 'count(*)-long_registry',
 'age > 70, endpoint = flatulence, sex = female'],
    
    Question - input: How many individuals under 78 have been diagnosed with migraine before 2005?\n
    Answer - output: count; people, migraine, 1, 78, 2000, 2005\n\n"
    '''
    sex_q, sex_a = get_sex()
    age_q, age_a = get_age()
    year_q, year_a = get_year()
    if year_q == '':
        q_list = [
            'How many '+sex_q+age_q+' have been diagnosed with '+endpoint+'?',
            'How many '+sex_q+age_q+' are diagnosed with '+endpoint+'?',
            'What is the number of '+sex_q+' who are'+age_q+' diagnosed with '+endpoint+'?',
            'How many '+sex_q+age_q+' suffer from '+endpoint+'?',
            'Frequency of '+sex_q+' with '+endpoint+age_q+'.',
            'In '+sex_q+age_q+', how many suffer from '+endpoint+'?',
        ]
    else:
        q_list = [
            'How many '+sex_q+age_q+' have been diagnosed with '+endpoint+year_q+'?',
            'How many '+sex_q+age_q+' are diagnosed with '+endpoint+year_q+'?',
            year_q.strip().capitalize()+', how many '+sex_q+age_q+' have been diagnosed with '+endpoint+'?',
            year_q.strip().capitalize()+', how many '+sex_q+age_q+' are diagnosed with '+endpoint+'?',
            'How many '+sex_q+age_q+' suffer from '+endpoint+year_q+'?',
            year_q.strip().capitalize()+', how many '+sex_q+age_q+' suffer from '+endpoint+'?',
            'Frequency of '+sex_q+' with '+endpoint+age_q+year_q+'.',
            'In '+sex_q+age_q+', how many suffer from '+endpoint+year_q+'?',
            'Among '+sex_q+age_q+', how many suffer from '+endpoint+year_q+'?'
        ]
    q = random.choice(q_list)
    a = 'count(*); long_registry; '+', '.join(age_a+['endpoint = '+endpoint]+sex_a+year_a)
    return input_prefix+q+input_suffix+output_prefix+a+output_suffix
    
def aveage_longre(endpoint):
    '''
    return string(question), list(answer)
    
    Question - What is the mean age at the first event for migraine among individuals over 71 from 2013 to 2017?\n
    Answer - output: mean age; people, migraine, 71, 100, 2013, 2017\n\n"
    '''
    num = random.random() # random float 0.0 <= x < 1.0
    bar = 'mean' if random.random() < 0.5 else 'average'
    prep = random.choice([' in ',' among ',' for '])
    if num < 0.1:
        q_list = [
            'What is the '+bar+' age at the first event for '+endpoint+'?',
            "What's the "+bar+' age at the first event for '+endpoint+'?'
        ]
        q = random.choice(q_list)
        a = 'avg(age); long_registry; endpoint='+endpoint
        return input_prefix+q+input_suffix+output_prefix+a+output_suffix
    else: 
        sex_q, sex_a = get_sex()
        year_q, year_a = get_year()
        if year_q == '':
            q_list = [
                'What is the '+bar+' age at the first event of '+endpoint+prep+sex_q+'?',
                "What's the "+bar+' age at the first event of '+endpoint+prep+sex_q+'?',
                'What is the '+bar+' age of '+sex_q+' who get diagnosed with '+endpoint+' for their 1st time?',
                "What's the "+bar+' age of '+sex_q+' who get diagnosed with '+endpoint+' for their first time?',
                'What is the '+bar+' age of '+sex_q+' with '+endpoint+' for the first time?',
                "What's the "+bar+' age of '+sex_q+' with '+endpoint+' for the 1st time?',
                'Normal '+sex_q+' age for initial '+endpoint+' diagnosis?',
                'Normal '+sex_q+' age for initial diagnosis of '+endpoint+'.',
                'For '+sex_q+' diagnosed with '+endpoint+', how old are they at first diagnosis?',
                'At what age are '+sex_q+' typically diagnosed with their first '+endpoint+'?',
                'How old on average are the '+sex_q+' diagnosed with '+endpoint+' for the 1st time?',
                'What is the '+bar+' age of women who get diagnosed with '+endpoint+' for their first time?'
            ]
        else:    
            q_list = [
                'What is the '+bar+' age at the first event of '+endpoint+prep+sex_q+year_q+'?',
                "What's the "+bar+' age at the first event of '+endpoint+prep+sex_q+year_q+'?',
                year_q.strip().capitalize()+', what is the '+bar+' age at the first event of '+endpoint+prep+sex_q+'?',
                year_q.strip().capitalize()+", what's the "+bar+' age at the first event of '+endpoint+prep+sex_q+'?',
                'What is the '+bar+' age of '+sex_q+' who get diagnosed with '+endpoint+' for their 1st time '+year_q+'?',
                "What's the "+bar+' age of '+sex_q+' who get diagnosed with '+endpoint+' for their first time '+year_q+'?',
                year_q.strip().capitalize()+', what is the '+bar+' age of '+sex_q+' who get diagnosed with '+endpoint+' for their 1st time?',
                year_q.strip().capitalize()+", what's the "+bar+' age of '+sex_q+' who get diagnosed with '+endpoint+' for their first time?',
                'What is the '+bar+' age of '+sex_q+' with '+endpoint+' for the first time '+year_q+'?',
                "What's the "+bar+' age of '+sex_q+' with '+endpoint+' for the 1st time '+year_q+'?',
                year_q.strip().capitalize()+', what is the '+bar+' age of '+sex_q+' with '+endpoint+' for the first time?',
                year_q.strip().capitalize()+", what's the "+bar+' age of '+sex_q+' with '+endpoint+' for the 1st time?',
                'Normal '+sex_q+' age for initial '+endpoint+' diagnosis '+year_q+'.',
                'Normal '+sex_q+' age for initial diagnosis of '+endpoint+year_q+'?',
                'For '+sex_q+' diagnosed with '+endpoint+', how old are they at first diagnosis '+year_q+'?',
                'At what age are '+sex_q+' typically diagnosed with their first '+endpoint+year_q+'?',
                'How old on average are the '+sex_q+' diagnosed with '+endpoint+' for the 1st time'+year_q+'?',
                year_q.strip().capitalize()+', how old on average are the '+sex_q+' diagnosed with '+endpoint+' for the 1st time?',
                'What is the '+bar+' age of women who get diagnosed with '+endpoint+' for their first time'+year_q+'?',
                "What's the "+bar+' age of women who get diagnosed with '+endpoint+' for their first time'+year_q+'?',
                year_q.strip().capitalize()+', what is the '+bar+' age of women who get diagnosed with '+endpoint+' for their first time?',
                year_q.strip().capitalize()+", what's the "+bar+' age of women who get diagnosed with '+endpoint+' for their first time?'
            ]
        q = random.choice(q_list)
        a = 'avg(age); long_registry; '+', '.join(['endpoint = '+endpoint]+sex_a+year_a)
        return input_prefix+q+input_suffix+output_prefix+a+output_suffix
    
def avgage_mortality(endpoint):
    '''
    return string(question), list(answer)
    
        'What is the average age of women who died after letrozole diagnosis?',
  'How old on average are women who died after letrozole?',
 'What is the average age of women who died after letrozole?',
 'On average, how old is a woman who died of the diagnosis of letrozole?',
  'What is the mean age of death regarding to disease?',
  'Considering disease, what is the age of death on average?',
  'What is the average age of men who died of the diagnosis of disease after five-year survival?',
  'After a five-year survival, what is the average age of men who died of disease?',
  'What is the average age of men who die of disease 5 years after their first diagnosis?',
  'For those men who died 5 years after the first event of disease, what is their mean age?',
  'On average, what is the age of men who died of the diagnosis of disease after a survival of fifteen years?',
    
    Question - What is the mean age of males who died 10 years after HIV diagnosis?\n
    Answer - output: mean age; people, migraine, 71, 100, 2013, 2017\n\n"
    '''
    num = random.random() # random float 0.0 <= x < 1.0
    bar = 'mean' if random.random() < 0.5 else 'average'

    sex_q, sex_a = get_sex()
    year_q, year_a = get_year()
    
    if num < 0.1:
        q_list = [
            'What is the '+bar+' age of death given the diagnosis of '+endpoint+'?',
            'What is the '+bar+' age of death after being diagnosed with '+endpoint+'?',
            'If one has '+endpoint+'. What is the '+bar+' age of death?'
        ]
        q = random.choice(q_list)
        a = 'avg(age); long_registry; endpoint='+endpoint
        return input_prefix+q+input_suffix+output_prefix+a+output_suffix
    else: 
        sex_q, sex_a = get_sex()
        year_q, year_a = get_year()
        if year_q == '':
            q_list = [
                bar.capitalize()+' age of death for '+sex_q+' get diagnosed with '+endpoint+'.',
                'Typical life expectancy of '+sex_q+' who get diagnosed with '+endpoint+'.',
                'On average, how old are '+sex_q+' who died of the diagnosis of '+endpoint+'?',
                'For '+sex_q+' having '+endpoint+', how many years do they normally live?',
                'For '+sex_q+' having '+endpoint+', how many years do they normally live for?',
                "After the diagnosis of "+endpoint+", what's the "+bar+" age of "+sex_q+" who survived for another 5 years?",
                'How old on average age are the '+sex_q+' who died of '+endpoint+'?',
                'What is the '+bar+' age of '+sex_q+' who deceased after the diagnosis of '+endpoint+'?',
                "What's the "+bar+' age of '+sex_q+' deceased after the diagnosis of '+endpoint+'?',
                'What is the '+bar+' age of '+sex_q+' who died of '+endpoint+'?',
                'What is the '+bar+' age of '+sex_q+' who died after the diagnosis of '+endpoint+'?',
                "What's the "+bar+' age of '+sex_q+' died after the diagnosis of '+endpoint+'?',
                "After being diagnosed with "+endpoint+", what's the "+bar+' age of '+sex_q+' who survived for another 5 years?'
            ]
        else:
            q_list = [
                bar.capitalize()+' age of death for '+sex_q+' get diagnosed with '+endpoint+year_q+'.',
                'Typical life expectancy of '+sex_q+' who get diagnosed with '+endpoint+year_q+'.',
                'On average, how old are '+sex_q+' who died of the diagnosis of '+endpoint+year_q+'?',
                'How old on average age are the '+sex_q+' who died of '+endpoint+year_q+'?',
                year_q.strip().capitalize()+', how old on average age are the '+sex_q+' who died of '+endpoint+'?',
                'What is the '+bar+' age of '+sex_q+' who deceased after the diagnosis of '+endpoint+year_q+'?',
                "What's the "+bar+' age of '+sex_q+' deceased after the diagnosis of '+endpoint+year_q+'?',
                'What is the '+bar+' age of '+sex_q+' who died of '+endpoint+year_q+'?',
                'What is the '+bar+' age of '+sex_q+' who died after the diagnosis of '+endpoint+year_q+'?',
                "What's the "+bar+' age of '+sex_q+' died after the diagnosis of '+endpoint+year_q+'?',
                year_q.strip().capitalize()+", what's the "+bar+' age of '+sex_q+' who died of '+endpoint+'?',
            ]
#     cut = random.choice(cut_yr)
#     if cut == 0:
#         q = 'What is the '+bar+' age of '+sex_q+' who died after '+endpoint+' diagnosis?'
#     elif cut == 1:
#         q = 'What is the '+bar+' age of '+sex_q+' who died '+random.choice([str(cut),'one','a'])+' year after '+endpoint+' diagnosis?'
#     else:
#         q = 'What is the '+bar+' age of '+sex_q+' who died '+str(cut)+' years after '+endpoint+' diagnosis?'
        q = random.choice(q_list)
        a = 'avg(age); mortality; '+', '.join(['endpoint = '+endpoint]+sex_a)
#         a = 'avg(age); mortality; '+', '.join(['cut_year = '+str(cut),'endpoint = '+endpoint]+sex_a)
        return input_prefix+q+input_suffix+output_prefix+a+output_suffix

def count_mortality(endpoint):
    '''
    return string(question), list(answer)
    
 'How many individuals under 72 have died 5 years after the diagnosis of nasal and breast cancer?',
 'How many people under 72 years of age died 5 years after diagnosis of sinus cancer?',
 *'Death rate of patients under 72 who were found to have nasal and sinus cancer five years earlier.',
 *'What is rate of mortality for those aged 71 years or less and had a nasal and sinus cancer diagnosis at least 5 years ago?',
 ['How many men between 20 and 21 died 5 years after they diagnosed with aciclovir?',
  'How many men aged from 20 to 21 has died 5 years after their diagnosis of aciclovir?',
  'How many men between 20 and 21 years have died 5 years after they got aciclovir?',
  'How many men between the ages of 20 and 21 die five years after being diagnosed with acetic acid?',
  'How many men from 20 to 21 years old have died after being diagnosed with acetic acid for 5 years?',
['How many women over 73 years old died 15 years after clonazepam diagnosis?',
  'How many women over 73 are dead 15 years after the diagnosis of clonazepam?',
  'How many old women over the age of 73 die 15 years after the diagnosis of Clonazepam?',
  'How many 73 years old or older grandmas died after 15 years of diagnosis of clonazepam?',
["What's the number of people below 72 years old if they died 5 years after nasal and sinus cancer diagnosis?",
  'How many people under 72 years old died after they suffered 5 years from nasal and sinus cancer?',
  'How many individuals under 72 have died 5 years after the diagnosis of nasal and breast cancer?',
  'What is the death toll of nasal and sinus cancer if these patients are younger than 72 and have survived for 5 years?',

    
    Question - How many females at 59 died 15 years after they diagnosed as asthma in 2012??\n
    Answer - output: count(*) ; motality ; endpoint = asthma , cut_year = 15 , age = 59 , year = 2012\n\n"
    '''
#     num = random.random() # random float 0.0 <= x < 1.0

    sex_q, sex_a = get_sex()
    age_q, age_a = get_age()
#     year_q, year_a = get_year()
    cut = random.choice(['0','1','5','10','15','five','ten','fifteen'])
    
    if cut == '0':
        q_list = [
            'How many '+sex_q+age_q+' died after '+endpoint+' diagnosis?',
            'How many '+sex_q+age_q+' died after they diagnosed with '+endpoint+'?',
            'How many '+sex_q+age_q+' died of '+endpoint+'?'
        ]
    elif cut == '1':
        q_list = [
            'How many '+sex_q+age_q+' died '+random.choice([cut,'one','a'])+' year after '+endpoint+' diagnosis?',
            'How many '+sex_q+age_q+' died '+random.choice([cut,'one','a'])+' year after they diagnosed with '+endpoint+'?'
        ]
    else:
        q_list = [
#             'How many '+sex_q+' with '+endpoint+' are dying '+cut+' years later, considering only those who are '+age_q+'?',
            'How many '+sex_q+age_q+' died '+cut+' years after '+endpoint+' diagnosis?',
            'How many '+sex_q+age_q+' died '+cut+' years after they diagnosed with '+endpoint+'?',
            'How many '+sex_q+age_q+' died of '+endpoint+' '+cut+' years after the first diagnosis?',
            'What was the number of '+sex_q+age_q+' who died '+cut+' years after having '+endpoint+'?',
            'What was the number of '+sex_q+age_q+' who died '+cut+' years after the diagnosis of '+endpoint+'?',
            'What is the number of '+sex_q+age_q+' who died '+cut+' years after being diagnosed with '+endpoint+'?',
            "What's the number of "+sex_q+age_q+' who died '+cut+' years after being diagnosed with '+endpoint+'?',
            'How many '+sex_q+age_q+' died after they suffered 5 years from '+endpoint+'?',
        ]
    
    q = random.choice(q_list)        
    a = 'count(*); mortality; '+', '.join(age_a+['cut_year = '+str(cut),'endpoint = '+endpoint]+sex_a)
    return input_prefix+q+input_suffix+output_prefix+a+output_suffix

def hr_cox(endpoint):
    '''
    return string(question), list(answer)
        
    Question - What is the hazard ratio of COPD given asthma after 2010?\n
    Answer - output: hr ; cox_hrs ; prior = asthma, outcome = COPD, year > 2010\n\n"
    '''
#     num = random.random() # random float 0.0 <= x < 1.0
    sex_dict = {
        'males':'male','females':'female','men':'man','women':'woman','people':'person','individuals':'person','patients':'patient'
    }

    sex_q, sex_a = get_sex()
    age_q, age_a = get_age()
    year_q, year_a = get_year()
    prior = 'stroke'#random.choice(diseases_train)
    prep = random.choice([' in ',' among ',' for '])#' in ' if random.random() < 0.5 else ' among '
    i_am_a = random.choice(['I am a ','This is a ',"I'm a "])
    
    if year_q == '':
        q_list = [
            'What is the hazard ratio of '+endpoint+' given '+prior+prep+sex_q+age_q+'?',
            "What's the hazard ratio of "+endpoint+' given '+prior+prep+sex_q+age_q+'?',
            'How much more likely are '+sex_q+age_q+' to develop '+endpoint+' if they are already diagnosed with '+prior+'?',
            'What extra risk of '+endpoint+' '+sex_q+age_q+' does a previous diagnosis of '+prior+' confer?',
            'How does a prior diagnosis of '+prior+' effect the risk of '+sex_q+age_q+' developing '+endpoint+'?'
            'If my '+sex_dict[sex_q]+' is'+age_q+' having '+prior+'. What is the risk ratio of '+endpoint+'?',
            'If my '+sex_dict[sex_q]+' is'+age_q+' diagnosed with '+prior+'. What is the risk ratio of having '+endpoint+'?',
            i_am_a+sex_dict[sex_q]+age_q+' with '+prior+'. What is my risk rate of having '+endpoint+'?',
        ]
    else:
        # What is the hazard ratio of COPD for those who had asthma after 2010?
        q_list = [
            'What is the hazard ratio of '+endpoint+' for those '+sex_q+age_q+' who had '+prior+year_q+'?',
            'What is the hazard ratio of '+endpoint+' given '+prior+prep+sex_q+age_q+year_q+'?',
            "What's the hazard ratio of "+endpoint+' given '+prior+prep+sex_q+age_q+year_q+'?',
            year_q.strip().capitalize()+", what is the hazard ratio of "+endpoint+' given '+prior+prep+sex_q+age_q+'?',
            year_q.strip().capitalize()+", what's the hazard ratio of "+endpoint+' given '+prior+prep+sex_q+age_q+'?'
            'How much more likely are '+sex_q+age_q+' to develop '+endpoint+' if they are already diagnosed with '+prior+year_q+'?',
            year_q.strip().capitalize()+', how much more likely are '+sex_q+age_q+' to develop '+endpoint+' if they are already diagnosed with '+prior+'?',
            year_q.strip().capitalize()+', what extra risk of '+endpoint+prep+sex_q+age_q+' does a previous diagnosis of '+prior+' confer?',
            'What extra risk of '+endpoint+prep+sex_q+age_q+' does a previous diagnosis of '+prior+' confer '+year_q+'?',
            'How does a prior diagnosis of '+prior+' effect the risk of '+sex_q+age_q+' developing '+endpoint+year_q+'?',
            year_q.strip().capitalize()+', how does a prior diagnosis of '+prior+' effect the risk of '+sex_q+age_q+' developing '+endpoint+'?'
        ]
        
    q = random.choice(q_list)     
    a = 'hr; cox_hrs; '+', '.join(age_a+['outcome = '+endpoint,'prior = '+prior]+sex_a+year_a)
    return input_prefix+q+input_suffix+output_prefix+a+output_suffix

def outcome_cox(endpoint):
    '''
    return string(question), list(answer)
    
    Question - Which diseases may be diagnosed after asthma for people between 25 to 65?\n
    Answer - output: hr ; cox_hrs ; prior = asthma, outcome = COPD, year > 2010\n\n"
    '''
    num = random.random() # random float 0.0 <= x < 1.0
    
    sex_dict = {
        'males':'male','females':'female','men':'man','women':'woman','people':'person','individuals':'person','patients':'patient'
    }

    sex_q, sex_a = get_sex()
    age_q, age_a = get_age()
    year_q, year_a = get_year()
    ep = random.choice(['disease','complication','comorbidity','illness','diagnosis','condition'])
    eps = random.choice(['diseases','complications','comorbidities','illnesses','diagnoses','conditions'])
    prep = random.choice([' in ',' among ',' for '])
    i_am_a = random.choice(['I am a ','This is a ',"I'm a "])
    
    if num < 0.2:
        q_list = [
            'My patient is a '+sex_dict[sex_q]+age_q+'. What is the most related '+ep+' given '+endpoint+year_q+'?',
            'What is the most related '+ep+' given '+endpoint+year_q+' if my patient is a '+sex_dict[sex_q]+age_q+'?',
            i_am_a+sex_dict[sex_q]+' with '+endpoint+'. What is the most possible '+ep+' I '+random.choice(['may','will','might'])+' get?',
            'Which '+ep+' may be diagnosed given '+endpoint+prep+sex_q+age_q+year_q+'?',
            'What is the most '+random.choice([' severe ',' possible '])+ep+prep+sex_q+age_q+year_q+' given '+endpoint+'?',
            'Given '+endpoint+', what is the strongest associated '+ep+prep+sex_q+age_q+year_q+'?',
            'Given '+endpoint+", what's the strongest associated "+ep+prep+sex_q+age_q+year_q+'?',
            'If '+sex_q+age_q+' are diagnosed with '+endpoint+', what '+ep+' are they most likely to suffer from in the period'+year_q+'?',
            'What are the most common '+ep+prep+age_q+' who had '+endpoint+year_q+'?',
            'Which '+ep+' is most commonly diagnosed'+prep+sex_q+age_q+year_q+'?',
        ]
        q = random.choice(q_list) 
        a = 'outcome; cox_hrs; '+', '.join(age_a+['prior = '+endpoint]+sex_a+year_a)+'; order by risk desc limit 1'
    elif num < 0.6:
        q_list = [
            'My patient is a '+sex_dict[sex_q]+age_q+'. What is the related '+eps+' given '+endpoint+year_q+'?',
            'What is the most related '+ep+' given '+endpoint+year_q+' if my patient is a '+sex_dict[sex_q]+age_q+year_q+'?',
            'Which '+eps+' may be diagnosed given '+endpoint+' for '+sex_q+age_q+year_q+'?',
            'What are the '+random.choice([' ',' severe ',' possible '])+eps+prep+sex_q+age_q+year_q+' given '+endpoint+'?',
            'Given '+endpoint+', what are the strongest associated '+eps+prep+sex_q+age_q+year_q+'?',
            'Given '+endpoint+", what're the strongest associated "+eps+prep+sex_q+age_q+year_q+'?',
            'If '+sex_q+age_q+' are diagnosed with '+endpoint+', what are they likely to suffer from in the period'+year_q+'?',
            'What are the most common '+eps+prep+age_q+' who had '+endpoint+year_q+'?',
            i_am_a+sex_dict[sex_q]+' with '+endpoint+'. What are the most possible '+eps+' this '+sex_dict[sex_q]+' will get?',
            'Which '+eps+' are most commonly diagnosed'+prep+sex_q+age_q+year_q+'?',
        ]
        q = random.choice(q_list) 
        a = 'outcome; cox_hrs; '+', '.join(age_a+['prior = '+endpoint]+sex_a+year_a)+'; order by risk desc limit 5'
    
    else:
        # What are the top 5 severe complications given cardiovascular diseases for men above 65?
        num_disease = random.choice([str(i) for i in range(2,11)]+['two','three','four','five','six','seven','eight','nine','ten'])
        q_list = [
            'My patient is a '+sex_dict[sex_q]+age_q+'. What is the '+num_disease+' most relevant '+eps+' given '+endpoint+year_q+'?',
            'What are the top '+num_disease+random.choice([' ',' severe ',' possible '])+eps+prep+sex_q+age_q+year_q+' given '+endpoint+'?',
            "What're the top "+num_disease+random.choice([' ',' severe ',' possible '])+eps+prep+sex_q+age_q+year_q+' given '+endpoint+'?',
            'Given '+endpoint+', what are the top '+num_disease+' strongest associated '+eps+prep+sex_q+age_q+year_q+'?',
            'Given '+endpoint+", what're the top "+num_disease+' strongest associated '+eps+prep+sex_q+age_q+year_q+'?',
            'If '+sex_q+age_q+' are diagnosed with '+endpoint+', what '+num_disease+' things are they likely to suffer from in the period'+year_q+'?',
            'What are the '+num_disease+' most common '+eps+prep+age_q+' who had '+endpoint+year_q+'?',
            i_am_a+sex_dict[sex_q]+' with '+endpoint+'. What are the '+num_disease+' most possible '+eps+' this '+sex_dict[sex_q]+' will get?',
            'Which '+num_disease+' '+eps+' are most commonly diagnosed'+prep+sex_q+age_q+year_q+'?',
        ]
        q = random.choice(q_list) 
        a = 'outcome; cox_hrs; '+', '.join(age_a+['prior = '+endpoint]+sex_a+year_a)+'; order by risk desc limit '+str(num_disease)
    
    return input_prefix+q+input_suffix+output_prefix+a+output_suffix



def prior_cox(endpoint):
    '''
    return string(question), list(answer)
     
    Question - Which diseases may be diagnosed before asthma?\n
    Answer - output: prior ; cox_hrs ; outcome = asthma ; order by risk desc limit 5\n\n"
    '''
#     num = random.random() # random float 0.0 <= x < 1.0
    ep = random.choice(['diseases','diagnoses','conditions','illnesses'])
    wh = 'what ' if random.random() < 0.5 else 'which '
    
    sex_q, sex_a = get_sex()
    age_q, age_a = get_age()
    year_q, year_a = get_year()
    
    if year_q == '':
        q_list = [
            'Prior to '+endpoint+', '+wh+ep+' are most likely to be diagnosed in '+sex_q+age_q+'?',
            wh.capitalize()+ep+' may be diagnosed before '+endpoint+' in '+sex_q+age_q+'?',
            wh.capitalize()+ep+' will '+sex_q+age_q+' have with before '+endpoint+'?',
        ]
    else:
        q_list = [
            'Prior to '+endpoint+', '+wh+ep+' are most likely to be diagnosed in '+sex_q+age_q+year_q+'?',
            wh.capitalize()+ep+' may be diagnosed before '+endpoint+' in '+sex_q+age_q+year_q+'?',
            year_q.strip().capitalize()+', '+wh+ep+' may be diagnosed before '+endpoint+' in '+sex_q+age_q+'?',
            wh.capitalize()+ep+' will '+sex_q+age_q+' have with before '+endpoint+year_q+'?',
            year_q.strip().capitalize()+', '+wh+ep+' will '+sex_q+age_q+' have with before '+endpoint+'?'
        ]
    q = random.choice(q_list)    
    a = 'prior; cox_hrs; '+', '.join(age_a+['outcome = '+endpoint]+sex_a+year_a)+'; order by risk desc limit 5'
    
    return input_prefix+q+input_suffix+output_prefix+a+output_suffix

# %%
re.findall('\d{4}','between 2001 and 2006')
# Out:
# ['2001', '2006']

# %%
# data = [make_data1(i) for i in endpoint_list]+[make_data2(i) for i in endpoint_list]+[make_data3(i) for i in endpoint_list]
# data_train = [count_longre(i) for i in diseases_train]+\
#     [aveage_longre(i) for i in diseases_train]+\
#     [avgage_mortality(i) for i in diseases_train]+\
#     [count_mortality(i) for i in diseases_train]+\
#     [hr_cox(i) for i in diseases_train]+\
#     [prior_cox(i) for i in diseases_train]
# #     [outcome_cox(i) for i in diseases_train]+\

# data_valid = [count_longre(i) for i in diseases_valid]+\
#     [aveage_longre(i) for i in diseases_valid]+\
#     [avgage_mortality(i) for i in diseases_valid]+\
#     [count_mortality(i) for i in diseases_valid]+\
#     [hr_cox(i) for i in diseases_valid]+\
#     [prior_cox(i) for i in diseases_valid]
# #     [outcome_cox(i) for i in diseases_valid]+\

# train_data= []
# for i in data_train:
#     question = re.findall('input: (.+) \\n output: ',i)[0]
#     groups = i.split('; ')
#     group1 = re.findall('output: (.+)',groups[0])[0]
#     group2 = groups[1]
#     group3 = re.sub(' \\n\\n','',groups[2])
#     train_data.append([question, group1+'-'+group2, group3])    

# valid_data = []
# for i in data_valid:
#     question = re.findall('input: (.+) \\n output: ',i)[0]
#     groups = i.split('; ')
#     group1 = re.findall('output: (.+)',groups[0])[0]
#     group2 = groups[1]
#     group3 = re.sub(' \\n\\n','',groups[2])
#     valid_data.append([question, group1+'-'+group2, group3])    
# # order desc is not included in this version

# %%
choice_list = [count_longre, aveage_longre, avgage_mortality, count_mortality, hr_cox, prior_cox, outcome_cox]
data = [random.choice(choice_list)(i) for i in ['diabetes']*700]
data = list(set(data))

structures = []
for i in data:
    question = re.findall('input: (.+) \\n output: ',i)[0]
    groups = i.split('; ')
    group1 = re.findall('output: (.+)',groups[0])[0]
    group2 = groups[1]
    group3 = re.sub(' \\n\\n','',groups[2])
    structures.append([question, group1+'-'+group2, group3])

# %%
len(structures)
# Out:
# 684

# %%
structures[:3]
# Out:
# [['How many males less than 79 years old have been diagnosed with diabetes during 2008?',
#   'count(*)-long_registry',
#   'age < 79, endpoint = diabetes, sex = male, year = 2008'],
#  ['During a 17 year period ending by 2020, how old on average age are the males who died of diabetes?',
#   'avg(age)-mortality',
#   'endpoint = diabetes, sex = male'],
#  ['Prior to diabetes, what illnesses are most likely to be diagnosed in individuals after 2011?',
#   'prior-cox_hrs',
#   'outcome = diabetes, year > 2011']]

# %%
for i in data_valid[50:55]:
    print(i)
# Out:
# input: Before 2004, what extra risk of other and unspecified parapsoriasis in women more than 61 years old does a previous diagnosis of other diseases of anus and rectum confer?
#  output: hr; cox_hrs; age > 61, outcome = other and unspecified parapsoriasis, prior = other diseases of anus and rectum, sex = female, year < 2004
#
#
# input: In 2012, how many males from 29 to 99 are diagnosed with inflammatory disorders of breast?
#  output: count(*); long_registry; age between 29 and 99, endpoint = inflammatory disorders of breast, sex = male, year = 2012
#
#
# input: What is the average age of people who get diagnosed with type 2 diabetes for their 1st time  from 2002 to 2010?
#  output: avg(age); long_registry; endpoint = type 2 diabetes, year between 2002 and 2010
#
#
# input: During 2007, how many females are diagnosed with secondary thrombocytopenia?
#  output: count(*); long_registry; endpoint = secondary thrombocytopenia, sex = female, year = 2007
#
#
# input: What extra risk of other and unspecified erythematous conditions individuals from 13 to 60 does a previous diagnosis of benign neoplasm of retina confer?
#  output: hr; cox_hrs; age between 13 and 60, outcome = other and unspecified erythematous conditions, prior = benign neoplasm of retina

# %% [markdown]
# # Data augmentation
# ## <font color='green'>Back translation

# %%
questions = [i[0] for i in structures]

# %%
import googletrans
print(googletrans.LANGUAGES)
# Out:
# {'af': 'afrikaans', 'sq': 'albanian', 'am': 'amharic', 'ar': 'arabic', 'hy': 'armenian', 'az': 'azerbaijani', 'eu': 'basque', 'be': 'belarusian', 'bn': 'bengali', 'bs': 'bosnian', 'bg': 'bulgarian', 'ca': 'catalan', 'ceb': 'cebuano', 'ny': 'chichewa', 'zh-cn': 'chinese (simplified)', 'zh-tw': 'chinese (traditional)', 'co': 'corsican', 'hr': 'croatian', 'cs': 'czech', 'da': 'danish', 'nl': 'dutch', 'en': 'english', 'eo': 'esperanto', 'et': 'estonian', 'tl': 'filipino', 'fi': 'finnish', 'fr': 'french', 'fy': 'frisian', 'gl': 'galician', 'ka': 'georgian', 'de': 'german', 'el': 'greek', 'gu': 'gujarati', 'ht': 'haitian creole', 'ha': 'hausa', 'haw': 'hawaiian', 'iw': 'hebrew', 'he': 'hebrew', 'hi': 'hindi', 'hmn': 'hmong', 'hu': 'hungarian', 'is': 'icelandic', 'ig': 'igbo', 'id': 'indonesian', 'ga': 'irish', 'it': 'italian', 'ja': 'japanese', 'jw': 'javanese', 'kn': 'kannada', 'kk': 'kazakh', 'km': 'khmer', 'ko': 'korean', 'ku': 'kurdish (kurmanji)', 'ky': 'kyrgyz', 'lo': 'lao', 'la': 'latin', 'lv': 'latvian', 'lt': 'lithuanian', 'lb': 'luxembourgish', 'mk': 'macedonian', 'mg': 'malagasy', 'ms': 'malay', 'ml': 'malayalam', 'mt': 'maltese', 'mi': 'maori', 'mr': 'marathi', 'mn': 'mongolian', 'my': 'myanmar (burmese)', 'ne': 'nepali', 'no': 'norwegian', 'or': 'odia', 'ps': 'pashto', 'fa': 'persian', 'pl': 'polish', 'pt': 'portuguese', 'pa': 'punjabi', 'ro': 'romanian', 'ru': 'russian', 'sm': 'samoan', 'gd': 'scots gaelic', 'sr': 'serbian', 'st': 'sesotho', 'sn': 'shona', 'sd': 'sindhi', 'si': 'sinhala', 'sk': 'slovak', 'sl': 'slovenian', 'so': 'somali', 'es': 'spanish', 'su': 'sundanese', 'sw': 'swahili', 'sv': 'swedish', 'tg': 'tajik', 'ta': 'tamil', 'te': 'telugu', 'th': 'thai', 'tr': 'turkish', 'uk': 'ukrainian', 'ur': 'urdu', 'ug': 'uyghur', 'uz': 'uzbek', 'vi': 'vietnamese', 'cy': 'welsh', 'xh': 'xhosa', 'yi': 'yiddish', 'yo': 'yoruba', 'zu': 'zulu'}

# %%
from googletrans import Translator
import time

# %%
def translate(sentences, src='en', dest='zh-cn'):
    translator = Translator()
    translator.raise_Exception = True
    encode, decode = [], []
    for i,t in enumerate(sentences): 
        try: 
            if (i != 0) & (i%150 == 0):
                time.sleep(5)
            encode.append(translator.translate(t, src=src, dest=dest).text)
            decode.append(translator.translate(encode[-1], src=dest, dest=src).text)
        except Exception as e: 
            print(i,e)
            break
    return encode, decode

def eur_trans(questions, dest):
    n = 0
    encodes, decodes = [], []
    while n < len(questions):
        encode_, decode_ = translate(questions[n:],dest=dest)
        encodes += encode_
        decodes += decode_
        if len(decode_) == 0:
            print('The number of quotas reaches maximum today :(')
            break
        n += len(decode_)
        print('n: ',n)
        if n < len(questions): time.sleep(20)
    print('This while loop is over.')
    return encodes, decodes

# %%
encodes_ja, decodes_ja = eur_trans(questions, 'ja')
# Out:
# 0 'NoneType' object has no attribute 'group'
# The number of quotas reaches maximum today :(
# This while loop is over.

# %%
batch_cn, batch_fr, batch_fi, batch_it, batch_ja, batch_de = [], [], [], [], [], []
for i in range(len(decode1)):
    batch_cn.append([questions[i], encode1[i], decode1[i],''])
    batch_fr.append([questions[i], encode2[i], decode2[i],''])
    batch_fi.append([questions[i], encode3[i], decode3[i],''])
    batch_it.append([questions[i], encode4[i], decode4[i],''])
    batch_ja.append([questions[i], encode5[i], decode5[i],''])
    batch_de.append([questions[i], encode6[i], decode6[i],''])

# %%
import time, re
from selenium import webdriver
from selenium.webdriver.support.ui import Select

# %%
# to initiate in terminal for the 1st time use
# xattr -d com.apple.quarantine chromedriver
driver = webdriver.Chrome('/Users/feiwang/Documents/Projects/chromedriver')

# %%
def substitute(sentence):
    return re.sub(regex,'between '+re.findall(regex,b)[0][0]+' and '+re.findall(regex,b)[0][1],sentence)

def multi_translate(sentence, src_xpath, dest_xpath, translator):
    driver.find_element_by_xpath(src_xpath).clear()
#     if check_exists_by_xpath(delete_xpath): 
#         driver.find_element_by_xpath(delete_xpath).click()
    driver.find_element_by_xpath(src_xpath).send_keys(sentence)
    try:
        if translator == 'bing': 
            time.sleep(5)
            return driver.find_element_by_xpath(dest_xpath).get_attribute('value')
        elif translator == 'deepl': 
            time.sleep(3)
            return driver.find_element_by_xpath(dest_xpath).get_attribute('value')
        else: 
            time.sleep(3)
            return driver.find_element_by_xpath(dest_xpath).text
    except NoSuchElementException:
        time.sleep(5)
        if translator in ['bing','deepl']: 
            return driver.find_element_by_xpath(dest_xpath).get_attribute('value')
        else: return driver.find_element_by_xpath(dest_xpath).text

from selenium.common.exceptions import NoSuchElementException        
def check_exists_by_xpath(xpath):
    try:
        driver.find_element_by_xpath(xpath)
    except NoSuchElementException:
        return False
    return True

# %% [markdown]
# ### Youdao translate

# %%
def youdao_trans(questions):
    youdao_link = 'https://fanyi.youdao.com/'
    trans_link = '//*[@id="langSelect"]/span'
    encode_link = '//*[@id="languageSelect"]/li[3]/a'
    decode_link = '//*[@id="languageSelect"]/li[2]/a'
    src_xpath = '//*[@id="inputOriginal"]'
    dest_xpath = '//*[@id="transTarget"]/p/span'
#     delete_xpath = '//*[@id="inputDelete"]'

    encodes_youdao = []
    
    driver.get(youdao_link)
    
    driver.find_element_by_xpath(trans_link).click()
    time.sleep(1)
    driver.find_element_by_xpath(encode_link).click()
    
    for i in tqdm.tqdm(questions):
        ans = multi_translate(i,src_xpath,dest_xpath,'youdao')
#         print(ans)
        encodes_youdao.append(ans)
#     encodes_youdao = [multi_translate(i,src_xpath,dest_xpath,delete_xpath) for i in questions]
    
#     driver.find_element_by_xpath(trans_link).click()
#     time.sleep(2)
#     driver.find_element_by_xpath(decode_link).click()
    
#     for i in tqdm.tqdm(encodes_youdao):
#         ans = multi_translate(i,src_xpath,dest_xpath,'youdao')
# #         print(ans)
#         decodes_youdao.append(ans)
# #     decodes_youdao = [multi_translate(i,src_xpath,dest_xpath,delete_xpath) for i in encodes_youdao]
    
    return encodes_youdao

# %%
encodes_youdao = encodes_youdao[:105]

# %%
res = youdao_trans(questions[105:250])
# Out:
# 100%|██████████| 145/145 [07:30<00:00,  3.11s/it]

# %% [markdown]
# ### Bing translate

# %%
bing_link = 'https://www.bing.com/translator'
encode_link = '//*[@id="tta_srcsl"]'
decode_link = '//*[@id="tta_tgtsl"]'
src_xpath = '//*[@id="tta_input_ta"]'
dest_xpath = '//*[@id="tta_output_ta"]'

driver.get(bing_link)
Select(driver.find_element_by_xpath(encode_link)).select_by_visible_text('English')
Select(driver.find_element_by_xpath(decode_link)).select_by_visible_text('Chinese Simplified')
encodes_bing = [multi_translate(i,src_xpath,dest_xpath,'bing') for i in questions]

Select(driver.find_element_by_xpath(encode_link)).select_by_visible_text('Chinese Simplified')
Select(driver.find_element_by_xpath(decode_link)).select_by_visible_text('English')
decodes_bing = [multi_translate(i,src_xpath,dest_xpath,'bing') for i in encodes_bing]

# %%
for i in range(5):#len(encodes_bing)):
    print(questions[i])
    print(encodes_bing[i])
    print(decodes_bing[i])
    print()
# Out:
# How many males less than 79 years old have been diagnosed with diabetes during 2008?
# 2008年有多少79岁以下的男性被诊断出患有糖尿病？
# How many men under the age of 79 were diagnosed with diabetes in 2008?
#
# During a 17 year period ending by 2020, how old on average age are the males who died of diabetes?
# 在截至2020年的17年期间，死于糖尿病的男性的平均年龄是多少？
# What is the average age of men who die of diabetes in the 17 years to 2020?
#
# Prior to diabetes, what illnesses are most likely to be diagnosed in individuals after 2011?
# 在糖尿病之前，2011年以后哪些疾病最有可能在个人中诊断出来？
# Before diabetes, which diseases are most likely to be diagnosed in individuals after 2011?
#
# Frequency of individuals with diabetes below 51 years old by 2016.
# 到2016年，糖尿病患者年龄在51岁以下。
# By 2016, people with diabetes are under the age of 51.
#
# Prior to diabetes, which diagnoses are most likely to be diagnosed in females over 10 years old during a 2 year period ending by 2013?
# 在糖尿病之前，在截至2013年的2年期间，10岁以上的女性最有可能被诊断出糖尿病？
# Before diabetes, women over the age of 10 were most likely to be diagnosed with diabetes in the two years to 2013.

# %% [markdown]
# ### DeepL translate

# %%
deepl_link = 'https://www.deepl.com/translator'
encode_link = '//*[@id="dl_translator"]/div[4]/div[4]/div[1]/div[1]/div/button'
encode_link_en = '//*[@id="dl_translator"]/div[4]/div[4]/div[1]/div[1]/div/div/button[7]'
encode_link_cn = '//*[@id="dl_translator"]/div[4]/div[4]/div[1]/div[1]/div/div/button[3]'
encode_link_jp = '//*[@id="dl_translator"]/div[4]/div[4]/div[1]/div[1]/div/div/button[15]'

decode_link = '//*[@id="dl_translator"]/div[4]/div[4]/div[3]/div[1]/div[2]/div[1]/button'
decode_link_cn = '//*[@id="dl_translator"]/div[4]/div[4]/div[3]/div[1]/div[2]/div[1]/div[2]/button[2]'
decode_link_en = '//*[@id="dl_translator"]/div[4]/div[4]/div[3]/div[1]/div[2]/div[1]/div[2]/button[6]'
decode_link_jp = '//*[@id="dl_translator"]/div[4]/div[4]/div[3]/div[1]/div[2]/div[1]/div[2]/button[15]'
src_xpath = '//*[@id="dl_translator"]/div[4]/div[4]/div[1]/div[2]/div[2]/textarea'
dest_xpath = '//*[@id="dl_translator"]/div[4]/div[4]/div[3]/div[3]/div[1]/textarea'

# %%
encodes_deepl, decodes_deepl = [], []

# %%
driver.get(deepl_link)

# %%
b = []
# driver.get(deepl_link)
# driver.find_element_by_xpath(encode_link).click()
# driver.find_element_by_xpath(encode_link_en).click()
# driver.find_element_by_xpath(decode_link).click()
# driver.find_element_by_xpath(decode_link_cn).click()
for i in questions1:
    b.append(multi_translate(i,src_xpath,dest_xpath,'deepl'))

# %%
encodes_deepl += b
len(encodes_deepl)
# Out:
# 100

# %%
# driver.get(deepl_link)
# driver.find_element_by_xpath(encode_link).click()
# driver.find_element_by_xpath(encode_link_jp).click()
# driver.find_element_by_xpath(decode_link).click()
# driver.find_element_by_xpath(decode_link_en).click()
b = []
for i in encodes_deepl:
    b.append(multi_translate(i,src_xpath,dest_xpath,'deepl'))
decodes_deepl += b

# %%
decodes_deepl = b 
len(decodes_deepl)
# Out:
# 100

# %%
len(encodes_deepl)
# Out:
# 100

# %%
decodes_deepl_jp1 = decodes_deepl
decodes_deepl_jp += decodes_deepl
encodes_deepl_jp1 = encodes_deepl
encodes_deepl_jp += encodes_deepl

# %%
for i in range(len(encodes_deepl)):
    print(questions1[i])
    print(encodes_deepl[i])
    print(decodes_deepl[i])
#     print(decodes_deepl_cn[i])
    print()
# Out:
# Which illnesses may be diagnosed given diabetes for men after 2010?
# 2010年以降、男性が糖尿病と診断される可能性のある病気は？
# What are the diseases that may cause men to be diagnosed with diabetes since 2010?
#
# What is the most  severe illness in people from 26 to 66 since 2020 given diabetes?
# 2020年以降、26歳から66歳までの人が糖尿病を与えられて最も重症化した病気は？
# Since 2020, what is the most severe disease given diabetes in people between the ages of 26 and 66?
#
# What are the top 2 severe illnesses in individuals over 92 years old given diabetes?
# 92歳以上で糖尿病を患っている人の重症度トップ2は？
# What are the top two severities of diabetes in people over 92 years old?
#
# My patient is a person. What is the related complications given diabetes?
# 私の患者は人です。糖尿病に伴う合併症とは？
# My patient is a person. What are the complications associated with diabetes?
#
# I'm a man with diabetes. What are the most possible conditions this man will get?
# 私は糖尿病の男性です。この男性が受ける可能性の高い条件は何ですか？
# I am a diabetic male. What are the most likely conditions that this man will receive?
#
# What is the most related condition given diabetes after 2009 if my patient is a woman at 66 years old after 2009?
# 2009年以降、66歳の女性が糖尿病になった場合、最も関連性の高い疾患は何ですか？
# Since 2009, what is the most relevant disease for a 66-year-old woman with diabetes?
#
# What is the most related comorbidity given diabetes during a 10 year interval beginning 2007 and ending 2017 if my patient is a person during a 10 year interval beginning 2007 and ending 2017?
# 私の患者が2007年から2017年までの10年間に人である場合、2007年から2017年までの10年間に糖尿病を与えられた最も関連性の高い併存疾患は何ですか？
# If my patient is a person in the decade 2007-2017, what is the most relevant comorbidity given diabetes in the decade 2007-2017?
#
# Given diabetes, what're the top two strongest associated illnesses for males older than 31 years old during a 10 year period starting in 2003?
# 糖尿病の場合、2003年からの10年間に31歳以上の男性が罹患した病気のうち、関連性の高い上位2つの病気は何か？
# In the case of diabetes, what are the top two most relevant diseases that affected men aged 31 years and older in the 10 years since 2003?
#
# My patient is a person older than 65 years old. What is the three most relevant illnesses given diabetes?
# 私の患者は65歳以上の高齢者です。糖尿病を与えられた三大疾病とは？
# My patients are older than 65 years old. What are the three major diseases given diabetes?
#
# What is the most  severe disease among individuals before 2011 given diabetes?
# 2011年に糖尿病を発症する前の人で、最も重篤な病気は何か？
# What is the most serious disease in people with pre-diabetes in 2011?
#
# I'm a woman with diabetes. What are the most possible diseases this woman will get?
# 私は糖尿病の女性です。この女性がかかる可能性の高い病気は何でしょうか？
# I am a diabetic woman. What are the diseases that this woman is most likely to get?
#
# Which diseases may be diagnosed given diabetes for males under 45 years old by 2002?
# 2002年までに45歳以下の男性で糖尿病と診断される可能性のある病気は？
# What are the diseases that may lead to a diagnosis of diabetes in men under the age of 45 by 2002?
#
# I am a male with diabetes. What are the most possible diseases this male will get?
# 糖尿病の男性です。この男性がなる可能性の高い病気は何でしょうか？
# I am a diabetic male. What are the diseases that this man is most likely to get?
#
# Given diabetes, what're the strongest associated diseases among males over 7 years old since 2016?
# 糖尿病を考えると、2016年以降、7歳以上の男性で最も強い関連疾患は何か？
# Given diabetes, what is the strongest associated disease in males aged 7 years and older since 2016?
#
# I am a patient with diabetes. What is the most possible comorbidity I will get?
# 私は糖尿病の患者です。併発する可能性の高いものは何ですか？
# I am a diabetic patient. What are the most likely complications?
#
# This is a patient with diabetes. What are the most possible diseases this patient will get?
# 糖尿病の患者さんです。この患者さんがなる可能性の高い病気は何でしょうか？
# I am a diabetic patient. What are the diseases that this patient is likely to get?
#
# What are the  diseases among patients during a 1 year interval beginning 2017 and ending 2018 given diabetes?
# 糖尿病を与えられた2017年から2018年までの1年間の間に、患者さんの中にある病気は何ですか？
# What is the disease in the patient during the year 2017-2018 given diabetes?
#
# I'm a person with diabetes. What are the most possible complications this person will get?
# 私は糖尿病の人です。この人がなる可能性の高い合併症は何ですか？
# I am a diabetic person. What are the complications that this person is likely to have?
#
# Which conditions may be diagnosed given diabetes for patients over 99 years old by 2009?
# 2009年までに99歳以上の患者さんに糖尿病と診断される可能性のある疾患は？
# What diseases are likely to result in a diagnosis of diabetes in patients over 99 years of age by 2009?
#
# What are the most common diseases for  more than 90 years old who had diabetes during a 12 year interval beginning 2007 and ending 2019?
# 2007年から2019年までの12年間に糖尿病を患った90歳以上の方に多い病気は？
# What are the most common diseases among people aged 90 and older who had diabetes in the 12 years between 2007 and 2019?
#
# If females below 11 years old are diagnosed with diabetes, what are they likely to suffer from in the period in 2015?
# 11歳以下の女性が糖尿病と診断された場合、2015年にはどのような症状に悩まされる可能性が高いですか？
# If a female under the age of 11 is diagnosed with diabetes, what symptoms are she most likely to suffer from in 2015?
#
# What're the top seven severe complications for women starting from 2000 given diabetes?
# 2000年から糖尿病を発症した女性の重篤な合併症トップ7とは？
# What are the top 7 serious complications for women with diabetes since 2000?
#
# My patient is a female at 29 years old. What is the related illnesses given diabetes?
# 患者は29歳の女性です。糖尿病を与えられた関連疾患は何ですか？
# The patient is a 29-year-old female. What are the associated diseases given diabetes mellitus?
#
# If people are diagnosed with diabetes, what are they likely to suffer from in the period before 2014?
# 糖尿病と診断された人は、2014年までの期間、どのようなことに悩んでいると思われますか？
# What do you think people diagnosed with diabetes will be struggling with in the period leading up to 2014?
#
# Given diabetes, what's the strongest associated disease for people younger than 6 years old during a 2 year period ending by 2017?
# 糖尿病を考えると、2017年までの2年間で6歳以下の人が最も強く関連する病気は何でしょうか？
# Considering diabetes, what disease is most strongly associated with people under the age of 6 in the two years leading up to 2017?
#
# I am a female with diabetes. What are the 3 most possible diseases this female will get?
# 私は糖尿病の女性です。この女性がかかる可能性の高い3つの病気は何ですか？
# I am a diabetic woman. What are the three diseases that this woman is most likely to get?
#
# If individuals between 67 and 86 are diagnosed with diabetes, what 9 things are they likely to suffer from in the period during a 1 year period starting in 2019?
# 67歳から86歳までの個人が糖尿病と診断された場合、2019年から1年間の期間に、どのような9つのことに悩まされる可能性がありますか？
# If an individual between the ages of 67 and 86 is diagnosed with diabetes, what nine things might they suffer from in the period of one year starting in 2019?
#
# If women over 58 years old are diagnosed with diabetes, what are they likely to suffer from in the period?
# 58歳以上の女性が糖尿病と診断された場合、生理中にどのような症状に悩まされる可能性があるのでしょうか？
# If a woman over the age of 58 is diagnosed with diabetes, what symptoms might she suffer from during her period?
#
# I'm a man with diabetes. What are the most possible illnesses this man will get?
# 糖尿病の男性です。この人がなる可能性の高い病気は何でしょうか？
# I am a diabetic male. What are the diseases that he is likely to get?
#
# This is a female with diabetes. What are the most possible illnesses this female will get?
# 糖尿病の女性です。この女性がかかる可能性の高い病気は何でしょうか？
# I am a diabetic woman. What are the diseases that this woman is most likely to have?
#
# What is the most related complication given diabetes during a 3 year interval beginning 2014 and ending 2017 if my patient is a man during a 3 year interval beginning 2014 and ending 2017?
# 私の患者が2014年から2017年までの3年間に男性である場合、2014年から2017年までの3年間に糖尿病を与えられた最も関連性の高い合併症は何ですか？
# If my patient is a male in the 3 years from 2014 to 2017, what is the most relevant complication given diabetes in the 3 years from 2014 to 2017?
#
# If people below 14 years old are diagnosed with diabetes, what condition are they most likely to suffer from in the period?
# 14歳以下の人が糖尿病と診断された場合、その時期に最も罹患しやすい疾患は何ですか？
# If a person under the age of 14 is diagnosed with diabetes, what disease is most likely to affect them at that age?
#
# My patient is a patient. What is the ten most relevant diseases given diabetes between 2003 and 2020?
# 私の患者は患者です。2003年から2020年にかけて、糖尿病に与えられた10大疾病とは？
# My patients are patients.What are the 10 major diseases given to diabetes between 2003 and 2020?
#
# Given diabetes, what are the top ten strongest associated complications in people starting in 2015?
# 糖尿病がある場合、2015年に開始した人の強い関連合併症のトップ10は何ですか？
# If you have diabetes, what are the top 10 strongest related complications for people starting in 2015?
#
# Given diabetes, what're the top 6 strongest associated conditions for people younger than 41 years old?
# 糖尿病がある場合、41歳以下の人が最も強い関連疾患のトップ6は何ですか？
# If you have diabetes, what are the top 6 most common related diseases that are strongest in people under the age of 41?
#
# Which illnesses may be diagnosed given diabetes for people between 4 and 20?
# 4～20歳の人が糖尿病と診断される可能性のある病気は？
# What diseases can cause a person between the ages of 4 and 20 to be diagnosed with diabetes?
#
# Given diabetes, what are the strongest associated illnesses among people over 42 years old after 2010?
# 糖尿病がある場合、2010年以降、42歳以上の人で最も関連性の高い病気は何ですか？
# If you have diabetes, what is the most relevant disease in people aged 42 and older since 2010?
#
# Which illnesses may be diagnosed given diabetes for men younger than 79 years old during a 7 year period starting in 2012?
# 2012年からの7年間で、79歳以下の男性が糖尿病と診断される可能性のある病気は？
# In the seven years since 2012, what diseases are most likely to result in a diagnosis of diabetes in men under 79?
#
# What are the  severe comorbidities for men before 2019 given diabetes?
# 2019年に糖尿病を発症する前の男性の重篤な併発疾患は？
# What are the most serious co-morbidities in men with prediabetes in 2019?
#
# Given diabetes, what are the top five strongest associated comorbidities in men from 84 to 89 since 2015?
# 糖尿病を考えると、2015年以降、84歳から89歳までの男性で最も強い関連合併症のトップ5は何か？
# Given diabetes, what are the top five strongest associated complications in men aged 84 to 89 years since 2015?
#
# If females are diagnosed with diabetes, what are they likely to suffer from in the period during a 14 year period starting in 2003?
# 女性が糖尿病と診断された場合、2003年から14年間の期間で、どのような症状に悩まされる可能性がありますか？
# If a woman is diagnosed with diabetes, what symptoms might she suffer from over a period of 14 years from 2003?
#
# Given diabetes, what's the strongest associated condition among females over 42 years old during a 1 year interval beginning 2018 and ending 2019?
# 糖尿病を考えると、2018年から2019年までの1年間に42歳以上の女性で最も強い関連疾患は何か？
# Considering diabetes, what is the strongest associated disease among women aged 42 and older in the year 2018-2019?
#
# What are the top eight possible complications in individuals above 24 years old since 2015 given diabetes?
# 2015年以降、糖尿病を発症した24歳以上の人が考えられる合併症のトップ8は？
# What are the top 8 possible complications for people over the age of 24 who have developed diabetes since 2015?
#
# This is a person with diabetes. What are the most possible diagnoses this person will get?
# これは、糖尿病の人です。この人が受ける可能性のある診断は何でしょうか？
# This is a person who is diabetic. What is the possible diagnosis that this person may receive?
#
# What is the most related diagnosis given diabetes during a 2 year period ending by 2016 if my patient is a person below 50 years old during a 2 year period ending by 2016?
# 2016年までの2年間に50歳以下の人が糖尿病と診断された場合、最も関連性の高い診断は何ですか？
# What is the most relevant diagnosis of diabetes for people under the age of 50 in the two years leading up to 2016?
#
# This is a patient with diabetes. What are the 7 most possible diagnoses this patient will get?
# これは、糖尿病の患者さんです。この患者さんが受ける可能性の高い7つの診断は何でしょうか？
# This is a patient with diabetes mellitus. What are the seven diagnoses that this patient is likely to receive?
#
# What are the most common complications for  who had diabetes?
# 糖尿病を患っていた人に多い合併症とは？
# What are the most common complications for people who have had diabetes?
#
# What is the most  severe complication among females given diabetes?
# 糖尿病を患っている女性の中で、最も重篤な合併症は何ですか？
# What are the most serious complications among women with diabetes?
#
# I'm a female with diabetes. What are the most possible conditions this female will get?
# 私は糖尿病の女性です。この女性が受ける可能性の高い症状は何でしょうか？
# I am a diabetic woman. What are the symptoms that this woman is likely to get?
#
# What is the most related illness given diabetes if my patient is a person at 52 years old?
# 患者が52歳の場合、糖尿病と最も関係のある病気は何でしょうか？
# If a patient is 52 years old, what disease is most associated with diabetes?
#
# Given diabetes, what're the top three strongest associated complications for men after 2001?
# 糖尿病の場合、2001年以降の男性の合併症のトップ3は何ですか？
# If you have diabetes, what are the top three complications for men since 2001?
#
# Given diabetes, what are the top 10 strongest associated complications in males at 84 years old after 2006?
# 糖尿病がある場合、2006年以降、84歳の男性で最も強い関連合併症のトップ10は何か？
# If you have diabetes, what are the top 10 strongest associated complications in 84-year-old men since 2006?
#
# What're the top seven diseases among females over 57 years old since 2017 given diabetes?
# 2017年以降、57歳以上の女性が糖尿病を発症した病気のトップ7は？
# What are the top 7 diseases that have caused diabetes in women aged 57 and older since 2017?
#
# My patient is a man. What is the four most relevant diseases given diabetes between 2000 and 2009?
# 私の患者は男性です。2000年から2009年の間に糖尿病を与えられた4つの最も関連性の高い病気は何ですか？
# My patient is male. what are the 4 most relevant diseases given diabetes between 2000 and 2009?
#
# What are the most common comorbidity among  older than 18 years old who had diabetes during 2018?
# 2018年中に糖尿病を患った18歳以上の高齢者に最も多い併存疾患は何ですか？
# What are the most common comorbidities among older adults 18 years and older who had diabetes during 2018?
#
# Which comorbidities may be diagnosed given diabetes for individuals below 66 years old?
# 66歳以下の人が糖尿病と診断される可能性のある併存疾患は？
# What comorbidities may lead to a diagnosis of diabetes in people under 66 years of age?
#
# What are the most common diseases among  who had diabetes during a 8 year interval beginning 2009 and ending 2017?
# 2009年から2017年までの8年間に糖尿病を患った人の中で、最も多い病気は？
# What is the most common disease among people with diabetes in the eight years from 2009 to 2017?
#
# What are the  possible diseases among men more than 79 years old given diabetes?
# 79歳以上の男性で糖尿病を患っている場合、どのような病気が考えられますか？
# If you are a man over the age of 79 and have diabetes, what are the possible diseases?
#
# If individuals at 90 years old are diagnosed with diabetes, what complication are they most likely to suffer from in the period by 2017?
# 90歳の人が糖尿病と診断された場合、2017年までの期間にどのような合併症が発生する可能性が高いですか？
# If a 90-year-old person is diagnosed with diabetes, what complications are likely to occur in the period up to 2017?
#
# If males over 82 years old are diagnosed with diabetes, what 6 things are they likely to suffer from in the period between 2019 and 2020?
# 82歳以上の男性が糖尿病と診断された場合、2019年から2020年の間に、どのような6つのことに悩まされる可能性がありますか？
# If a man over the age of 82 is diagnosed with diabetes, what six things might he suffer from between 2019 and 2020?
#
# Given diabetes, what are the strongest associated diseases for males more than 89 years old?
# 糖尿病がある場合、89歳以上の男性で最も強い関連疾患は何か？
# If diabetes mellitus is present, what is the strongest associated disease in men over 89 years of age?
#
# Which diagnoses may be diagnosed given diabetes for individuals from 20 to 34 starting in 2005?
# 2005年から20歳から34歳までの人を対象に、糖尿病と診断される可能性のある診断は？
# Since 2005, people between the ages of 20 and 34 have been asked what diagnosis they might have of diabetes.
#
# If males under 67 years old are diagnosed with diabetes, what comorbidity are they most likely to suffer from in the period after 2018?
# 67歳以下の男性が糖尿病と診断された場合、2018年以降の期間に最も罹患しやすい併存疾患は何ですか？
# If a man under the age of 67 is diagnosed with diabetes, what comorbidities are most likely to affect him in 2018 and beyond?
#
# What are the two most common diseases for  at 26 years old who had diabetes?
# 26歳で糖尿病になった人に多い2つの病気とは？
# What are the two most common diseases in people with diabetes at age 26?
#
# I am a person with diabetes. What is the most possible disease I might get?
# 私は糖尿病を患っている者です。私がかかる可能性のある病気は何ですか？
# I am a diabetic. What are the diseases that I could get?
#
# Given diabetes, what're the top nine strongest associated complications for patients over 86 years old starting in 2015?
# 糖尿病がある場合、2015年から86歳以上の患者さんに最も強く関連する合併症のトップ9は何ですか？
# If you have diabetes, what are the top 9 complications most strongly associated with patients age 86 and older since 2015?
#
# What are the  severe diseases in men at 83 years old during 2001 given diabetes?
# 2001年に糖尿病を発症した83歳の男性の重篤な疾患は？
# What is the serious disease of an 83-year-old man who developed diabetes in 2001?
#
# My patient is a person. What is the six most relevant conditions given diabetes?
# 私の患者は人です。糖尿病に与えられた6つの条件とは？
# My patients are people. What are the six conditions given to diabetes?
#
# Which comorbidities may be diagnosed given diabetes for males at 51 years old?
# 51歳の男性で糖尿病と診断される可能性のある併存疾患は？
# What are the comorbidities that may lead to a diagnosis of diabetes in a 51-year-old man?
#
# Which disease is most commonly diagnosed among women under 6 years old starting in 2016?
# 2016年から6歳以下の女性に最も多く診断されている病気は？
# What is the most common disease diagnosed in females under the age of 6 since 2016?
#
# What're the top 6 possible diseases in patients under 52 years old starting in 2006 given diabetes?
# 2006年に糖尿病を発症した52歳以下の患者さんで考えられる病気のトップ6は？
# What are the top 6 possible diseases in patients under 52 years old who developed diabetes in 2006?
#
# What is the most related comorbidity given diabetes during a 12 year period starting in 2002 if my patient is a female older than 35 years old?
# 患者が35歳以上の女性の場合、2002年からの12年間に糖尿病に最も関連する併発疾患は何ですか？
# If the patient is a woman over the age of 35, what are the most common comorbidities associated with diabetes in the 12 years since 2002?
#
# If females are diagnosed with diabetes, what are they likely to suffer from in the period?
# 女性が糖尿病と診断された場合、生理中はどのようなことに悩まされるのでしょうか？
# If a woman is diagnosed with diabetes, what does she have to worry about during her period?
#
# Which 4 illnesses are most commonly diagnosed in people older than 87 years old between 2018 and 2020?
# 2018年から2020年にかけて、87歳以上の高齢者で診断されることが多い4つの病気は？
# What are the four most common diseases diagnosed in people aged 87 and older between 2018 and 2020?
#
# If males more than 48 years old are diagnosed with diabetes, what are they likely to suffer from in the period during 2009?
# 48歳以上の男性が糖尿病と診断された場合、2009年の間にどのような症状が出る可能性がありますか？
# If a man over the age of 48 is diagnosed with diabetes, what symptoms might he experience during the year 2009?
#
# Which 8 conditions are most commonly diagnosed in people by 2003?
# 2003年までに最も多くの人に診断されている8つの疾患は？
# What are the eight most commonly diagnosed diseases by 2003?
#
# What are the most common diagnosis for  who had diabetes?
# 糖尿病を患っていた人に多い診断名を教えてください。
# What are the most common diagnoses for people who have had diabetes?
#
# What is the most related comorbidity given diabetes from 2012 to 2016 if my patient is a woman from 2012 to 2016?
# 私の患者が2012年から2016年に女性である場合、糖尿病を与えられた最も関連性の高い併存疾患は何ですか？
# If my patient is a woman from 2012-2016, what is the most relevant comorbidity given diabetes?
#
# Which diseases are most commonly diagnosed for women over 48 years old?
# 48歳以上の女性に最も多く診断される病気は？
# What is the most common disease diagnosed in women over the age of 48?
#
# I'm a patient with diabetes. What is the most possible diagnosis I might get?
# 私は糖尿病の患者です。私が受ける可能性のある診断は何ですか？
# I am a diabetic patient. What are the possible diagnoses I may receive?
#
# What are the most common illness in  at 65 years old who had diabetes starting from 2014?
# 2014年から糖尿病になった65歳の方に多い病気は何ですか？
# What is the most common disease among 65 year olds with diabetes since 2014?
#
# This is a person with diabetes. What are the most possible illnesses this person will get?
# これは、糖尿病の人です。この人がなる可能性の高い病気は何でしょうか？
# This is a person who is diabetic. What disease is this person most likely to get?
#
# If males older than 76 years old are diagnosed with diabetes, what are they likely to suffer from in the period since 2012?
# 76歳以上の男性が糖尿病と診断された場合、2012年以降はどのような症状に悩まされる可能性が高いですか？
# If a man over the age of 76 is diagnosed with diabetes, what are the symptoms he is likely to suffer from in 2012 and beyond?
#
# Which five complications are most commonly diagnosed in individuals from 32 to 100 during a 11 year period starting in 2008?
# 2008年からの11年間に、32歳から100歳までの人に最も多く診断された5つの合併症は？
# In the 11 years since 2008, what were the five most commonly diagnosed complications in people between the ages of 32 and 100?
#
# My patient is a person from 99 to 100. What is the related conditions given diabetes from 2003 to 2004?
# 私の患者は99から100までの人です。2003年から2004年に糖尿病を発症した関連疾患は何ですか？
# My patients are between 99 and 100. what is the associated disease that caused diabetes in 2003-2004?
#
# Given diabetes, what're the top 4 strongest associated complications for females starting from 2005?
# 糖尿病の場合、2005年以降の女性の4大合併症は何ですか？
# If you have diabetes, what are the four major complications for women after 2005?
#
# What is the most related complication given diabetes if my patient is a woman less than 93 years old?
# 患者が93歳以下の女性の場合、糖尿病に最も関連する合併症は何ですか？
# If the patient is a woman under the age of 93, what is the most common complication associated with diabetes?
#
# Which illnesses may be diagnosed given diabetes for men starting from 2003?
# 2003年から男性の糖尿病と診断される可能性のある病気は？
# What are the diseases that may lead to a diagnosis of diabetes in men since 2003?
#
# What are the 8 most common illnesses among  at 42 years old who had diabetes starting from 2019?
# 2019年から糖尿病になった42歳の人に多い8つの病気とは？
# What are the 8 most common diseases in 42 year olds with diabetes from 2019?
#
# This is a woman with diabetes. What are the ten most possible diagnoses this woman will get?
# これは、糖尿病の女性です。この女性が受ける可能性のある10個の診断は何でしょうか？
# This is a woman who is diabetic. What are the 10 possible diagnoses that this woman could receive?
#
# What are the two most common comorbidities in  at 94 years old who had diabetes during a 1 year interval beginning 2017 and ending 2018?
# 2017年から2018年までの1年間に糖尿病を患った94歳の方で、最も多い2つの併存疾患は何ですか？
# What are the two most common comorbidities among 94-year-olds who had diabetes in the year 2017-2018?
#
# What are the five most common diseases in  who had diabetes after 2013?
# 2013年以降に糖尿病を患った人に多い5つの病気とは？
# What are the five most common diseases in people with diabetes since 2013?
#
# What are the 10 most common comorbidities among  from 11 to 71 who had diabetes during a 1 year period starting in 2012?
# 2012年から1年間に糖尿病を患った11歳から71歳までの人のうち、最も多い10種類の併存疾患は何ですか？
# What are the 10 most common comorbidities among people aged 11 to 71 years who had diabetes in the year starting in 2012?
#
# What are the two most common illnesses among  less than 28 years old who had diabetes during 2013?
# 2013年に糖尿病を患った28歳以下の人のうち、最も多い2つの病気は何ですか？
# What are the two most common diseases among people under the age of 28 who had diabetes in 2013?
#
# Which comorbidities may be diagnosed given diabetes for people older than 11 years old?
# 11歳以上の人に糖尿病を与えて診断される可能性のある併存疾患は？
# What are the possible comorbidities that can be diagnosed by giving a person over the age of 11 diabetes?
#
# What're the top three possible diseases among females during a 2 year period starting in 2015 given diabetes?
# 2015年からの2年間に女性が罹患する可能性のある病気のうち、糖尿病を除いたトップ3は？
# What are the top three diseases, excluding diabetes, that women are likely to suffer from in the two years starting 2015?
#
# This is a person with diabetes. What are the five most possible diagnoses this person will get?
# これは、糖尿病の人です。この人が受ける可能性のある5つの診断は何でしょうか？
# This is a person who is diabetic. What are the five possible diagnoses that this person could receive?
#
# What are the four most common illnesses in  older than 35 years old who had diabetes?
# 糖尿病を患った35歳以上の高齢者に多い4つの病気とは？
# What are the four most common diseases in older adults over the age of 35 with diabetes?
#
# I am a woman with diabetes. What are the eight most possible diagnoses this woman will get?
# 私は、糖尿病の女性です。この女性が受ける可能性の高い8つの診断を教えてください。
# I am a woman with diabetes. What are the eight most likely diagnoses that this woman will receive?
#
# What is the most related illness given diabetes during a 3 year interval beginning 2017 and ending 2020 if my patient is a person above 95 years old?
# 私の患者が95歳以上の人の場合、2017年から2020年までの3年間に糖尿病に最も関連する病気は何ですか？
# If my patient is 95 years old or older, what are the diseases most associated with diabetes in the three years between 2017 and 2020?

# %%
decodes_deepl_cn = decodes_deepl
encodes_deepl_cn = encodes_deepl

# %%
decodes_deepl_jp = decodes_deepl
encodes_deepl_jp = encodes_deepl

# %% [markdown]
# ### Google translate

# %%
encode_link = 'https://translate.google.com/?sl=en&tl=zh-CN&op=translate'
decode_link = 'https://translate.google.com/?sl=zh-CN&tl=en&op=translate'
consent_xpath = '//*[@id="yDmH0d"]/c-wiz/div/div/div/div[2]/div[1]/div[4]/form/div[1]/div/button'
# regex = 'from ([\d]{,2}) to ([\d]{,2})'
# questions_ = [substitute(i) for i in questions]
# delete_xpath = '//*[@id="ow42"]/div/span/button'
src_xpath = '//*[@id="yDmH0d"]/c-wiz/div/div[2]/c-wiz/div[2]/c-wiz/div[1]/div[2]/div[2]/c-wiz[1]/span/span/div/textarea'
dest_xpath = '//*[@id="yDmH0d"]/c-wiz/div/div[2]/c-wiz/div[2]/c-wiz/div[1]/div[2]/div[2]/c-wiz[2]/div[5]/div/div[1]/span[1]/span/span'

driver.get(decode_link)
if check_exists_by_xpath(consent_xpath):
    driver.find_element_by_xpath(consent_xpath).click()
decodes_google_train2 = [multi_translate(i,src_xpath, dest_xpath, 'google') for i in tqdm.tqdm(encodes_bing)]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-162-535be419c6aa> in <module>
#      11 if check_exists_by_xpath(consent_xpath):
#      12     driver.find_element_by_xpath(consent_xpath).click()
# ---> 13 decodes_google_train2 = [multi_translate(i,src_xpath, dest_xpath, 'google') for i in tqdm.tqdm(encodes_bing_train)]
#
# NameError: name 'encodes_bing_train' is not defined

# %%
decodes_google_train1 = [multi_translate(i,src_xpath, dest_xpath, 'google') for i in encodes_youdao]

# %% [markdown]
# ### Merge data

# %%
structures_bt = [i for i in structures]
for i in range(len(structures)):
    structures_bt.append([decodes_bing[i],structures[i][1],structures[i][2]])
    structures_bt.append([decodes_deepl_jp[i],structures[i][1],structures[i][2]])
    structures_bt.append([decodes_deepl_cn[i],structures[i][1],structures[i][2]])
# structures_bt = list(zip(*structures_bt))

# data_df = pd.DataFrame({
#     'x':data_bt[0], 'x_bing':decodes_fr_train, 'x_deepl_cn':decodes_it_train, 'x_deepl_ja':decodes_ja_train, 
#     'y1':data_bt[1], 'y2':data_bt[2]
# })

# random.shuffle(data_bt)

# %%
len(diseases_valid)*2
# Out:
# 562

# %%
# train_data = [[
#     re.sub('stroke',diseases_train[i+150],re.sub('diabetes',diseases_train[i],structures_bt[i][0])),
#     re.sub('stroke',diseases_train[i+150],re.sub('diabetes',diseases_train[i],structures_bt[i][1])),
#     re.sub('stroke',diseases_train[i+150],re.sub('diabetes',diseases_train[i],structures_bt[i][2])),
# ] for i in range(len(structures_bt))]

train_data = []
for i in range(len(diseases_train)*3):
    qna = random.choice(structures_bt)
    prior = random.choice(diseases_train)
    q = re.sub('stroke',prior,re.sub('diabetes',(diseases_train*3)[i],qna[0]))
    a1 = re.sub('stroke',prior,re.sub('diabetes',(diseases_train*3)[i],qna[1]))
    a2 = re.sub('stroke',prior,re.sub('diabetes',(diseases_train*3)[i],qna[2]))
    train_data.append([q,a1,a2])

valid_data = []
for i in range(len(diseases_valid)*3):
    qna = random.choice(structures_bt)
    prior = random.choice(diseases_valid)
    q = re.sub('stroke',prior,re.sub('diabetes',(diseases_valid*3)[i],qna[0]))
    a1 = re.sub('stroke',prior,re.sub('diabetes',(diseases_valid*3)[i],qna[1]))
    a2 = re.sub('stroke',prior,re.sub('diabetes',(diseases_valid*3)[i],qna[2]))
    valid_data.append([q,a1,a2])
    
# train_data = list(zip(*train_data)) # 7599
# valid_data = list(zip(*valid_data)) # 843

# %%
with open('custom_data_train.txt','w') as f:
    json.dump(train_data,f)

# %%
len(train_data)
# Out:
# 7599

# %%
import shutil

def processData(train_valid, dataset):
#     dataset = train_data if train_valid == 'train' else valid_data
    group_dir = '/Users/feiwang/Documents/Projects/custom_data_bt/group/'
    if os.path.isdir(group_dir+train_valid):
        shutil.rmtree(group_dir+train_valid)
    os.mkdir(group_dir+train_valid)

    for i in range(len(dataset)):
        str_i = str(i)
        path = os.path.join(group_dir+train_valid, dataset[i][1])
        if not os.path.isdir(path):
            os.mkdir(path)
        json.dump(dataset[i][0], open(os.path.join(path,train_valid+'_'+str_i+'.txt'),'w'))

# %%
processData('train', train_data)
processData('valid', valid_data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-2d3adec8ef96> in <module>
# ----> 1 processData('train', train_data)
#       2 processData('valid', valid_data)
#
# NameError: name 'train_data' is not defined

# %%
# !tar -czvf custom_data_bt_new.tar.gz custom_data_bt/
# Out:
# a custom_data_bt
# a custom_data_bt/.DS_Store
# a custom_data_bt/group
# a custom_data_bt/group/valid
# a custom_data_bt/group/.DS_Store
# a custom_data_bt/group/train
# a custom_data_bt/group/train/.DS_Store
# a custom_data_bt/group/train/count(*)-long_registry
# a custom_data_bt/group/train/count(*)-mortality
# a custom_data_bt/group/train/others
# a custom_data_bt/group/train/avg(age)-long_registry
# a custom_data_bt/group/train/avg(age)-mortality
# a custom_data_bt/group/train/avg(age)-mortality/train_4227.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_5139.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_5893.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_702.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_3574.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_2332.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_6154.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_2440.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_528.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_83.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_5307.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_266.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_7504.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_4838.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_6961.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_1968.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_2520.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_5529.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_6034.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_3164.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_7316.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_1767.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_6008.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_851.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_4384.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_2911.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_6550.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_4409.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_1203.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_1202.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_1570.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_111.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_3367.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_4408.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_1216.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_4346.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_3398.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_6009.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_475.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_313.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_3165.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_4622.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_1982.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_6747.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_4811.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_2284.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_1955.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_515.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_3763.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_7511.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_501.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_2469.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_1606.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_5448.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_4756.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_4024.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_55.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_3788.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_1821.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_717.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_3561.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_5662.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_5851.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_4595.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_926.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_3588.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_4581.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_6341.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_4230.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_729.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_4542.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_3205.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_3563.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_1406.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_43.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_1837.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_6180.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_4740.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_94.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_6631.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_5476.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_265.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_5304.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_3832.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_2286.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_4146.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_1758.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_1994.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_7473.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_305.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_1770.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_6779.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_1016.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_7467.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_6590.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_6584.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_6553.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_2721.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_5728.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_6209.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_7117.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_107.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_4378.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_1214.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_1201.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_3358.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_5932.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_1598.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_1771.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_6778.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_1003.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_304.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_6744.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_2250.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_1981.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_6787.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_7499.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_4184.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_1942.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_516.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_3760.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_1611.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_3006.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_5339.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_6624.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_3984.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_1413.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_1375.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_5885.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_2132.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_6340.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_6426.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_4594.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_937.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_923.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_4209.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_2678.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_3200.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_2644.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_4792.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_1832.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_3016.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_1629.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_4751.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_6620.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_3994.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_4023.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_7310.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_6768.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_5261.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_843.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_5936.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_5088.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_664.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_7106.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_1211.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_4355.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_2725.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_5738.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_2080.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_856.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_6580.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_2916.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_329.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_6033.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_1012.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_1774.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_7305.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_4817.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_2335.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_3759.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_5328.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_7517.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_5472.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_5314.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_2490.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_5499.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_47.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_6437.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_2651.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_2645.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_1370.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_2679.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_5116.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_4208.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_7067.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_2686.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_908.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_7065.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_5672.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_2121.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_5896.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_7059.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_3559.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_1819.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_6810.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_51.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_6186.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_1602.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_92.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_4020.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_4034.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_3808.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_2280.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_1776.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_3161.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_1010.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_7461.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_5504.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_2243.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_1992.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_6025.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_6743.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_6757.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_854.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_2096.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_698.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_6596.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_3363.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_1574.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_3377.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_5060.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_6541.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_2041.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_4424.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_6233.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_4342.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_2732.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_896.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_2726.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_7138.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_1561.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_5075.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_114.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_3389.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_6597.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_699.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_6583.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_869.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_2530.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_3148.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_2256.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_464.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_7474.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_7312.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_5511.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_7306.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_1944.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_2281.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_6781.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_5459.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_3766.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_504.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_5303.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_6839.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_1824.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_2493.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_78.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_6346.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_2646.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_6420.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_4545.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_2134.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_7064.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_3564.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_946.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_4287.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_4244.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_3259.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_4536.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_5166.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_4085.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_3926.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_23.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_3098.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_1658.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_5358.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_6889.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_6651.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_5402.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_7573.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_1670.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_4697.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_6080.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_3852.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_1923.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_4873.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_6902.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_2225.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_4654.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_3885.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_6731.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_5238.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_359.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_2219.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_365.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_2796.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_2972.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_629.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_5990.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_4442.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_1260.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_601.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_5007.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_172.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_4443.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_4331.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_5749.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_7189.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_199.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_3489.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_2783.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_1705.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_2218.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_3648.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_2230.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_4899.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_6917.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_2581.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_4709.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_7200.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_204.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_2344.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_4906.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_4090.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_3933.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_5615.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_3502.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_1315.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_2608.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_6320.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_1329.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_990.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_2152.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_2807.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_2813.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_4292.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_4286.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_1498.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_6487.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_789.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_2187.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_4284.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_2805.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_2811.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_992.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_3528.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_1854.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_4086.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_4938.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_2346.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_4051.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_6652.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_2352.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_3702.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_6108.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_1667.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_7389.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_2597.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_1908.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_4643.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_1049.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_5561.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_3676.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_372.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_3104.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_4441.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_1263.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_5763.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_170.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_5762.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_165.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_6243.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_4497.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_2958.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_5212.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_1712.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_3111.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_5206.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_2569.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_3677.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_1048.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_2227.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_6096.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_2409.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_1100.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_3703.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_4722.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_1882.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_5428.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_1128.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_3930.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_1699.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_4939.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_4093.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_2151.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_2637.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_2804.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_944.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_5831.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_940.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_5174.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_5160.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_1306.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_7039.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_983.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_1879.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_3908.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_25.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_6858.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_2394.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_31.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_7207.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_5410.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_5404.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_1104.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_6086.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_6938.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_3101.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_3897.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_4646.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_6290.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_2790.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_1500.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_1272.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_3303.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_5982.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_6247.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_5997.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_6252.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_7164.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_1515.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_7170.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_1267.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_6285.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_809.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_6044.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_4135.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_438.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_3666.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_410.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_1071.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_404.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_362.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_6087.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_4848.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_2587.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_6905.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_558.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_4041.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_2342.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_4733.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_2395.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_4928.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_6865.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_18.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_6326.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_7038.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_4257.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_3276.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_1475.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_1313.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_5808.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_969.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_943.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_2181.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_5177.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_5611.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_6873.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_3937.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_2397.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_26.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_3710.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_3076.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_7204.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_214.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_3062.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_5375.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_1113.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_2354.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_228.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_4731.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_6126.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_6907.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_4862.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_2585.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_4692.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_3664.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_374.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_406.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_6708.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_3880.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_348.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_2552.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_6287.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_5956.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_2787.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_176.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_3300.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_4309.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_1265.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_5003.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_604.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_638.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_1259.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_639.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_2989.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_2751.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_2023.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_2745.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_6292.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_836.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_4644.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_2235.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_6735.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_6721.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_1927.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_4693.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_6912.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_6906.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_1890.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_6127.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_5348.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_3705.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_1106.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_598.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_4917.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_2631.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_5837.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_6499.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_5190.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_2827.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_6314.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_1309.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_4271.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_768.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_1321.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_16.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_3907.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_4926.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_7585.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_6843.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_6116.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_4073.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_2364.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_5423.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_1123.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_1889.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_3683.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_2589.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_3697.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_5580.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_5219.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_6710.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_350.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_1043.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_7181.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_1282.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_4477.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_3324.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_152.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_7142.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_620.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_1241.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_1526.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_2985.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_153.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_6275.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_5768.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_2007.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_3319.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_7194.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_5967.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_1724.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_4884.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_4648.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_4890.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_2239.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_1056.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_3899.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_6711.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_7369.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_3872.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_1888.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_543.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_3709.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_594.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_3906.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_1877.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_5634.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_2629.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_741.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_1320.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_1446.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_1308.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_4502.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_3292.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_1485.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_6465.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_3521.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_5150.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_3253.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_1691.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_3086.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_6698.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_29.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_2415.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_4702.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_7545.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_6883.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_2429.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_4058.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_6129.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_1901.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_6908.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_3858.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_5597.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_6707.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_5568.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_2950.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_186.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_5959.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_6288.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_5795.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_192.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_2777.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_4306.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_4460.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_2011.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_7169.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_2763.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_5742.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_5756.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_3441.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_637.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_636.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_2992.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_6504.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_2762.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_7168.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_2010.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_1280.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_5780.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_5970.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_3642.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_352.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_5555.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_7342.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_3130.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_5227.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_2560.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_6706.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_6060.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_3859.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_5582.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_7395.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_3871.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_1121.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_5421.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_7544.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_4065.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_4717.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_568.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_4924.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_4930.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_7587.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_597.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_3905.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_1486.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_5192.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_965.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_5810.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_5828.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_791.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_785.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_3295.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_5800.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_7024.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_1333.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_2160.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_3518.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_2606.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_1694.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_587.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_3726.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_3040.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_1643.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_3054.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_7554.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_4713.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_2362.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_3875.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_7434.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_424.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_6058.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_5237.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_4101.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_4667.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_2202.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_4673.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_801.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_3336.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_5747.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_2028.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_3444.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_4471.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_4470.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_169.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_7179.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_5752.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_3323.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_5746.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_7151.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_3451.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_2997.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_814.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_2798.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_4672.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_2203.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_6703.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_6717.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_7421.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_4128.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_3135.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_3874.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_3690.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_6105.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_7233.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_1642.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_6893.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_551.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_4048.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_1656.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_3041.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_11.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_1859.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_4921.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_6844.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_6475.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_2613.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_4276.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_3243.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_1483.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_3280.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_2188.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_3282.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_7033.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_3241.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_4506.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_779.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_4260.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_6305.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_3094.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_13.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_1126.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_7231.txt
# a custom_data_bt/group/train/avg(age)-mortality/train_5426.txt
# ...
# a custom_data_bt/group/valid/others/valid_822.txt
# a custom_data_bt/group/valid/others/valid_638.txt
# a custom_data_bt/group/valid/others/valid_360.txt
# a custom_data_bt/group/valid/others/valid_374.txt
# a custom_data_bt/group/valid/others/valid_228.txt
# a custom_data_bt/group/valid/others/valid_566.txt
# a custom_data_bt/group/valid/count(*)-mortality/valid_594.txt
# a custom_data_bt/group/valid/count(*)-mortality/valid_436.txt
# a custom_data_bt/group/valid/count(*)-mortality/valid_350.txt
# a custom_data_bt/group/valid/count(*)-mortality/valid_36.txt
# a custom_data_bt/group/valid/count(*)-mortality/valid_597.txt
# a custom_data_bt/group/valid/count(*)-mortality/valid_385.txt
# a custom_data_bt/group/valid/count(*)-mortality/valid_186.txt
# a custom_data_bt/group/valid/count(*)-mortality/valid_804.txt
# a custom_data_bt/group/valid/count(*)-mortality/valid_227.txt
# a custom_data_bt/group/valid/count(*)-mortality/valid_790.txt
# a custom_data_bt/group/valid/count(*)-mortality/valid_419.txt
# a custom_data_bt/group/valid/count(*)-mortality/valid_380.txt
# a custom_data_bt/group/valid/count(*)-mortality/valid_394.txt
# a custom_data_bt/group/valid/count(*)-mortality/valid_182.txt
# a custom_data_bt/group/valid/count(*)-mortality/valid_593.txt
# a custom_data_bt/group/valid/count(*)-mortality/valid_578.txt
# a custom_data_bt/group/valid/count(*)-mortality/valid_752.txt
# a custom_data_bt/group/valid/count(*)-mortality/valid_787.txt
# a custom_data_bt/group/valid/count(*)-mortality/valid_234.txt
# a custom_data_bt/group/valid/count(*)-mortality/valid_591.txt
# a custom_data_bt/group/valid/count(*)-mortality/valid_426.txt
# a custom_data_bt/group/valid/count(*)-mortality/valid_368.txt
# a custom_data_bt/group/valid/count(*)-mortality/valid_396.txt
# a custom_data_bt/group/valid/count(*)-mortality/valid_779.txt
# a custom_data_bt/group/valid/count(*)-mortality/valid_285.txt
# a custom_data_bt/group/valid/count(*)-mortality/valid_83.txt
# a custom_data_bt/group/valid/count(*)-mortality/valid_291.txt
# a custom_data_bt/group/valid/count(*)-mortality/valid_440.txt
# a custom_data_bt/group/valid/count(*)-mortality/valid_680.txt
# a custom_data_bt/group/valid/count(*)-mortality/valid_247.txt
# a custom_data_bt/group/valid/count(*)-mortality/valid_6.txt
# a custom_data_bt/group/valid/count(*)-mortality/valid_330.txt
# a custom_data_bt/group/valid/count(*)-mortality/valid_95.txt
# a custom_data_bt/group/valid/count(*)-mortality/valid_244.txt
# a custom_data_bt/group/valid/count(*)-mortality/valid_718.txt
# a custom_data_bt/group/valid/count(*)-mortality/valid_91.txt
# a custom_data_bt/group/valid/count(*)-mortality/valid_283.txt
# a custom_data_bt/group/valid/count(*)-mortality/valid_650.txt
# a custom_data_bt/group/valid/count(*)-mortality/valid_678.txt
# a custom_data_bt/group/valid/count(*)-mortality/valid_90.txt
# a custom_data_bt/group/valid/count(*)-mortality/valid_241.txt
# a custom_data_bt/group/valid/count(*)-mortality/valid_45.txt
# a custom_data_bt/group/valid/count(*)-mortality/valid_257.txt
# a custom_data_bt/group/valid/count(*)-mortality/valid_685.txt
# a custom_data_bt/group/valid/count(*)-mortality/valid_691.txt
# a custom_data_bt/group/valid/count(*)-mortality/valid_134.txt
# a custom_data_bt/group/valid/count(*)-mortality/valid_75.txt
# a custom_data_bt/group/valid/count(*)-mortality/valid_449.txt
# a custom_data_bt/group/valid/count(*)-mortality/valid_677.txt
# a custom_data_bt/group/valid/count(*)-mortality/valid_689.txt
# a custom_data_bt/group/valid/count(*)-mortality/valid_474.txt
# a custom_data_bt/group/valid/count(*)-mortality/valid_516.txt
# a custom_data_bt/group/valid/count(*)-mortality/valid_675.txt
# a custom_data_bt/group/valid/count(*)-mortality/valid_259.txt
# a custom_data_bt/group/valid/count(*)-mortality/valid_729.txt
# a custom_data_bt/group/valid/count(*)-mortality/valid_705.txt
# a custom_data_bt/group/valid/count(*)-mortality/valid_73.txt
# a custom_data_bt/group/valid/count(*)-mortality/valid_507.txt
# a custom_data_bt/group/valid/count(*)-mortality/valid_498.txt
# a custom_data_bt/group/valid/count(*)-mortality/valid_116.txt
# a custom_data_bt/group/valid/count(*)-mortality/valid_260.txt
# a custom_data_bt/group/valid/count(*)-mortality/valid_710.txt
# a custom_data_bt/group/valid/count(*)-mortality/valid_470.txt
# a custom_data_bt/group/valid/count(*)-mortality/valid_128.txt
# a custom_data_bt/group/valid/count(*)-mortality/valid_699.txt
# a custom_data_bt/group/valid/count(*)-mortality/valid_303.txt
# a custom_data_bt/group/valid/count(*)-mortality/valid_713.txt
# a custom_data_bt/group/valid/count(*)-mortality/valid_16.txt
# a custom_data_bt/group/valid/count(*)-mortality/valid_576.txt
# a custom_data_bt/group/valid/count(*)-mortality/valid_628.txt
# a custom_data_bt/group/valid/count(*)-mortality/valid_166.txt
# a custom_data_bt/group/valid/count(*)-mortality/valid_403.txt
# a custom_data_bt/group/valid/count(*)-mortality/valid_17.txt
# a custom_data_bt/group/valid/count(*)-mortality/valid_777.txt
# a custom_data_bt/group/valid/count(*)-mortality/valid_401.txt
# a custom_data_bt/group/valid/count(*)-mortality/valid_373.txt
# a custom_data_bt/group/valid/count(*)-mortality/valid_818.txt
# a custom_data_bt/group/valid/count(*)-mortality/valid_164.txt
# a custom_data_bt/group/valid/count(*)-mortality/valid_158.txt
# a custom_data_bt/group/valid/count(*)-mortality/valid_766.txt
# a custom_data_bt/group/valid/count(*)-mortality/valid_376.txt
# a custom_data_bt/group/valid/count(*)-mortality/valid_820.txt
# a custom_data_bt/group/valid/count(*)-mortality/valid_798.txt
# a custom_data_bt/group/valid/count(*)-mortality/valid_773.txt
# a custom_data_bt/group/valid/count(*)-mortality/valid_765.txt
# a custom_data_bt/group/valid/count(*)-mortality/valid_759.txt
# a custom_data_bt/group/valid/count(*)-mortality/valid_567.txt
# a custom_data_bt/group/valid/count(*)-mortality/valid_361.txt
# a custom_data_bt/group/valid/count(*)-mortality/valid_823.txt
# a custom_data_bt/group/valid/count(*)-mortality/valid_348.txt
# a custom_data_bt/group/valid/count(*)-mortality/valid_406.txt
# a custom_data_bt/group/valid/count(*)-mortality/valid_599.txt
# a custom_data_bt/group/valid/count(*)-mortality/valid_214.txt
# a custom_data_bt/group/valid/count(*)-mortality/valid_758.txt
# a custom_data_bt/group/valid/count(*)-mortality/valid_764.txt
# a custom_data_bt/group/valid/count(*)-long_registry/valid_782.txt
# a custom_data_bt/group/valid/count(*)-long_registry/valid_231.txt
# a custom_data_bt/group/valid/count(*)-long_registry/valid_609.txt
# a custom_data_bt/group/valid/count(*)-long_registry/valid_153.txt
# a custom_data_bt/group/valid/count(*)-long_registry/valid_806.txt
# a custom_data_bt/group/valid/count(*)-long_registry/valid_185.txt
# a custom_data_bt/group/valid/count(*)-long_registry/valid_152.txt
# a custom_data_bt/group/valid/count(*)-long_registry/valid_634.txt
# a custom_data_bt/group/valid/count(*)-long_registry/valid_608.txt
# a custom_data_bt/group/valid/count(*)-long_registry/valid_556.txt
# a custom_data_bt/group/valid/count(*)-long_registry/valid_542.txt
# a custom_data_bt/group/valid/count(*)-long_registry/valid_218.txt
# a custom_data_bt/group/valid/count(*)-long_registry/valid_756.txt
# a custom_data_bt/group/valid/count(*)-long_registry/valid_540.txt
# a custom_data_bt/group/valid/count(*)-long_registry/valid_420.txt
# a custom_data_bt/group/valid/count(*)-long_registry/valid_622.txt
# a custom_data_bt/group/valid/count(*)-long_registry/valid_811.txt
# a custom_data_bt/group/valid/count(*)-long_registry/valid_187.txt
# a custom_data_bt/group/valid/count(*)-long_registry/valid_623.txt
# a custom_data_bt/group/valid/count(*)-long_registry/valid_179.txt
# a custom_data_bt/group/valid/count(*)-long_registry/valid_569.txt
# a custom_data_bt/group/valid/count(*)-long_registry/valid_794.txt
# a custom_data_bt/group/valid/count(*)-long_registry/valid_431.txt
# a custom_data_bt/group/valid/count(*)-long_registry/valid_141.txt
# a custom_data_bt/group/valid/count(*)-long_registry/valid_155.txt
# a custom_data_bt/group/valid/count(*)-long_registry/valid_197.txt
# a custom_data_bt/group/valid/count(*)-long_registry/valid_154.txt
# a custom_data_bt/group/valid/count(*)-long_registry/valid_632.txt
# a custom_data_bt/group/valid/count(*)-long_registry/valid_140.txt
# a custom_data_bt/group/valid/count(*)-long_registry/valid_395.txt
# a custom_data_bt/group/valid/count(*)-long_registry/valid_418.txt
# a custom_data_bt/group/valid/count(*)-long_registry/valid_342.txt
# a custom_data_bt/group/valid/count(*)-long_registry/valid_544.txt
# a custom_data_bt/group/valid/count(*)-long_registry/valid_26.txt
# a custom_data_bt/group/valid/count(*)-long_registry/valid_585.txt
# a custom_data_bt/group/valid/count(*)-long_registry/valid_803.txt
# a custom_data_bt/group/valid/count(*)-long_registry/valid_619.txt
# a custom_data_bt/group/valid/count(*)-long_registry/valid_590.txt
# a custom_data_bt/group/valid/count(*)-long_registry/valid_508.txt
# a custom_data_bt/group/valid/count(*)-long_registry/valid_40.txt
# a custom_data_bt/group/valid/count(*)-long_registry/valid_468.txt
# a custom_data_bt/group/valid/count(*)-long_registry/valid_454.txt
# a custom_data_bt/group/valid/count(*)-long_registry/valid_497.txt
# a custom_data_bt/group/valid/count(*)-long_registry/valid_130.txt
# a custom_data_bt/group/valid/count(*)-long_registry/valid_642.txt
# a custom_data_bt/group/valid/count(*)-long_registry/valid_695.txt
# a custom_data_bt/group/valid/count(*)-long_registry/valid_643.txt
# a custom_data_bt/group/valid/count(*)-long_registry/valid_119.txt
# a custom_data_bt/group/valid/count(*)-long_registry/valid_333.txt
# a custom_data_bt/group/valid/count(*)-long_registry/valid_509.txt
# a custom_data_bt/group/valid/count(*)-long_registry/valid_737.txt
# a custom_data_bt/group/valid/count(*)-long_registry/valid_709.txt
# a custom_data_bt/group/valid/count(*)-long_registry/valid_4.txt
# a custom_data_bt/group/valid/count(*)-long_registry/valid_735.txt
# a custom_data_bt/group/valid/count(*)-long_registry/valid_523.txt
# a custom_data_bt/group/valid/count(*)-long_registry/valid_331.txt
# a custom_data_bt/group/valid/count(*)-long_registry/valid_696.txt
# a custom_data_bt/group/valid/count(*)-long_registry/valid_683.txt
# a custom_data_bt/group/valid/count(*)-long_registry/valid_668.txt
# a custom_data_bt/group/valid/count(*)-long_registry/valid_442.txt
# a custom_data_bt/group/valid/count(*)-long_registry/valid_522.txt
# a custom_data_bt/group/valid/count(*)-long_registry/valid_52.txt
# a custom_data_bt/group/valid/count(*)-long_registry/valid_254.txt
# a custom_data_bt/group/valid/count(*)-long_registry/valid_240.txt
# a custom_data_bt/group/valid/count(*)-long_registry/valid_297.txt
# a custom_data_bt/group/valid/count(*)-long_registry/valid_446.txt
# a custom_data_bt/group/valid/count(*)-long_registry/valid_308.txt
# a custom_data_bt/group/valid/count(*)-long_registry/valid_651.txt
# a custom_data_bt/group/valid/count(*)-long_registry/valid_645.txt
# a custom_data_bt/group/valid/count(*)-long_registry/valid_269.txt
# a custom_data_bt/group/valid/count(*)-long_registry/valid_533.txt
# a custom_data_bt/group/valid/count(*)-long_registry/valid_719.txt
# a custom_data_bt/group/valid/count(*)-long_registry/valid_0.txt
# a custom_data_bt/group/valid/count(*)-long_registry/valid_733.txt
# a custom_data_bt/group/valid/count(*)-long_registry/valid_86.txt
# a custom_data_bt/group/valid/count(*)-long_registry/valid_92.txt
# a custom_data_bt/group/valid/count(*)-long_registry/valid_445.txt
# a custom_data_bt/group/valid/count(*)-long_registry/valid_135.txt
# a custom_data_bt/group/valid/count(*)-long_registry/valid_120.txt
# a custom_data_bt/group/valid/count(*)-long_registry/valid_450.txt
# a custom_data_bt/group/valid/count(*)-long_registry/valid_295.txt
# a custom_data_bt/group/valid/count(*)-long_registry/valid_50.txt
# a custom_data_bt/group/valid/count(*)-long_registry/valid_3.txt
# a custom_data_bt/group/valid/count(*)-long_registry/valid_515.txt
# a custom_data_bt/group/valid/count(*)-long_registry/valid_298.txt
# a custom_data_bt/group/valid/count(*)-long_registry/valid_139.txt
# a custom_data_bt/group/valid/count(*)-long_registry/valid_105.txt
# a custom_data_bt/group/valid/count(*)-long_registry/valid_662.txt
# a custom_data_bt/group/valid/count(*)-long_registry/valid_110.txt
# a custom_data_bt/group/valid/count(*)-long_registry/valid_299.txt
# a custom_data_bt/group/valid/count(*)-long_registry/valid_74.txt
# a custom_data_bt/group/valid/count(*)-long_registry/valid_462.txt
# a custom_data_bt/group/valid/count(*)-long_registry/valid_112.txt
# a custom_data_bt/group/valid/count(*)-long_registry/valid_311.txt
# a custom_data_bt/group/valid/count(*)-long_registry/valid_305.txt
# a custom_data_bt/group/valid/count(*)-long_registry/valid_463.txt
# a custom_data_bt/group/valid/count(*)-long_registry/valid_265.txt
# a custom_data_bt/group/valid/count(*)-long_registry/valid_513.txt
# a custom_data_bt/group/valid/count(*)-long_registry/valid_275.txt
# a custom_data_bt/group/valid/count(*)-long_registry/valid_98.txt
# a custom_data_bt/group/valid/count(*)-long_registry/valid_329.txt
# a custom_data_bt/group/valid/count(*)-long_registry/valid_665.txt
# a custom_data_bt/group/valid/count(*)-long_registry/valid_117.txt
# a custom_data_bt/group/valid/count(*)-long_registry/valid_659.txt
# a custom_data_bt/group/valid/count(*)-long_registry/valid_842.txt
# a custom_data_bt/group/valid/count(*)-long_registry/valid_102.txt
# a custom_data_bt/group/valid/count(*)-long_registry/valid_664.txt
# a custom_data_bt/group/valid/count(*)-long_registry/valid_99.txt
# a custom_data_bt/group/valid/count(*)-long_registry/valid_248.txt
# a custom_data_bt/group/valid/count(*)-long_registry/valid_66.txt
# a custom_data_bt/group/valid/count(*)-long_registry/valid_704.txt
# a custom_data_bt/group/valid/count(*)-long_registry/valid_70.txt
# a custom_data_bt/group/valid/count(*)-long_registry/valid_302.txt
# a custom_data_bt/group/valid/count(*)-long_registry/valid_114.txt
# a custom_data_bt/group/valid/count(*)-long_registry/valid_100.txt
# a custom_data_bt/group/valid/count(*)-long_registry/valid_459.txt
# a custom_data_bt/group/valid/count(*)-long_registry/valid_465.txt
# a custom_data_bt/group/valid/count(*)-long_registry/valid_59.txt
# a custom_data_bt/group/valid/count(*)-long_registry/valid_539.txt
# a custom_data_bt/group/valid/count(*)-long_registry/valid_277.txt
# a custom_data_bt/group/valid/count(*)-long_registry/valid_505.txt
# a custom_data_bt/group/valid/count(*)-long_registry/valid_748.txt
# a custom_data_bt/group/valid/count(*)-long_registry/valid_760.txt
# a custom_data_bt/group/valid/count(*)-long_registry/valid_774.txt
# a custom_data_bt/group/valid/count(*)-long_registry/valid_238.txt
# a custom_data_bt/group/valid/count(*)-long_registry/valid_210.txt
# a custom_data_bt/group/valid/count(*)-long_registry/valid_364.txt
# a custom_data_bt/group/valid/count(*)-long_registry/valid_402.txt
# a custom_data_bt/group/valid/count(*)-long_registry/valid_417.txt
# a custom_data_bt/group/valid/count(*)-long_registry/valid_371.txt
# a custom_data_bt/group/valid/count(*)-long_registry/valid_359.txt
# a custom_data_bt/group/valid/count(*)-long_registry/valid_788.txt
# a custom_data_bt/group/valid/count(*)-long_registry/valid_824.txt
# a custom_data_bt/group/valid/count(*)-long_registry/valid_14.txt
# a custom_data_bt/group/valid/count(*)-long_registry/valid_799.txt
# a custom_data_bt/group/valid/count(*)-long_registry/valid_216.txt
# a custom_data_bt/group/valid/count(*)-long_registry/valid_564.txt
# a custom_data_bt/group/valid/count(*)-long_registry/valid_174.txt
# a custom_data_bt/group/valid/count(*)-long_registry/valid_148.txt
# a custom_data_bt/group/valid/count(*)-long_registry/valid_821.txt
# a custom_data_bt/group/valid/count(*)-long_registry/valid_363.txt
# a custom_data_bt/group/valid/count(*)-long_registry/valid_11.txt
# a custom_data_bt/group/valid/count(*)-long_registry/valid_771.txt
# a custom_data_bt/group/valid/count(*)-long_registry/valid_13.txt
# a custom_data_bt/group/valid/count(*)-long_registry/valid_162.txt
# a custom_data_bt/group/valid/count(*)-long_registry/valid_604.txt
# a custom_data_bt/group/valid/count(*)-long_registry/valid_610.txt
# a custom_data_bt/group/valid/count(*)-long_registry/valid_572.txt
# a custom_data_bt/group/valid/count(*)-long_registry/valid_770.txt

# %%
train = list(zip(*train_data_bt))
valid = list(zip(*valid_data_bt))
train_X, train_y = train[0], train[1]
valid_X, valid_y = valid[0], valid[1]

# %%
len(train[1])
# Out:
# 2910

# %%
data_X = train[0] + valid[0]
data_y = train[1] + valid[1]

# %%
len(data_X)
# Out:
# 3228

# %%
data_len = [*range(len(data_X))]

# %%
passed_endpoints = []
passed_indice = []
failed_indice = []

for i in data_X:
    sub_endpoints = []
    for j in diseases:
        if j in i.lower():
            sub_endpoints.append(j)
    if len(sub_endpoints) == 0:
        failed_indice.append(data_X.index(i))
    else:
        passed_endpoints.append(sub_endpoints)
        passed_indice.append(data_X.index(i))

# %%
# index_failed = [i for i in endpoints if type(i) == int]
# index_passed = [i for i in endpoints if type(i) == str] #list(set(data_len) - set(index_failed))

# %%
len(endpoints) == len(data_X)
# Out:
# True

# %%
trainx = [data_X[i] for i in passed_indice]
trainy1 = [data_y[i] for i in passed_indice]
trainy2 = [passed_endpoints[passed_indice.index(i)] for i in passed_indice]

validx = [data_X[i] for i in failed_indice]
validy1 = [data_y[i] for i in failed_indice]

# %%
trainx = [re.sub('in people','in the population',i) if 'in people' in i else i for i in trainx]
validx = [re.sub('in people','in the population',i) if 'in people' in i else i for i in validx]

# %%
with open('custom_data.json','w') as f:
    json.dump({'train_X':trainx,'train_y1':trainy1,'train_y2':trainy2,'valid_X':validx,'valid_y1':validy1},f)

# %%
len(endpoints)
# Out:
# 3228

# %%
trainx.index('How many men are at age 18 after they were diagnosed with Ebola virus disease?')
# Out:
# 10

# %%
# Which diseases may be diagnosed before heart failure for females from 10 to 95 from 2018 to 2019?

# %%
trainx = trainx[:43]+["What diseases can I have diagnosed before heart failure if I'm a female from 10-95 years old in 2018-2019?"]+trainx[44:]

# %%
endpoints[960]
# Out:
# ['duloxetine']

# %%
trainy2[960]
# Out:
# ['alcohol-related liver disease', "addison's disease", 'liver disease']

# %%
import pandas as pd

# %%
train_data = pd.DataFrame({'train_X':trainx,'train_y1':trainy1,'train_y2':trainy2})
valid_data = pd.DataFrame({'valid_X':validx,'valid_y1':validy1})

# %%
def save_xls(list_dfs, xls_path):
    with pd.ExcelWriter(xls_path) as writer:
        for n, df in enumerate(list_dfs):
            df.to_excel(writer,'sheet%s' % n)
        writer.save()

# %%
save_xls([train_data,valid_data], 'custom_data.xlsx')

# %%
save_xls([train_df,valid_df], 'custom_data_bt.xlsx')

# %%
len(train_df)
# Out:
# 485

# %%
disease_name changed,

# %%
train_datalist_copy = train_datalist

# %%
train_datalist=[]

# %%
train_df.iloc[32,:].tolist() # not yet
# Out:
# ["What is the average age of women who died after alzheimer's disease diagnosis?",
#  "What is the average age of women deceased after the diagnosis of Alzheimer's disease?",
#  "What is the average age of women who died after the diagnosis of Alzheimer's disease?",
#  "What is the average age of died women after diagnosing Alzheimer's disease?",
#  "What is the average age of women who die after being diagnosed with Alzheimer's disease?",
#  "How old is the average age of women who died after the diagnosis of Alzheimer's disease?",
#  'avg(age)-mortality',
#  "cut_year = 0, endpoint = alzheimer's disease, sex = female"]

# %%
data_list = [train_df.iloc[i,:].tolist() for i in range(32,len(train_df))]
# data_list

# %%
[valid_df.iloc[18,:].tolist(),valid_df.iloc[19,:].tolist(),valid_df.iloc[20,:].tolist(),valid_df.iloc[21,:].tolist(),valid_df.iloc[22,:].tolist()]
# Out:
# [['Given mebendazole, what are the strongest associated comorbidities for women over 58 years old between 2019 and 2020?',
#   'Give Mebendazole, what are the strongest comorbidities associated with women over 58 between 2019 and 2020?',
#   'Given Mebendazole, what are the strongest associated comorbidities for women over 58 years between 2019 and 2020?',
#   'Considering Mebendazole, what is the strongest related labor force for women over 58 years or older between 2019 and 2020?',
#   'Given Mebendazor, what is the strongest correlation among women over the age of 58 between 2019 and 2020?',
#   "During 2016 to 2020, how is the average age of 29-year-old children's first fever?",
#   'outcome-cox_hrs',
#   'age > 58, prior = mebendazole, sex = female, year between 2019 and 2020'],
#  ['How many individuals under 73 years old died one year after fentanyl diagnosis?',
#   'How many people under 73 years old died one year after the diagnosis of fentanyl?',
#   'How many individuals under the age of 73 have died a year after the diagnosis of Fentanyl?',
#   'What was the number of individuals under the age of 73 died one year after the diagnosis of fentanyl?',
#   'How many people under the age of 73 die a year after fentanyl diagnosis?',
#   'How many people under the age of 73 after a diagnosis of fentanyl?',
#   'count(*)-mortality',
#   'age < 73, cut_year = 1, endpoint = fentanyl'],
#  ['Which diseases may be diagnosed before domperidone for women between 50 and 91 between 2016 and 2017?',
#   'What diseases can be diagnosed before domperidone for women between 50 and 91 between 2016 and 2017?',
#   'What diseases can be diagnosed before domperidone for women between 50 and 91 between 2016 and 2017?',
#   'Which disease may be diagnosed before Domperidone for women between 50 and 91 between 2016 and 2017?',
#   'What diseases can women aged 50 to 91 be diagnosed before Domberone between 2016 and 2017?',
#   'During 2016 to 2017, women from 50 to 91 years old can diagnose what diseases can be diagnosed before Dompetone?',
#   'prior-cox_hrs',
#   'age between 50 and 91, outcome = domperidone, sex = female, year between 2016 and 2017'],
#  ['What is the mean age of men who died after azithromycin diagnosis?',
#   'What is the average age of men who died after the diagnosis of azithromycin?',
#   "What is the average age of men who died after azithromycin's diagnosis?",
#   'What is the average age of men who died after azithromycin diagnosis?',
#   'What is the average age of men who die after a diagnosis of azithromycin?',
#   'What is the average age of men who died after azithromycin diagnosis?',
#   'avg(age)-mortality',
#   'cut_year = 0, endpoint = azithromycin, sex = male'],
#  ['How many women above 6 years old died 15 years after they diagnosed with varenicline?',
#   'How many women over 6 years old died 15 years after their verenicine diagnosis?',
#   'How many women over the age of 6 died 15 years after diagnosing with Varenicline?',
#   'What is the number of women over 6 years old who die after 15 years after being diagnosed with VarenicLine?',
#   'How many women over the age of 6 die 15 years after being diagnosed with varicose veins?',
#   'How many women over 6 years old have died after being diagnosed with varicose # 15 years?',
#   'count(*)-mortality',
#   'age > 6, cut_year = 15, endpoint = varenicline, sex = female']]

# %%
'How many women between 1 and 56 have been diagnosed with corona virus?',
  'How many women aged from 1 to 56 are suffering from corona virus?',
  'What is the number of women between 1 and 56 diagnosed with corona virus?',
  'How many women are diagnosed corona virus if they are between 1 year old and 56 years old?',
  'How many women between the ages of 1 and 56 are diagnosed with overeating?',
  'How many women from 1 to 56 were diagnosed as corona virus?',

# %%
'What is the average age at the first event of paracetamol among individuals below 7 years old in 2016?',
  'What is the average age for the first paracetamol event among children under 7 in 2016?',
  'In 2016, what is the average age at the first paracetamol event in kids under 7 years old?',
  "During 2016, what's the mean age for first Paracetamor diagnosis for children under 7 years old?",
  'What is the average age of children below the age of 7 when they had first paracetamol diagnosis in 2016?',
  'What is the average age of children below 7 years old who got paracetamol for the first time in 2016?',
  'avg(age)-long_registry',
  'age < 7, endpoint = paracetamol, year = 2016'],

# %%
this = [
['What is the hazard ratio of chloramphenicol for those females above 67 years old who had diazepam?',
  'If my patient is above 67 having diazepam. What is her risk ratio of chloramphenicol?',
  'If my patient is above 67 and was diagnosed with diazepam. What is her risk ratio of having chloramphenicol??',
  'What is the hazard ratio of chloramphenicol diagnosis if my patient is above 67 and was diagnosed with diazepam?',
  'What is the risk ratio of having chloramphenicol if I am above 67 years old with diazepam?',
  'For women with diazepam and over 67 years old, what is the risk ratio of chloramphenicol?',
  'hr-cox_hrs',
  'age > 67, outcome = chloramphenicol, prior = diazepam, sex = female'],
 ['What is the hazard ratio of irritable bowel syndrome in ibs given heparinoid for individuals over 89 years old between 2010 and 2011?',
  'What is the danger ratio of irritable intestine syndrome at IBS given the heparinoid for people over 89 between 2010 and 2011?',
  'between 2010 and 2011, What is the danger relationship of irritable bowel syndrome in IBS given eparinoid for individuals over 89 years between 2010 and 2011?',
  'What is the hazard ratio of IBS hypertherminal syndrome given heparinoids for individuals over 89 in the year of 2010 and 2011?',
  'Between 2010 and 2011, for people over the age of 89, what is their risk ratio of having irritable bowel syndrome in ibs after they have heparinoid?',
  'For seniors over 67 years old, what is the risk ratio of having irritable bowel syndrome in ibs if they have heparinoid??',
  'hr-cox_hrs',
  'age > 89, outcome = irritable bowel syndrome in ibs, prior = heparinoid, year between 2010 and 2011'],
 ['What is the hazard ratio of clobetasone for those men above 96 years old who had tramadol in 2009?',
  'What is the danger ratio of Clobésone for old men over 96 who had Tramadol in 2009?',
  "What's the risk ratio of Clobetasone if I have Tramadol in 2009? I'm an old man above 96",
  'What is the hazard ratio of Clobetasone given Tramador during 2009? He is over 96 years old?',
  'What is the risk ratio of Clobetasone to men over the age of 96 who had cumado in 2009?',
  'He is older than 96 years old in 2009, so what is his hazard ratio of clobetasone if he has tramadol already?',
  'hr-cox_hrs',
  'age > 96, outcome = clobetasone, prior = tramadol, sex = male, year = 2009'],
 ['Given leg cramps, what are the top 6 strongest associated complications for people over 55 years old before 2014?',
  'If my patients are above 55. What are the 6 strongest complications associated with leg cramps before 2014?',
  'Given leg cramps, what are the first 6 strongest complications associated with people over 55 years before 2014?',
  'What is the strongest relevant complications of leg cramps by 2014 if we are over 55 years old?',
  'Given leg cramps, what are the top 6 related complications by 2014? We are some people over the age of 55.',
  'What is the risk ratio of leg cramps by 2014 if my patients are all above 55 years old?',
  'outcome-cox_hrs',
  'age > 55, prior = leg cramps, year < 2014'],
 ['What is the mean age at the first event of fever between 2016 and 2020?',
  'What is the average age at the first fever event between 2016 and 2020?',
  'between 2016 and 2020, What is the average age for the first fever diagnosis between 2016 and 2020?',
  "between 2016 and 2020, What's the average age for the first fever diagnosis?",
  'how old on average are these people when they had first paracetamol diagnosis between 2016 and 2020?',
  "During 2016 to 2020, how old are these patients who had their first fever diagnosis?",
  'avg(age)-long_registry',
  'endpoint = fever, year between 2016 and 2020']
]
train_datalist += this

# %%
'What is the average age of men who died 5 years after obstructive sleep apnoea diagnosis?',
  'What is the average age of men who died 5 years after the diagnosis of obstructive sleep apnea?',
  "What's males's average life expectancy 5 years after their first diagnosis of obstructive sleep apnoea?",
  "What's the average life expectancy of men after a five-year survival of obstructive sleep apnoea?",
  'What is the average age of men who died after a five year survival of obstructive sleep apnea?',
  'What is the average age of men who die five years after diagnosis of obstructive sleep apnea?',
  'How old is the average age of men in obstructive sleep apnea after 5 years?',

'On average, how old are these women who died 5 years after pseudoqualine diagnosis?',

# %%
train_datalist
# Out:
# [['What are the top 5 comorbidities for males between 13 and 93 between 2002 and 2012 given clarithromycin?',
#   'What are the 5 main comorbidities for men between 13 and 93 between 2002 and 2012 if they have clarithromycin?',
#   'During 2002 and 2012, what are the first 5 comorbidities for males between 13 and 93 who have Claritromycin?',
#   'Between 2002 and 2012, what is the top 5 diseases if a male aged from 13 to 93 years old has clarithromycin?',
#   'What were the five combinations of clarithromycin for those men aged 13 to 93 between 2002 and 2012?',
#   'From 2002 to 2012, what is the five main problems for males having clarithromycin, given age range between 13 and 93?',
#   'outcome-cox_hrs',
#   'age between 13 and 93, prior = clarithromycin, sex = male, year between 2002 and 2012'],
#  ['Which diseases may be diagnosed before budesonide rectal foam and enemas for men at 36 years old after 2019?',
#   'What diseases can be diagnosed before the rectal foam of budesonide among males  at age 36 after 2019?',
#   'After 2019, what diseases can be diagnosed for those men at 36 years who already have rectal foam of Budesonide and enemies?',
#   'Which disease may be diagnosed before budesonide rectal foam and enema for 36-year-old men since 2019?',
#   'What diseases can be diagnosed before budson rectal foam and enemas in the male population aged 36 after 2019?',
#   'Which diseases can be diagnosed since 2019 for a 36-year-old male with rectal foam of Budesonide and enemies?',
#   'prior-cox_hrs',
#   'age = 36, outcome = budesonide rectal foam and enemas, sex = male, year > 2019'],
#  ['What is the average age of women who died after letrozole diagnosis?',
#   'What is the average age of women deceased after the diagnosis of letrozole?',
#   'What is the average age of women who died after the diagnosis of Letrozole?',
#   'How old on average are women who died after letrozole?',
#   'What is the average age of women who died after letrozole?',
#   'On average, how old is a woman who died of the diagnosis of letrozole?',
#   'avg(age)-mortality',
#   'cut_year = 0, endpoint = letrozole, sex = female'],
#  ['How many women above 70 years old have been diagnosed with flatulence?',
#   'How many women older than 70 have been diagnosed with flatulence?',
#   'How many women over 70 are diagnosed with flatulence?',
#   'What is the number of women over 70 years old diagnosed with the flatulence?',
#   'How many women over the age of 70 got flatulence?',
#   'How many women over 70 years old suffer from flatulence?',
#   'count(*)-long_registry',
#   'age > 70, endpoint = flatulence, sex = female'],
#  ['What is the hazard ratio of osteoporosis given ewing sarcoma for children under 9 years old after 2018?',
#   "What's the risk of osteoporosis given to Ewing Sarcoma among children under 9 years after 2018?",
#   'What is the risk ratio of osteoporosis if a kid under 9 diagnosed with ewing sarcoma after 2018?',
#   'What is the hazard ratio of osteoporosis given the diagnosis of ewing sarcoma for nine-year-old people since 2018?',
#   'After 2018, what is the risk of osteoporosis in children under 9 years old given ewing sarcoma?',
#   'After 2018, how risky is osteoporosis for kids under the age of 9 if they have ewing sarcoma?',
#   'hr-cox_hrs',
#   'age < 29, outcome = osteoporosis, prior = ewing sarcoma, year > 2018'],
#  ['Which diseases may be diagnosed before salbutamol inhaler for men below 66 years old between 2003 and 2008?',
#   'In year 2003-2008, what diseases can be diagnosed before the Salbutamol inhaler in men under 66?',
#   'What diseases can be diagnosed before Salbutamol inhaler for men under 66 between 2003 and 2008?',
#   'Regarding to the men younger than 66 years old, which disease may be diagnosed before the Salbutamol inhaler from 2003 to 2008?',
#   'What diseases could men under the age of 66 get diagnosed before they had inhaling salbutamol between 2003 and 2008?',
#   'From 2003 to 2008, what diseases can be diagnosed before salbutamol inhaler for males younger than the age of 66?',
#   'prior-cox_hrs',
#   'age < 66, outcome = salbutamol inhaler, sex = male, year between 2003 and 2008'],
#  ['How many males over 69 years old have been diagnosed with lisinopril before 2018?',
#   'How many men over 69 were diagnosed with Lisinopril before 2018?',
#   'How many males above 69 have been diagnosed with Lisinopril before 2018?',
#   'What is the number of men over 69 years old before 2018 who have been diagnosed with Lisinopril?',
#   'How many men over the age of 69 got diagnosed with lisinopril by 2018?',
#   'Before 2018, how many men over 69 years old were diagnosed with lisinopril?',
#   'count(*)-long_registry',
#   'age > 69, endpoint = lisinopril, sex = male, year < 2018'],
#  ['What is the mean age of men when they died after autistic spectrum disorder?',
#   'What is the average age of men who deseased after an autistic spectrum disorder diagnosis?',
#   'What is the average age of men who died after the diagnosis of autistic spectrum disturbance?',
#   'What is the average age of men who died with ASD?',
#   'How old on average age are the men who died of Asd diagnosis?',
#   'What is age on average for those males who died with autistic spectrum disorder?',
#   'avg(age)-mortality',
#   'cut_year = 0, endpoint = autistic spectrum disorder, sex = male'],
#  ['How many men between 20 and 21 died 5 years after they diagnosed with aciclovir?',
#   'How many men aged from 20 to 21 has died 5 years after their diagnosis of aciclovir?',
#   'How many men between 20 and 21 years have died 5 years after they got aciclovir?',
#   'What is the number of 20-year-old men and 21-year-old men who died five years after being diagnosed with Acyclovir?',
#   'How many men between the ages of 20 and 21 die five years after being diagnosed with acetic acid?',
#   'How many men from 20 to 21 years old have died after being diagnosed with acetic acid for 5 years?',
#   'count(*)-mortality',
#   'age between 20 and 21, cut_year = 5, endpoint = aciclovir, sex = male'],
#  ['How many women under 72 years old have been diagnosed with prednisolone?',
#   'How many women under 72 have been diagnosed with prednisolone?',
#   'How many women under 72 have been diagnosed with prednisolone?',
#   'What is the number of women under 72 years old are diagnosed with prednisolone?',
#   'How many women under the age of 72 have been diagnosed with Plinysoron?',
#   'How many women under 72 years old are diagnosed with Pulinielon?',
#   'count(*)-long_registry',
#   'age < 72, endpoint = prednisolone, sex = female'],
#  ['What is the average age of men who died 5 years after liver tumours diagnosis?',
#   "After the diagnosis of liver tumors, what's the mean age of men who survived for another 5 years?",
#   'What is the average age of men who died of the diagnosis of liver tumors after five-year survival?',
#   'After a five-year survival, what is the average age of men who died of liver tumors?',
#   'What is the average age of men who die of liver tumors 5 years after their first diagnosis?',
#   'For those men who died 5 years after the first event of liver tumors, what is their mean age?',
#   'avg(age)-mortality',
#   'cut_year = 5, endpoint = liver tumours, sex = male'],
#  ['Which diseases may be diagnosed before sildenafil for men at 11 years old?',
#   'For 11-year-old kids, what diseases can be diagnosed first if they later get diagnosed with sildenafil?',
#   'My patient is 11 years old. What diseases can he have before being diagnosed with Sildenafil?',
#   'My little patient is 11 years old with sildenafil. Which diseases may he have before that?',
#   'What diseases can be diagnosed before sildenafil if I have a boy at 11-year-old?',
#   'What diseases can I diagnose before sildenafil if I am an 11-year-old male?',
#   'prior-cox_hrs',
#   'age = 11, outcome = sildenafil, sex = male'],
#  ['What is the mean age of males who died 15 years after urinary tract infection diagnosis?',
#   "After the diagnosis of urinary tract infection, what's the mean age of men who have survived for another 15 years?",
#   'What is the average age of men who deseased 15 years after an urinary tract infection?',
#   'On average, what is the average age of men who died of the diagnosis of urinary tract infection after a survival of fifteen years?',
#   'What is the average age of men who stay alive for 15 years after they are diagnosed with urinary tract infection?',
#   'How old on average age are men who died after 15 years of urinary tract infection?',
#   'avg(age)-mortality',
#   'cut_year = 15, endpoint = urinary tract infection, sex = male'],
#  ['Which diseases may be diagnosed before diabetes for females under 31 years old after 2013?',
#   'Since 2013, what diseases can women under 31 get diagnosed if they have diabetes later?',
#   'After 2013, what diseases can be diagnosed for females under 31 years old if later they are diagnosed with diabetes?',
#   "Which disease may be diagnosed before women's diabetes under 31 years of age after 2013?",
#   'Before diabetes, what diseases could be diagnosed in women under the age of 31 after 2013?',
#   'I am female below 31. After 2013, what diseases I may have if some time later I find I have diabetes?',
#   'prior-cox_hrs',
#   'age < 31, outcome = diabetes, sex = female, year > 2013'],
#  ["What's the hazard ratio of headaches for those women below 41 years old who had vertigo between 2005 and 2019?",
#   'Between 2005 and 2019, what is the danger ratio of headaches if a women under the age of 41 already had Vertigo?',
#   'What is the danger of headache for those women under 41 years who had vertigo between 2005 and 2019?',
#   'Given vertigo, what is the danger ratio of headaches for women younger 41 from 2005 to 2019?',
#   'What is the risk of headaches among women under the age of 41 who have dizziness between 2005 and 2019?',
#   "What is the dangerous ratio of women's headaches if they are under the 41 years old and dizzy during 2005 to 2019?",
#   'hr-cox_hrs',
#   'age < 41, outcome = headaches, prior = vertigo, sex = female, year between 2005 and 2019'],
#  ["What's the number of people below 72 years old if they died 5 years after nasal and sinus cancer diagnosis?",
#   'How many people under 72 years old died after they suffered 5 years from nasal and sinus cancer?',
#   'How many individuals under 72 have died 5 years after the diagnosis of nasal and breast cancer?',
#   'What was the number of individuals under 72 years old who died five years after the diagnosis of the nose and the sinus cancer?',
#   'What is the death toll of nasal and sinus cancer if these patients are younger than 72 and have survived for 5 years?',
#   'How many people under 72 years of age died 5 years after diagnosis of sinus cancer?',
#   'count(*)-mortality',
#   'age < 72, cut_year = 5, endpoint = nasal and sinus cancer'],
#  ['How many individuals under 30 years old have been diagnosed with hyperglycaemia in high blood sugar in 2020?',
#   'How many people under 30 were diagnosed with hyperglycemia in high blood glucose in 2020?',
#   'How many individuals under the age of 30 were diagnosed with hyperglycemia in high blood sugar in 2020?',
#   'What is the number of persons who were under 30 and were diagnosed with hyperglycemia in 2020?',
#   'During 2020, how many people below the age of 30 got diagnosed with hyperglycemia?',
#   'Do you know how many people in 2020 have been diagnosed with high blood sugar if they are younger than 30?',
#   'count(*)-long_registry',
#   'age < 30, endpoint = hyperglycaemia in high blood sugar, year = 2020'],
#  ["What's the average age of individuals who died 15 years after tuberculosis in tb diagnosis?",
#   "After bing diagnosed with Tuberculosis, what's the age on average of people who survived for 15 years more?",
#   'What is the average age of people who died 15 years after Tuberculosis in the diagnosis of TB?',
#   'What is the average age of individuals who die of tuberculosis in tb 15 years after their first diagnosis of this disease?',
#   'For those who die of tuberculosis fifteen years after their first diagnosis, what is their average age?',
#   'How old is the average age of people who died after 15 years of tuberculosis diagnosis?',
#   'avg(age)-mortality',
#   'cut_year = 15, endpoint = tuberculosis in tb'],
#  ['Which diseases may be diagnosed given tranexamic acid for individuals over 49 years old after 2010?',
#   'What diseases can be diagnosed after transeexamic acid for people over 49 years after 2010?',
#   'Which diseases can be diagnosed with after being diagnosed tranexamic acid for individuals over 49 years after 2010?',
#   'For those who are older than 49, which disease they can have if they already have tranexamic acid since 2010?',
#   'Since 2010, what diseases may be diagnosed by people over the age of 49 who are given transsine?',
#   'After 2010, some people over 49 may diagnose with amucine. Which disease they may have later?',
#   'outcome-cox_hrs',
#   'age > 49, prior = tranexamic acid, year > 2010'],
#  ['What is the hazard ratio of osteoarthritis for those females between 92 and 99 who had cirrhosis between 2005 and 2020?',
#   'What is the danger ratio of osteoarthritis for these women between 92 and 99 with cirrhosis between 2005 and 2020?',
#   'During 2005-2020, what is the risk rate of osteoarthritis if an old lady between 92-99 with cirrhosis?',
#   'What is the risk rate of deformer arthrosis if a women between 92-99 with cirrhosis during 2005-2020?',
#   'If an old grandma who younger than 99 but older than 92 gets diagnosed with cirrhosis between 2005 and 2020. What is her risk of osteoarthritis?',
#   'What is the dangerous ratio of osteoarthritis considering females aged between 92-99 from 2005 to 2020 given cirrhosis?',
#   'hr-cox_hrs',
#   'age between 92 and 99, outcome = osteoarthritis, prior = cirrhosis, sex = female, year between 2005 and 2020'],
#  ['What is the average age of people who died after dysphagia in swallowing problems diagnosis?',
#   'If one has dysphagia in swallowing problems. What is the average age of death?',
#   'What is the average age of death given diagnosis of swallowing problems?',
#   'What is the average age of death after being diagnosed with dysphagia in swallowing problems?',
#   'What is the mean age of death regarding to dysphagia in swallowing problems?',
#   'Considering dysphagia in swallowing problems, what is the age of death on average?',
#   'avg(age)-mortality',
#   'cut_year = 0, endpoint = dysphagia in swallowing problems'],
#  ["Given mirtazapine, what're the strongest associated comorbidities for men over 99 years old in 2006?",
#   'Given the Mirtazapine, what are the strongest associated comorbidities for senior males above 99 in 2006?',
#   'Given Mirtazapine, what are the strongest associated comorbidities in 2006 for men over 99?',
#   'Considering Meltazapine, what is the strongest related labor work for men over 99 in 2006?',
#   'Given Mirtazapin, what was the strongest associated comormission among men over the age of 99 in 2006?',
#   'What is the strongest related diseases in 2006 if men over 99 years old were diagnosed with mirtazapine?',
#   'outcome-cox_hrs',
#   'age > 99, prior = mirtazapine, sex = male, year = 2006'],
#  ['What is the mean age at the first event of common heart conditions among women?',
#   'What is the average age at the first event of common heart status among women?',
#   'What is the average age of women who get diagnosed with common heart conditions for their first time?',
#   'What is the average age when women get diagnosed with common heart conditions for the first time?',
#   'What is the average age of women with common heart disease for the 1st time?',
#   'How old on average are the women diagnosed with common heart disease for the 1st time?',
#   'avg(age)-long_registry',
#   'endpoint = common heart conditions, sex = female'],
#  ['What are the top 6 severe comorbidities for males over 61 years old given itching?',
#   'What are the 6 major serious comorbidities for men over 61 years old with itching?',
#   'What are the first 6 serious comorbidities for males above the age of 61 if they have itching?',
#   'Considering itching, what are the top six severe problems for men over 61-year-old?',
#   'What are the top 6 severe comoriphs after bing diagnosed with itching considering the cases of men over 61 years old?',
#   'My patient is a male over 61. What is the six most related diagnoses given itching?',
#   'outcome-cox_hrs',
#   'age > 61, prior = itching, sex = male'],
#  ['What is the hazard ratio of otitis externa for those males at 92 years old who had morphine from 2003 to 2011?',
#   'What is the danger ratio of external otitis for these 92-year-old men who had morphine from 2003 to 2011?',
#   'What is the risk ratio of otitis external for those males to 92 years who had morphine from 2003 to 2011?',
#   'What is the hazard ratio of otitis externa from 2003 to 2011? My patient is a 92-year-old man who had morphine.',
#   'From 2003 to 2011, what was the risk of otitis media in 92-year-old men with morphine?',
#   'Between 200 and 2011, what is the dangerous ratio of otitis externa for 92-year-old males with morphine?',
#   'hr-cox_hrs',
#   'age = 92, outcome = otitis externa, prior = morphine, sex = male, year between 2003 and 2011'],
#  ['What is the mean age at the first event of urticaria in hives among women between 2003 and 2010?',
#   'Between 2003 and 2010, what is the average age of women who got urticaria in hives for the 1st time?',
#   'From 2003 to 2010, what is the average age of females being diagnosed with urticaria in hives for the first time?',
#   'How old on average are these women when they are diagnosed with urticaria in hives for the first time between 2003 and 2010?',
#   'How old on average are the women when urticaria in hives occurred for the first time in their life between 2003 and 2010?',
#   'During the period from 2003 to 2010, how old on average are these females when it is their first time to be diagnosed with measles in the hive?',
#   'avg(age)-long_registry',
#   'endpoint = urticaria in hives, sex = female, year between 2003 and 2010'],
#  ['What is the hazard ratio of tonsillitis for those men under 24 years old who had diarrhoea before 2019?',
#   'What is the risk ratio of tonsillitis given young men below the age of 24 who had diarrhea before 2019?',
#   'What is the risk ratio of tonsillitis for those men under the 24 years who had diarrhea before 2019?',
#   'I am a young man under 24 with diarrhea. What is the risk rate of having tonsilitis before 2019?',
#   'What is the risk of tonsillitis before 2019 if I am a guy younger than 24 years old and was diagnosed with diarrhoea?',
#   'What is the risk ratio of tonsillitis given diarrhoea by 2019? I have a male patient who is younger than 24.',
#   'hr-cox_hrs',
#   'age < 24, outcome = tonsillitis, prior = diarrhoea, sex = male, year < 2019'],
#  ['What is the hazard ratio of diazepam for those men at 11 years old who had fibromyalgia before 2012?',
#   'By 2012, what is the risk ratio of diazepam given these 11-year-old men who had fibromyalgia?',
#   'What is the danger relationship of Diazepam given fibromyalgia for men at 11 before 2012?',
#   'What is the danger ratio of diazepam for the 11-year-old people who had fibromyalgia before 2012?',
#   'What is the risk of stability for 11-year-old boys with fibromyalgia prior to 2012?',
#   'Prior to 2012, what is the dangerous ratio of diazepam given fibromyalgia if my patient is an eleven-year-old boy?',
#   'hr-cox_hrs',
#   'age = 11, outcome = diazepam, prior = fibromyalgia, sex = male, year < 2012'],
#  ['What is the average age of men who died 15 years after metformin diagnosis?',
#   'What is the mean age of men who died 15 years after the diagnosis of metformin?',
#   'What is the average age of death after a 15-year survival if my patient is a man with the diagnosis of metformin?',
#   'if I am a man with metformin. What is the average age of death 15 years after the diagnosis?',
#   'What is the average age of men who die 15 years after having metformin?',
#   'How old on average are these men with metformin 15 years after their first diagnosis when they died?',
#   'avg(age)-mortality',
#   'cut_year = 15, endpoint = metformin, sex = male'],
#  ["What's the hazard ratio of methadone for those women from 11 to 37 who had latanoprost between 2007 and 2013?",
#   'Between 2007 and 2013, what is the danger ratio of methadone for these women from 11 to 37 who had latanoprosis?',
#   'From 2007 to 2013, what is the risk ratio of methadone for those women from 11 to 37 with Latanoprost?',
#   'What is the hazard ratio of Metadondon for 11 to 37 women who had Latanoprost between 2007 and 2013?',
#   'How much risk of methadone given for Latanoprost between 2007 and 2013? She is a patient between 11 and 37 years old.',
#   'How much hazard of methadone between 2007 and 2013 if her age is from 11 to 37 years old with latanoprost?',
#   'hr-cox_hrs',
#   'age between 11 and 37, outcome = methadone, prior = latanoprost, sex = female, year between 2007 and 2013'],
#  ['What is the average age at the first event of abdominal aortic aneurysm for individuals after 2000?',
#   'What is the average age at the first abdominal aortic aneurysm event for old people after 2000?',
#   'What is the average age at the first event of the abdominal aortic aneurysm for seniors after 2000?',
#   'What is the average age of patients since 2000 when they have their first event of abdominal aortic aneurysm?',
#   'After 2000, what is the average age of patients who has abdominal aortic aneurysm for their first time?',
#   'Since 2000, what is the mean age of personals when they have been diagnoesed with abdominal aortic aneurysm for the 1st time?',
#   'avg(age)-long_registry',
#   'endpoint = abdominal aortic aneurysm, year > 2000'],
#  ['Which diseases may be diagnosed before chronic kidney disease for individuals from 2015 to 2020?',
#   'My patients have been diagnosed with chronic kidney disease from 2015 to 2020. What diseases could they have before that??',
#   'From 2015 to 2020, What diseases can be diagnosed before chronic kidney disease for patients?',
#   'During 2015-2020, which disease people might have earlier if they later got diagnosed with chronic kidney disease?',
#   "I've been diagnosed with chronic kidney disease from 2015 to 2020. What diseases could I have before that?",
#   'From 2015 to 2020, which diseases can be diagnosed before chronic kidney disease?',
#   'prior-cox_hrs',
#   'outcome = chronic kidney disease, year between 2015 and 2020'],
#  ['How many females from 43 to 58 have been diagnosed with type 2 diabetes in 2018?',
#   'How many women from 43 to 58 were diagnosed with type 2 diabetes in 2018?',
#   'How many females from 43 to 58 have been diagnosed with type 2 diabetes in 2018?',
#   'What is the number of 43 to 58 women in 2018 diagnosed with type 2 diabetes?',
#   'How many women between the ages of 43 and 58 will be diagnosed with type 2 diabetes in 2018?',
#   "What's the number of women aged between 43 and 58 in 2018 who have been diagnosed with type 2 diabetes?",
#   'count(*)-long_registry',
#   'age between 43 and 58, endpoint = type 2 diabetes, sex = female, year = 2018'],
#  ['How many women over 73 years old died 15 years after clonazepam diagnosis?',
#   'How many women over 73 are dead 15 years after the diagnosis of clonazepam?',
#   'How many women over 73 years died of clonazepam 15 years after the first diagnosis?',
#   'What was the number of women over 73 years old who died after 15 years of clonazepam?',
#   'How many old women over the age of 73 die 15 years after the diagnosis of Clonazepam?',
#   'How many 73 years old or older grandmas died after 15 years of diagnosis of clonazepam?',
#   'count(*)-mortality',
#   'age > 73, cut_year = 15, endpoint = clonazepam, sex = female'],
#  ['What is the average age at the first event of paracetamol among individuals below 7 years old in 2016?',
#   'What is the average age for the first paracetamol event among children under 7 in 2016?',
#   'In 2016, what is the average age at the first paracetamol event in kids under 7 years old?',
#   "During 2016, what's the mean age for first Paracetamor diagnosis for children under 7 years old?",
#   'What is the average age of children below the age of 7 when they had first paracetamol diagnosis in 2016?',
#   'What is the average age of children below 7 years old who got paracetamol for the first time in 2016?',
#   'avg(age)-long_registry',
#   'age < 7, endpoint = paracetamol, year = 2016'],
#  ['How many people between 78 and 95 have been diagnosed with bowel incontinence?',
#   'What is the number of people aged from 78 years old to 95 years old diagnosed with intestinal incontinence?',
#   'What was the number of people between 78 and 95 diagnosed with intestinal incontinence?',
#   'What was the number of people between 78 and 95 diagnosed with intestinal loss?',
#   'How many people between the ages of 78 and 95 have been diagnosed with bowel incontinence?',
#   'How many people aged 78 to 95 were diagnosed as intestinal incontinence?',
#   'count(*)-long_registry',
#   'age between 78 and 95, endpoint = bowel incontinence'],
#  ['How many males between 61 and 86 have been diagnosed with vaginal thrush in 2018?',
#   'In 2018, how many men between 61 and 86 were diagnosed with vaginal thrush?',
#   'In 2018, how many males between 61 and 86 have been diagnosed with vaginal mugherus?',
#   'What is the number of men who got diagnosed with vaginal thrush and aged between 61 and 86 in 2018?',
#   'How many men between the ages of 61 and 86 during 2018 was diagnosed with vaginal thrush?',
#   'How many men in 2018 have been diagnosed with vaginal thrush if they are from 61 years old to 86 years old?',
#   'count(*)-long_registry',
#   'age between 61 and 86, endpoint = vaginal thrush, sex = male, year = 2018'],
#  ['What is the mean age of males who died 15 years after their first dementia with lewy bodies diagnosis?',
#   "What's the average age of men who died 15 years after dementia with the diagnosis of Lewy's bodies?",
#   "What is males's average life expectancy 15 years after their first diagnosis of dementia with lewy bodies?",
#   'What is the average age of men who died 15 years after dementia in Lebie Body diagnosis?',
#   'What is the average age at which men die 15 years after diagnosis of dementia?',
#   'What is the average age of men in 15 years after the diagnosis of dementia?',
#   'avg(age)-mortality',
#   'cut_year = 15, endpoint = dementia with lewy bodies, sex = male'],
#  ['How many women between 1 and 56 have been diagnosed with corona virus?',
#   'How many women aged from 1 to 56 are suffering from corona virus?',
#   'What is the number of women between 1 and 56 diagnosed with corona virus?',
#   'How many women are diagnosed corona virus if they are between 1 year old and 56 years old?',
#   'How many women between the ages of 1 and 56 are diagnosed with overeating?',
#   'How many women from 1 to 56 were diagnosed as corona virus?',
#   'count(*)-long_registry',
#   'age between 1 and 56, endpoint = corona virus, sex = female'],
#  ['What is the mean age at the first event of fybogel for people between 2001 and 2020?',
#   'What is the average age for the first Fybogel event between 2001 and 2020?',
#   'What is the average age for the first Fybogel diagnosis between 2001 and 2020?',
#   "Between 2001 and 2020, what's the average age of Fybogel's first event for people over 61 years or older?",
#   'What was the average age of people when they first got diagnosed with fybogel between 2001 and 2020?',
#   'During 2001 to 2020, how old on average are those people diagnosed with fybogel for the 1st time?',
#   'avg(age)-long_registry',
#   'endpoint = fybogel, year between 2001 and 2020'],
#  ['What is the mean age of females who died 5 years after pseudoephedrine diagnosis?',
#   'What is the average age of females who died 5 years after the diagnosis of pseudoephedrine?',
#   'What is the average age of females that died 5 years after the diagnosis of pseudoefedrina?',
#   'Given Pseudoephedrine, What is the average age of women who died five years after their first diagnosis?',
#   'What is the average age of women who die five years after pseudoephedrine diagnosis?',
#   'On average, how old are these women who died 5 years after pseudoqualine diagnosis?',
#   'avg(age)-mortality',
#   'cut_year = 5, endpoint = pseudoephedrine, sex = female'],
#  ['What is the hazard ratio of trazodone given cough for individuals between 2015 and 2020?',
#   'Between 2015 and 2020, what is the hazard ratio of Trazodone for people having cough?',
#   'Between 2015 and 2020, what is hazard ratio of trazodone considering that someone has cough?',
#   'Between 2015 and 2020, what is the danger ratio of trazosterone if one has cough already?',
#   'Between 2015 and 2020, what is the risk ratio of trazosterone given cough?',
#   'During 2015 to 2020, what is the risk ratio of trazodone given cough?',
#   'hr-cox_hrs',
#   'outcome = trazodone, prior = cough, year between 2015 and 2020'],
#  ['What is the mean age at the first event of febrile seizures for males under 16 years old by 2017?',
#   'What is the average age for the first event of the febrile crises among men under the age of 16 before 2017?',
#   'before 2017, what is the average age for the first event of febrile seizures for males under 16 years?',
#   'What is the average age for the first thermal seizure among men under 16 years old by 2017?',
#   'before 2017, what is the average age of men under 16 years of age when they first had febrile seizures?',
#   'What is the average age of males who had fever for the first time when they are under 16 years old?',
#   'avg(age)-long_registry',
#   'age < 16, endpoint = febrile seizures, sex = male, year < 2017'],
#  ['Which diseases may be diagnosed before thyroid cancer in people between 51 and 92 from 2003 to 2008?',
#   'Between 2003 to 2008, what diseases can be diagnosed before thyroid cancer among seniors from 51 to 92?',
#   'What diseases can be diagnosed before thyroid cancer in adolescents and young adults for people between 51 and 92 from 2003 to 2008?',
#   'Which disease may be diagnosed before thyroid cancer in the population aged from 51 to 92 years from 2003 to 2008?',
#   'What diseases can people aged 51 to 92 be diagnosed earlier if they later have thyroid cancer between 2003 and 2008?',
#   'From 2003 to 2008, if people aged 51-92 have thyroid cancer, what diseases they may have earlier?',
#   'prior-cox_hrs',
#   'age between 51 and 92, outcome = thyroid cancer, year between 2003 and 2008'],
#  ['What is the average age of men who died 5 years after obstructive sleep apnoea diagnosis?',
#   'What is the average age of men who died 5 years after the diagnosis of obstructive sleep apnea?',
#   "What's males's average life expectancy 5 years after their first diagnosis of obstructive sleep apnoea?",
#   "What's the average life expectancy of men after a five-year survival of obstructive sleep apnoea?",
#   'What is the average age of men who died after a five year survival of obstructive sleep apnea?',
#   'What is the average age of men who die five years after diagnosis of obstructive sleep apnea?',
#   'How old is the average age of men in obstructive sleep apnea after 5 years?',
#   'avg(age)-mortality',
#   'cut_year = 5, endpoint = obstructive sleep apnoea, sex = male']]

# %%
with open('custom_data_bt.json','w') as f:
    json.dump(train_datalist,f)

# %%
train_datalist = train_datalist[:-1]

# %%
train_datalist = [['What are the top 5 comorbidities for males between 13 and 93 between 2002 and 2012 given clarithromycin?',
  'What are the 5 main comorbidities for men between 13 and 93 between 2002 and 2012 if they have clarithromycin?',
  'During 2002 and 2012, what are the first 5 comorbidities for males between 13 and 93 who have Claritromycin?',
  'Between 2002 and 2012, what is the top 5 diseases if a male aged from 13 to 93 years old has clarithromycin?',
  'What were the five combinations of clarithromycin for those men aged 13 to 93 between 2002 and 2012?',
  'From 2002 to 2012, what is the five main prolblems for males having clarithromycin, given age range between 13 and 93?',
  'outcome-cox_hrs',
  'age between 13 and 93, prior = clarithromycin, sex = male, year between 2002 and 2012'],
 ['Which diseases may be diagnosed before budesonide rectal foam and enemas for men at 36 years old after 2019?',
  'What diseases can be diagnosed before the rectal foam of budesonide among males  at age 36 after 2019?',
  'After 2019, what diseases can be diagnosed for those men at 36 years who already have rectal foam of Budesonide and enemies?',
  'Which disease may be diagnosed before budesonide rectal foam and enema for 36-year-old men since 2019?',
  'What diseases can be diagnosed before budson rectal foam and enemas in the male population aged 36 after 2019?',
  'Which diseases can be diagnosed since 2019 for a 36-year-old male with rectal foam of Budesonide and enemies?',
  'prior-cox_hrs',
  'age = 36, outcome = budesonide rectal foam and enemas, sex = male, year > 2019'],
 ['What is the average age of women who died after letrozole diagnosis?',
  'What is the average age of women deceased after the diagnosis of letrozole?',
  'What is the average age of women who died after the diagnosis of Letrozole?',
  'How old on average are women who died after letrozole?',
  'What is the average age of women who died after letrozole?',
  'On average, how old is a woman who died of the diagnosis of letrozole?',
  'avg(age)-mortality',
  'cut_year = 0, endpoint = letrozole, sex = female'],
 ['How many women above 70 years old have been diagnosed with flatulence?',
  'How many women older than 70 have been diagnosed with flatulence?',
  'How many women over 70 are diagnosed with flatulence?',
  'What is the number of women over 70 years old diagnosed with the flatulence?',
  'How many women over the age of 70 got flatulence?',
  'How many women over 70 years old suffer from flatulence?',
  'count(*)-long_registry',
  'age > 70, endpoint = flatulence, sex = female'],
 ['What is the hazard ratio of osteoporosis given ewing sarcoma for children under 9 years old after 2018?',
  "What's the risk of osteoporosis given to Ewing Sarcoma among children under 9 years after 2018?",
  'What is the risk ratio of osteoporosis if a kid under 9 diagnosed with ewing sarcoma after 2018?',
  'What is the hazard ratio of osteoporosis given the diagnosis of ewing sarcoma for nine-year-old people since 2018?',
  'After 2018, what is the risk of osteoporosis in children under 9 years old given ewing sarcoma?',
  'After 2018, how risky is osteoporosis for kids under the age of 9 if they have ewing sarcoma?',
  'hr-cox_hrs',
  'age < 29, outcome = osteoporosis, prior = ewing sarcoma, year > 2018'],
 ['Which diseases may be diagnosed before salbutamol inhaler for men below 66 years old between 2003 and 2008?',
  'In year 2003-2008, what diseases can be diagnosed before the Salbutamol inhaler in men under 66?',
  'What diseases can be diagnosed before Salbutamol inhaler for men under 66 between 2003 and 2008?',
  'Regarding to the men younger than 66 years old, which disease may be diagnosed before the Salbutamol inhaler from 2003 to 2008?',
  'What diseases could men under the age of 66 get diagnosed before they had inhaling salbutamol between 2003 and 2008?',
  'From 2003 to 2008, what diseases can be diagnosed before salbutamol inhaler for males younger than the age of 66?',
  'prior-cox_hrs',
  'age < 66, outcome = salbutamol inhaler, sex = male, year between 2003 and 2008'],
 ['How many males over 69 years old have been diagnosed with lisinopril before 2018?',
  'How many men over 69 were diagnosed with Lisinopril before 2018?',
  'How many males above 69 have been diagnosed with Lisinopril before 2018?',
  'What is the number of men over 69 years old before 2018 who have been diagnosed with Lisinopril?',
  'How many men over the age of 69 got diagnosed with lisinopril by 2018?',
  'Before 2018, how many men over 69 years old were diagnosed with lisinopril?',
  'count(*)-long_registry',
  'age > 69, endpoint = lisinopril, sex = male, year < 2018'],
 ['What is the mean age of men when they died after autistic spectrum disorder?',
  'What is the average age of men who deseased after an autistic spectrum disorder diagnosis?',
  'What is the average age of men who died after the diagnosis of autistic spectrum disturbance?',
  'What is the average age of men who died with ASD?',
  'How old on average age are the men who died of Asd diagnosis?',
  'What is age on average for those males who died with autistic spectrum disorder?',
  'avg(age)-mortality',
  'cut_year = 0, endpoint = autistic spectrum disorder, sex = male'],
 ['How many men between 20 and 21 died 5 years after they diagnosed with aciclovir?',
  'How many men aged from 20 to 21 has died 5 years after their diagnosis of aciclovir?',
  'How many men between 20 and 21 years have died 5 years after they got aciclovir?',
  'What is the number of 20-year-old men and 21-year-old men who died five years after being diagnosed with Acyclovir?',
  'How many men between the ages of 20 and 21 die five years after being diagnosed with acetic acid?',
  'How many men from 20 to 21 years old have died after being diagnosed with acetic acid for 5 years?',
  'count(*)-mortality',
  'age between 20 and 21, cut_year = 5, endpoint = aciclovir, sex = male'],
 ['How many women under 72 years old have been diagnosed with prednisolone?',
  'How many women under 72 have been diagnosed with prednisolone?',
  'How many women under 72 have been diagnosed with prednisolone?',
  'What is the number of women under 72 years old are diagnosed with prednisolone?',
  'How many women under the age of 72 have been diagnosed with Plinysoron?',
  'How many women under 72 years old are diagnosed with Pulinielon?',
  'count(*)-long_registry',
  'age < 72, endpoint = prednisolone, sex = female'],
 ['What is the average age of men who died 5 years after liver tumours diagnosis?',
  "After the diagnosis of liver tumors, what's the mean age of men who survived for another 5 years?",
  'What is the average age of men who died of the diagnosis of liver tumors after five-year survival?',
  'After a five-year survival, what is the average age of men who died of liver tumors?',
  'What is the average age of men who die of liver tumors 5 years after their first diagnosis?',
  'For those men who died 5 years after the first event of liver tumors, what is their mean age?',
  'avg(age)-mortality',
  'cut_year = 5, endpoint = liver tumours, sex = male'],
 ['Which diseases may be diagnosed before sildenafil for men at 11 years old?',
  'For 11-year-old kids, what diseases can be diagnosed first if they later get diagnosed with sildenafil?',
  'My patient is 11 years old. What diseases can he have before being diagnosed with Sildenafil?',
  'My little patient is 11 years old with sildenafil. Which diseases may he have before that?',
  'What diseases can be diagnosed before sildenafil if I have a boy at 11-year-old?',
  'What diseases can I diagnose before sildenafil if I am an 11-year-old male?',
  'prior-cox_hrs',
  'age = 11, outcome = sildenafil, sex = male'],
 ['What is the mean age of males who died 15 years after urinary tract infection diagnosis?',
  "After the diagnosis of urinary tract infection, what's the mean age of men who have survived for another 15 years?",
  "What is the average age of men who deseased 15 years after an urinary tract infection?",
  'On average, what is the average age of men who died of the diagnosis of urinary tract infection after a survival of fifteen years?',
  'What is the average age of men who stay alive for 15 years after they are diagnosed with urinary tract infection?',
  'How old on average age are men who died after 15 years of urinary tract infection?',
  'avg(age)-mortality',
  'cut_year = 15, endpoint = urinary tract infection, sex = male'],
 ['Which diseases may be diagnosed before diabetes for females under 31 years old after 2013?',
  'Since 2013, what diseases can women under 31 get diagnosed if they have diabetes later?',
  'After 2013, what diseases can be diagnosed for females under 31 years old if later they are diagnosed with diabetes?',
  "Which disease may be diagnosed before women's diabetes under 31 years of age after 2013?",
  'Before diabetes, what diseases could be diagnosed in women under the age of 31 after 2013?',
  'I am female below 31. After 2013, what diseases I may have if some time later I find I have diabetes?',
  'prior-cox_hrs',
  'age < 31, outcome = diabetes, sex = female, year > 2013'],
 ["What's the hazard ratio of headaches for those women below 41 years old who had vertigo between 2005 and 2019?",
  'Between 2005 and 2019, what is the danger ratio of headaches if a women under the age of 41 already had Vertigo?',
  'What is the danger of headache for those women under 41 years who had vertigo between 2005 and 2019?',
  'Given vertigo, what is the danger ratio of headaches for women younger 41 from 2005 to 2019?',
  'What is the risk of headaches among women under the age of 41 who have dizziness between 2005 and 2019?',
  "What is the dangerous ratio of women's headaches if they are under the 41 years old and dizzy during 2005 to 2019?",
  'hr-cox_hrs',
  'age < 41, outcome = headaches, prior = vertigo, sex = female, year between 2005 and 2019'],
 ["What's the number of people below 72 years old if they died 5 years after nasal and sinus cancer diagnosis?",
  'How many people under 72 years old died after they suffered 5 years from nasal and sinus cancer?',
  'How many individuals under 72 have died 5 years after the diagnosis of nasal and breast cancer?',
  'What was the number of individuals under 72 years old who died five years after the diagnosis of the nose and the sinus cancer?',
  'What is the death toll of nasal and sinus cancer if these patients are younger than 72 and have survived for 5 years?',
  'How many people under 72 years of age died 5 years after diagnosis of sinus cancer?',
  'count(*)-mortality',
  'age < 72, cut_year = 5, endpoint = nasal and sinus cancer'],
 ['How many individuals under 30 years old have been diagnosed with hyperglycaemia in high blood sugar in 2020?',
  'How many people under 30 were diagnosed with hyperglycemia in high blood glucose in 2020?',
  'How many individuals under the age of 30 were diagnosed with hyperglycemia in high blood sugar in 2020?',
  'What is the number of persons who were under 30 and were diagnosed with hyperglycemia in 2020?',
  'During 2020, how many people below the age of 30 got diagnosed with hyperglycemia?',
  'Do you know how many people in 2020 have been diagnosed with high blood sugar if they are younger than 30?',
  'count(*)-long_registry',
  'age < 30, endpoint = hyperglycaemia in high blood sugar, year = 2020'],
 ["What's the average age of individuals who died 15 years after tuberculosis in tb diagnosis?",
  "After bing diagnosed with Tuberculosis, what's the age on average of people who survived for 15 years more?",
  "What is the average age of people who died 15 years after Tuberculosis in the diagnosis of TB?",
  'What is the average age of individuals who die of tuberculosis in tb 15 years after their first diagnosis of this disease?',
  'For those who die of tuberculosis fifteen years after their first diagnosis, what is their average age?',
  'How old is the average age of people who died after 15 years of tuberculosis diagnosis?',
  'avg(age)-mortality',
  'cut_year = 15, endpoint = tuberculosis in tb'],
 ['Which diseases may be diagnosed given tranexamic acid for individuals over 49 years old after 2010?',
  'What diseases can be diagnosed after transeexamic acid for people over 49 years after 2010?',
  'Which diseases can be diagnosed with after being diagnosed tranexamic acid for individuals over 49 years after 2010?',
  'For those who are older than 49, which disease they can have if they already have tranexamic acid since 2010?',
  'Since 2010, what diseases may be diagnosed by people over the age of 49 who are given transsine?',
  'After 2010, some people over 49 may diagnose with amucine. Which disease they may have later?',
  'outcome-cox_hrs',
  'age > 49, prior = tranexamic acid, year > 2010'],
 ['What is the hazard ratio of osteoarthritis for those females between 92 and 99 who had cirrhosis between 2005 and 2020?',
  'What is the danger ratio of osteoarthritis for these women between 92 and 99 with cirrhosis between 2005 and 2020?',
  'During 2005-2020, what is the risk rate of osteoarthritis if an old lady between 92-99 with cirrhosis?',
  'What is the risk rate of deformer arthrosis if a women between 92-99 with cirrhosis during 2005-2020?',
  'If an old grandma who younger than 99 but older than 92 gets diagnosed with cirrhosis between 2005 and 2020. What is her risk of osteoarthritis?',
  'What is the dangerous ratio of osteoarthritis considering females aged between 92-99 from 2005 to 2020 given cirrhosis?',
  'hr-cox_hrs',
  'age between 92 and 99, outcome = osteoarthritis, prior = cirrhosis, sex = female, year between 2005 and 2020'],
 ['What is the average age of people who died after dysphagia in swallowing problems diagnosis?',
  'If one has dysphagia in swallowing problems. What is the average age of death?',
  'What is the average age of death given diagnosis of swallowing problems?',
  'What is the average age of death after being diagnosed with dysphagia in swallowing problems?',
  'What is the mean age of death regarding to dysphagia in swallowing problems?',
  'Considering dysphagia in swallowing problems, what is the age of death on average?',
  'avg(age)-mortality',
  'cut_year = 0, endpoint = dysphagia in swallowing problems'],
 ["Given mirtazapine, what're the strongest associated comorbidities for men over 99 years old in 2006?",
  'Given the Mirtazapine, what are the strongest associated comorbidities for senior males above 99 in 2006?',
  'Given Mirtazapine, what are the strongest associated comorbidities in 2006 for men over 99?',
  'Considering Meltazapine, what is the strongest related labor work for men over 99 in 2006?',
  'Given Mirtazapin, what was the strongest associated comormission among men over the age of 99 in 2006?',
  'What is the strongest related diseases in 2006 if men over 99 years old were diagnosed with mirtazapine?',
  'outcome-cox_hrs',
  'age > 99, prior = mirtazapine, sex = male, year = 2006'],
 ['What is the mean age at the first event of common heart conditions among women?',
  'What is the average age at the first event of common heart status among women?',
  'What is the average age of women who get diagnosed with common heart conditions for their first time?',
  'What is the average age when women get diagnosed with common heart conditions for the first time?',
  'What is the average age of women with common heart disease for the 1st time?',
  'How old on average are the women diagnosed with common heart disease for the 1st time?',
  'avg(age)-long_registry',
  'endpoint = common heart conditions, sex = female']]
